# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.ptt.cc/bbs/index.html'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    title_links = soup.select('div', class_='title')

    for title_link in title_links:
        # 印出每個找到的標題文字（去除前後空白）
        print(title_link.text.strip())
# Out:
# 200
# 批踢踢實業坊
# 關於我們
# 聯絡資訊
# 批踢踢實業坊
# 關於我們
# 聯絡資訊
# 熱門看板
# 分類看板
#
#
#
#
#
#
# Gossiping
# 10408
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
#
#
#
#
# Stock
# 5026
# 學術
# ◎[股票] 地震來襲 請注意安全
#
#
#
#
# NBA
# 4350
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
#
#
#
#
# C_Chat
# 3585
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
#
#
#
#
# Baseball
# 2035
# 棒球
# ◎[棒球] Baseball is life
#
#
#
#
# HatePolitics
# 1326
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
#
#
#
#
# marriage
# 1206
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
#
#
#
#
# Lifeismoney
# 927
# 省錢
# ◎推薦碼板規已修改，推文前請注意
#
#
#
#
# KoreaStar
# 754
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
#
#
#
#
# LoL
# 752
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
#
#
#
#
# home-sale
# 710
# 房屋
# ◎[房版] 房屋買賣版
#
#
#
#
# car
# 605
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
#
#
#
#
# basketballTW
# 528
# 籃球
# ◎[台籃]        例行賽
#
#
#
#
# sex
# 504
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
#
#
#
#
# MobileComm
# 383
# 資訊
# ◎[通訊]
#
#
#
#
# Tech_Job
# 379
# 工作
# ◎[科技] 這裡是科技板
#
#
#
#
# movie
# 348
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
#
#
#
#
# Beauty
# 337
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
#
#
#
#
# Japan_Travel
# 327
# 旅遊
# ◎感謝各位參與富士山票選
#
#
#
#
# Military
# 295
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
#
#
#
#
# BaseballXXXX
# 284
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
#
#
#
#
# PlayStation
# 275
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
#
#
#
#
# PC_Shopping
# 267
# 硬體
# ◎[電蝦] intel 13 14代災情回報
#
#
#
#
# BabyMother
# 251
# 家庭
# ◎[寶寶] 記得打流感疫苗
#
#
#
#
# creditcard
# 247
# 理財
# ◎[卡板]
#
#
#
#
# KoreaDrama
# 237
# 韓劇
# ◎[韓劇]
#
#
#
#
# miHoYo
# 221
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
#
#
#
#
# Marginalman
# 196
# 心情
# ◎[邊緣] どう足掻いても明日はない
#
#
#
#
# WomenTalk
# 195
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
#
#
#
#
# TaichungBun
# 190
# 台中
# ◎[台中] 節約用水 節約用電
#
#
#
#
# SportLottery
# 178
# 博弈
# ◎[運彩] 運彩板
#
#
#
#
# Steam
# 174
# 平台
# ◎本板禁止買賣合購代購代刷
#
#
#
#
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
#
#
#
#
# G-S-WARRIORS
# 171
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
#
#
#
#
# japanavgirls
# 169
# 綜合
# ◎AV女優板 清新、優質,神人照格式
#
#
#
#
# Boy-Girl
# 164
# 心情
# ◎[男女] 水桶很滿 推文請三思
#
#
#
#
# Tainan
# 162
# 台南
# ◎[台南] 請詳閱交易文規範:)
#
#
#
#
# Kaohsiung
# 150
# 高雄
# ◎高雄板
#
#
#
#
# HardwareSale
# 149
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
#
#
#
#
# AllTogether
# 149
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
#
#
#
#
# marvel
# 127
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
#
#
#
#
# Elephants
# 126
# CPBL
# ◎The Last Together 最後一齊
#
#
#
#
# CFantasy
# 121
# 玄幻
# ◎[玄幻] 玄幻小說板
#
#
#
#
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
#
#
#
#
# iOS
# 113
# 系統
# ◎[iOS] Apple®devices family
#
#
#
#
# joke
# 113
# 娛樂
# ◎[就可] 貓貓可愛
#
#
#
#
# CVS
# 110
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
#
#
#
#
# NSwitch
# 105
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
#
#
#
#
# e-shopping
# 104
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
#
#
#
#
# EAseries
# 102
# 歐美
# ◎[EA] 歐美影集版
#
#
#
#
# AC_In
# 101
# 閒談
# ◎[裏洽] 勤洗手
#
#
#
#
# CarShop
# 94
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
#
#
#
#
# ONE_PIECE
# 92
# 日本
# ◎[海賊王] 1111 「太陽之盾」
#
#
#
#
# biker
# 91
# 車車
# ◎[機車]殺人部長 王國才
#
#
#
#
# PuzzleDragon
# 89
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
#
#
#
#
# Aviation
# 85
# 交通
# ◎[航空] 航空板 請先詳閱板規
#
#
#
#
# MacShop
# 83
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
#
#
#
#
# mobilesales
# 82
# 資訊
# ◎[Mobile] 板規不看，水桶就來
#
#
#
#
# BeautySalon
# 82
# 美容
# ◎[美保]
#
#
#
#
# Japandrama
# 81
# 日劇
# ◎[日劇] 土22 森本慎太郎
#
#
#
#
# Gamesale
# 77
# 綜合
# ◎[GS] 遊戲交易板
#
#
#
#
# KR_Entertain
# 75
# 綜藝
# ◎[韓綜] Show Me The 新板主!
#
#
#
#
# BabyProducts
# 74
# 買賣
# ◎婦嬰用品販售版
#
#
#
#
# China-Drama
# 73
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
#
#
#
#
# e-coupon
# 70
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
#
#
#
#
# Drama-Ticket
# 68
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
#
#
#
#
# DigiCurrency
# 66
# 資訊
# ◎[數位貨幣] 地動山搖
#
#
#
#
# DSLR
# 65
# 攝影
# ◎[攝影] 2024
#
#
#
#
# Hsinchu
# 63
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
#
#
#
#
# Lions
# 63
# CPBL
# ◎統一獅板
#
#
#
#
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
#
#
#
#
# Headphone
# 59
# 資訊
# ◎水桶機器人值勤中 O口O
#
#
#
#
# studyteacher
# 58
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
#
#
#
#
# YuanChuang
# 56
# 原創
# ◎[原創] 年度必看 徵文詳見置底
#
#
#
#
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
#
#
#
#
# Salary
# 56
# 職場
# ◎[職場] 工作職場板
#
#
#
#
# PublicServan
# 54
# 公職
# ◎[公職] 今年5/1軍公教不放假
#
#
#
#
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
#
#
#
#
# fastfood
# 53
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
#
#
#
#
# Teacher
# 50
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
#
#
#
#
# MuscleBeach
# 50
# 美體
# ◎[健身] 發文前請務必詳閱板規
#
#
#
#
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
#
#
#
#
# PokemonGO
# 50
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
#
#
#
#
# MLB
# 50
# #MLB
# ◎2024 Opening Day
#
#
#
#
# Hearthstone
# 49
# 線上
# ◎[爐石] 爐石十週年了!
#
#
#
#
# Wanted
# 47
# 徵求
# ◎[汪踢] 速揪吃早餐
#
#
#
#
# ToS
# 46
# 轉珠
# ◎[神魔] 四乃森蒼紫
#
#
#
#
# Badminton
# 46
# 羽球
# ◎[羽球版]
#
#
#
#
# Road_Running
# 45
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
#
#
#
#
# Audiophile
# 44
# 資訊
# ◎[喇音] 請詳閱置底板規公告
#
#
#
#
# cat
# 44
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
#
#
#
#
# Tennis
# 42
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
#
#
#
#
# Option
# 41
# 學術
# ◎[期權] 違規檢舉請至置底文
#
#
#
#
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
#
#
#
#
# BlueArchive
# 40
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
#
#
#
#
# MakeUp
# 40
# 美容
# ◎[美妝]
#
#
#
#
# tabletennis
# 40
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
#
#
#
#
# FAPL
# 38
# 聯賽
# ◎歡樂．三喵．足球
#
#
#
#
# Food
# 37
# 美食
# ◎美食板
#
#
#
#
# H-GAME
# 36
# 綜合
# ◎H-GAME板
#
#
#
#
# PathofExile
# 36
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
#
#
#
#
# Brand
# 36
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
#
#
#
#
# cookclub
# 36
# 烹飪
# ◎歡迎分享手做美食
#
#
#
#
# Railway
# 35
# 交通
# ◎[鐵道] 徵選板主
#
#
#
#
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
#
#
#
#
# Key_Mou_Pad
# 33
# 生活
# ◎[鍵鼠] 2024新年快樂
#
#
#
#
# TaiwanDrama
# 33
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
#
#
#
#
# DIABLO
# 33
# 線上
# ◎[暗黑] 暗黑2024年到來!
#
#
#
#
# Guardians
# 33
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
#
#
#
#
# MRT
# 33
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
#
#
#
#
# nb-shopping
# 32
# 硬體
# ◎[筆電蝦]
#
#
#
#
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
#
#
#
#
# Broad_Band
# 30
# 網路
# ◎[寬頻板] 禁發廣告文/轉讓文
#
#
#
#
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
#
#
#
#
# Insurance
# 30
# 理財
# ◎保險板-★徵業務、站內信★劣退
#
#
#
#
# WOW
# 30
# 線上
# ◎[WoW] 10.2.6 上線
#
#
#
#
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
#
#
#
#
# EatToDie
# 29
# 美食
# ◎[飽板] 能吃就是福
#
#
#
#
# Digitalhome
# 29
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
#
#
#
#
# part-time
# 29
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
#
#
#
#
# Soft_Job
# 28
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
#
#
#
#
# Taoyuan
# 28
# 桃園
# ◎[桃園]
#
#
#
#
# DMM_GAMES
# 28
# 遊戲
# ◎[DMMG] 歡迎光臨DMM GAMES
#
#
#
#
# BikerShop
# 27
# 買賣
# ◎機車相關買賣板‧一天限發一篇文
#
#
#
#
# Loan
# 27
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
#
#
#
#
# Gov_owned
# 27
# 國營
# ◎[國營] 徵求上榜心得文
#
#
#
#
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
#
#
#
#
# XBOX
# 26
# 主機
# ◎[XBOX] XGP疑問請先參閱置底/爬文
# 熱門看板
# 分類看板
# 熱門看板
# 分類看板
# 熱門看板
# 分類看板
# Gossiping
# 10408
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
#
#
#
#
# Stock
# 5026
# 學術
# ◎[股票] 地震來襲 請注意安全
#
#
#
#
# NBA
# 4350
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
#
#
#
#
# C_Chat
# 3585
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
#
#
#
#
# Baseball
# 2035
# 棒球
# ◎[棒球] Baseball is life
#
#
#
#
# HatePolitics
# 1326
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
#
#
#
#
# marriage
# 1206
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
#
#
#
#
# Lifeismoney
# 927
# 省錢
# ◎推薦碼板規已修改，推文前請注意
#
#
#
#
# KoreaStar
# 754
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
#
#
#
#
# LoL
# 752
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
#
#
#
#
# home-sale
# 710
# 房屋
# ◎[房版] 房屋買賣版
#
#
#
#
# car
# 605
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
#
#
#
#
# basketballTW
# 528
# 籃球
# ◎[台籃]        例行賽
#
#
#
#
# sex
# 504
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
#
#
#
#
# MobileComm
# 383
# 資訊
# ◎[通訊]
#
#
#
#
# Tech_Job
# 379
# 工作
# ◎[科技] 這裡是科技板
#
#
#
#
# movie
# 348
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
#
#
#
#
# Beauty
# 337
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
#
#
#
#
# Japan_Travel
# 327
# 旅遊
# ◎感謝各位參與富士山票選
#
#
#
#
# Military
# 295
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
#
#
#
#
# BaseballXXXX
# 284
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
#
#
#
#
# PlayStation
# 275
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
#
#
#
#
# PC_Shopping
# 267
# 硬體
# ◎[電蝦] intel 13 14代災情回報
#
#
#
#
# BabyMother
# 251
# 家庭
# ◎[寶寶] 記得打流感疫苗
#
#
#
#
# creditcard
# 247
# 理財
# ◎[卡板]
#
#
#
#
# KoreaDrama
# 237
# 韓劇
# ◎[韓劇]
#
#
#
#
# miHoYo
# 221
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
#
#
#
#
# Marginalman
# 196
# 心情
# ◎[邊緣] どう足掻いても明日はない
#
#
#
#
# WomenTalk
# 195
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
#
#
#
#
# TaichungBun
# 190
# 台中
# ◎[台中] 節約用水 節約用電
#
#
#
#
# SportLottery
# 178
# 博弈
# ◎[運彩] 運彩板
#
#
#
#
# Steam
# 174
# 平台
# ◎本板禁止買賣合購代購代刷
#
#
#
#
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
#
#
#
#
# G-S-WARRIORS
# 171
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
#
#
#
#
# japanavgirls
# 169
# 綜合
# ◎AV女優板 清新、優質,神人照格式
#
#
#
#
# Boy-Girl
# 164
# 心情
# ◎[男女] 水桶很滿 推文請三思
#
#
#
#
# Tainan
# 162
# 台南
# ◎[台南] 請詳閱交易文規範:)
#
#
#
#
# Kaohsiung
# 150
# 高雄
# ◎高雄板
#
#
#
#
# HardwareSale
# 149
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
#
#
#
#
# AllTogether
# 149
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
#
#
#
#
# marvel
# 127
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
#
#
#
#
# Elephants
# 126
# CPBL
# ◎The Last Together 最後一齊
#
#
#
#
# CFantasy
# 121
# 玄幻
# ◎[玄幻] 玄幻小說板
#
#
#
#
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
#
#
#
#
# iOS
# 113
# 系統
# ◎[iOS] Apple®devices family
#
#
#
#
# joke
# 113
# 娛樂
# ◎[就可] 貓貓可愛
#
#
#
#
# CVS
# 110
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
#
#
#
#
# NSwitch
# 105
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
#
#
#
#
# e-shopping
# 104
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
#
#
#
#
# EAseries
# 102
# 歐美
# ◎[EA] 歐美影集版
#
#
#
#
# AC_In
# 101
# 閒談
# ◎[裏洽] 勤洗手
#
#
#
#
# CarShop
# 94
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
#
#
#
#
# ONE_PIECE
# 92
# 日本
# ◎[海賊王] 1111 「太陽之盾」
#
#
#
#
# biker
# 91
# 車車
# ◎[機車]殺人部長 王國才
#
#
#
#
# PuzzleDragon
# 89
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
#
#
#
#
# Aviation
# 85
# 交通
# ◎[航空] 航空板 請先詳閱板規
#
#
#
#
# MacShop
# 83
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
#
#
#
#
# mobilesales
# 82
# 資訊
# ◎[Mobile] 板規不看，水桶就來
#
#
#
#
# BeautySalon
# 82
# 美容
# ◎[美保]
#
#
#
#
# Japandrama
# 81
# 日劇
# ◎[日劇] 土22 森本慎太郎
#
#
#
#
# Gamesale
# 77
# 綜合
# ◎[GS] 遊戲交易板
#
#
#
#
# KR_Entertain
# 75
# 綜藝
# ◎[韓綜] Show Me The 新板主!
#
#
#
#
# BabyProducts
# 74
# 買賣
# ◎婦嬰用品販售版
#
#
#
#
# China-Drama
# 73
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
#
#
#
#
# e-coupon
# 70
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
#
#
#
#
# Drama-Ticket
# 68
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
#
#
#
#
# DigiCurrency
# 66
# 資訊
# ◎[數位貨幣] 地動山搖
#
#
#
#
# DSLR
# 65
# 攝影
# ◎[攝影] 2024
#
#
#
#
# Hsinchu
# 63
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
#
#
#
#
# Lions
# 63
# CPBL
# ◎統一獅板
#
#
#
#
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
#
#
#
#
# Headphone
# 59
# 資訊
# ◎水桶機器人值勤中 O口O
#
#
#
#
# studyteacher
# 58
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
#
#
#
#
# YuanChuang
# 56
# 原創
# ◎[原創] 年度必看 徵文詳見置底
#
#
#
#
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
#
#
#
#
# Salary
# 56
# 職場
# ◎[職場] 工作職場板
#
#
#
#
# PublicServan
# 54
# 公職
# ◎[公職] 今年5/1軍公教不放假
#
#
#
#
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
#
#
#
#
# fastfood
# 53
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
#
#
#
#
# Teacher
# 50
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
#
#
#
#
# MuscleBeach
# 50
# 美體
# ◎[健身] 發文前請務必詳閱板規
#
#
#
#
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
#
#
#
#
# PokemonGO
# 50
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
#
#
#
#
# MLB
# 50
# #MLB
# ◎2024 Opening Day
#
#
#
#
# Hearthstone
# 49
# 線上
# ◎[爐石] 爐石十週年了!
#
#
#
#
# Wanted
# 47
# 徵求
# ◎[汪踢] 速揪吃早餐
#
#
#
#
# ToS
# 46
# 轉珠
# ◎[神魔] 四乃森蒼紫
#
#
#
#
# Badminton
# 46
# 羽球
# ◎[羽球版]
#
#
#
#
# Road_Running
# 45
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
#
#
#
#
# Audiophile
# 44
# 資訊
# ◎[喇音] 請詳閱置底板規公告
#
#
#
#
# cat
# 44
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
#
#
#
#
# Tennis
# 42
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
#
#
#
#
# Option
# 41
# 學術
# ◎[期權] 違規檢舉請至置底文
#
#
#
#
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
#
#
#
#
# BlueArchive
# 40
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
#
#
#
#
# MakeUp
# 40
# 美容
# ◎[美妝]
#
#
#
#
# tabletennis
# 40
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
#
#
#
#
# FAPL
# 38
# 聯賽
# ◎歡樂．三喵．足球
#
#
#
#
# Food
# 37
# 美食
# ◎美食板
#
#
#
#
# H-GAME
# 36
# 綜合
# ◎H-GAME板
#
#
#
#
# PathofExile
# 36
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
#
#
#
#
# Brand
# 36
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
#
#
#
#
# cookclub
# 36
# 烹飪
# ◎歡迎分享手做美食
#
#
#
#
# Railway
# 35
# 交通
# ◎[鐵道] 徵選板主
#
#
#
#
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
#
#
#
#
# Key_Mou_Pad
# 33
# 生活
# ◎[鍵鼠] 2024新年快樂
#
#
#
#
# TaiwanDrama
# 33
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
#
#
#
#
# DIABLO
# 33
# 線上
# ◎[暗黑] 暗黑2024年到來!
#
#
#
#
# Guardians
# 33
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
#
#
#
#
# MRT
# 33
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
#
#
#
#
# nb-shopping
# 32
# 硬體
# ◎[筆電蝦]
#
#
#
#
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
#
#
#
#
# Broad_Band
# 30
# 網路
# ◎[寬頻板] 禁發廣告文/轉讓文
#
#
#
#
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
#
#
#
#
# Insurance
# 30
# 理財
# ◎保險板-★徵業務、站內信★劣退
#
#
#
#
# WOW
# 30
# 線上
# ◎[WoW] 10.2.6 上線
#
#
#
#
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
#
#
#
#
# EatToDie
# 29
# 美食
# ◎[飽板] 能吃就是福
#
#
#
#
# Digitalhome
# 29
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
#
#
#
#
# part-time
# 29
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
#
#
#
#
# Soft_Job
# 28
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
#
#
#
#
# Taoyuan
# 28
# 桃園
# ◎[桃園]
#
#
#
#
# DMM_GAMES
# 28
# 遊戲
# ◎[DMMG] 歡迎光臨DMM GAMES
#
#
#
#
# BikerShop
# 27
# 買賣
# ◎機車相關買賣板‧一天限發一篇文
#
#
#
#
# Loan
# 27
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
#
#
#
#
# Gov_owned
# 27
# 國營
# ◎[國營] 徵求上榜心得文
#
#
#
#
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
#
#
#
#
# XBOX
# 26
# 主機
# ◎[XBOX] XGP疑問請先參閱置底/爬文
# Gossiping
# 10408
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
# Gossiping
# 10408
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
# Stock
# 5026
# 學術
# ◎[股票] 地震來襲 請注意安全
# Stock
# 5026
# 學術
# ◎[股票] 地震來襲 請注意安全
# NBA
# 4350
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
# NBA
# 4350
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
# C_Chat
# 3585
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
# C_Chat
# 3585
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
# Baseball
# 2035
# 棒球
# ◎[棒球] Baseball is life
# Baseball
# 2035
# 棒球
# ◎[棒球] Baseball is life
# HatePolitics
# 1326
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
# HatePolitics
# 1326
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
# marriage
# 1206
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
# marriage
# 1206
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
# Lifeismoney
# 927
# 省錢
# ◎推薦碼板規已修改，推文前請注意
# Lifeismoney
# 927
# 省錢
# ◎推薦碼板規已修改，推文前請注意
# KoreaStar
# 754
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
# KoreaStar
# 754
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
# LoL
# 752
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
# LoL
# 752
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
# home-sale
# 710
# 房屋
# ◎[房版] 房屋買賣版
# home-sale
# 710
# 房屋
# ◎[房版] 房屋買賣版
# car
# 605
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
# car
# 605
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
# basketballTW
# 528
# 籃球
# ◎[台籃]        例行賽
# basketballTW
# 528
# 籃球
# ◎[台籃]        例行賽
# sex
# 504
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
# sex
# 504
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
# MobileComm
# 383
# 資訊
# ◎[通訊]
# MobileComm
# 383
# 資訊
# ◎[通訊]
# Tech_Job
# 379
# 工作
# ◎[科技] 這裡是科技板
# Tech_Job
# 379
# 工作
# ◎[科技] 這裡是科技板
# movie
# 348
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
# movie
# 348
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
# Beauty
# 337
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
# Beauty
# 337
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
# Japan_Travel
# 327
# 旅遊
# ◎感謝各位參與富士山票選
# Japan_Travel
# 327
# 旅遊
# ◎感謝各位參與富士山票選
# Military
# 295
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
# Military
# 295
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
# BaseballXXXX
# 284
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
# BaseballXXXX
# 284
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
# PlayStation
# 275
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
# PlayStation
# 275
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
# PC_Shopping
# 267
# 硬體
# ◎[電蝦] intel 13 14代災情回報
# PC_Shopping
# 267
# 硬體
# ◎[電蝦] intel 13 14代災情回報
# BabyMother
# 251
# 家庭
# ◎[寶寶] 記得打流感疫苗
# BabyMother
# 251
# 家庭
# ◎[寶寶] 記得打流感疫苗
# creditcard
# 247
# 理財
# ◎[卡板]
# creditcard
# 247
# 理財
# ◎[卡板]
# KoreaDrama
# 237
# 韓劇
# ◎[韓劇]
# KoreaDrama
# 237
# 韓劇
# ◎[韓劇]
# miHoYo
# 221
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
# miHoYo
# 221
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
# Marginalman
# 196
# 心情
# ◎[邊緣] どう足掻いても明日はない
# Marginalman
# 196
# 心情
# ◎[邊緣] どう足掻いても明日はない
# WomenTalk
# 195
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
# WomenTalk
# 195
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
# TaichungBun
# 190
# 台中
# ◎[台中] 節約用水 節約用電
# TaichungBun
# 190
# 台中
# ◎[台中] 節約用水 節約用電
# SportLottery
# 178
# 博弈
# ◎[運彩] 運彩板
# SportLottery
# 178
# 博弈
# ◎[運彩] 運彩板
# Steam
# 174
# 平台
# ◎本板禁止買賣合購代購代刷
# Steam
# 174
# 平台
# ◎本板禁止買賣合購代購代刷
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
# G-S-WARRIORS
# 171
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
# G-S-WARRIORS
# 171
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
# japanavgirls
# 169
# 綜合
# ◎AV女優板 清新、優質,神人照格式
# japanavgirls
# 169
# 綜合
# ◎AV女優板 清新、優質,神人照格式
# Boy-Girl
# 164
# 心情
# ◎[男女] 水桶很滿 推文請三思
# Boy-Girl
# 164
# 心情
# ◎[男女] 水桶很滿 推文請三思
# Tainan
# 162
# 台南
# ◎[台南] 請詳閱交易文規範:)
# Tainan
# 162
# 台南
# ◎[台南] 請詳閱交易文規範:)
# Kaohsiung
# 150
# 高雄
# ◎高雄板
# Kaohsiung
# 150
# 高雄
# ◎高雄板
# HardwareSale
# 149
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
# HardwareSale
# 149
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
# AllTogether
# 149
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
# AllTogether
# 149
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
# marvel
# 127
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
# marvel
# 127
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
# Elephants
# 126
# CPBL
# ◎The Last Together 最後一齊
# Elephants
# 126
# CPBL
# ◎The Last Together 最後一齊
# CFantasy
# 121
# 玄幻
# ◎[玄幻] 玄幻小說板
# CFantasy
# 121
# 玄幻
# ◎[玄幻] 玄幻小說板
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
# iOS
# 113
# 系統
# ◎[iOS] Apple®devices family
# iOS
# 113
# 系統
# ◎[iOS] Apple®devices family
# joke
# 113
# 娛樂
# ◎[就可] 貓貓可愛
# joke
# 113
# 娛樂
# ◎[就可] 貓貓可愛
# CVS
# 110
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
# CVS
# 110
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
# NSwitch
# 105
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
# NSwitch
# 105
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
# e-shopping
# 104
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
# e-shopping
# 104
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
# EAseries
# 102
# 歐美
# ◎[EA] 歐美影集版
# EAseries
# 102
# 歐美
# ◎[EA] 歐美影集版
# AC_In
# 101
# 閒談
# ◎[裏洽] 勤洗手
# AC_In
# 101
# 閒談
# ◎[裏洽] 勤洗手
# CarShop
# 94
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
# CarShop
# 94
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
# ONE_PIECE
# 92
# 日本
# ◎[海賊王] 1111 「太陽之盾」
# ONE_PIECE
# 92
# 日本
# ◎[海賊王] 1111 「太陽之盾」
# biker
# 91
# 車車
# ◎[機車]殺人部長 王國才
# biker
# 91
# 車車
# ◎[機車]殺人部長 王國才
# PuzzleDragon
# 89
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
# PuzzleDragon
# 89
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
# Aviation
# 85
# 交通
# ◎[航空] 航空板 請先詳閱板規
# Aviation
# 85
# 交通
# ◎[航空] 航空板 請先詳閱板規
# MacShop
# 83
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
# MacShop
# 83
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
# mobilesales
# 82
# 資訊
# ◎[Mobile] 板規不看，水桶就來
# mobilesales
# 82
# 資訊
# ◎[Mobile] 板規不看，水桶就來
# BeautySalon
# 82
# 美容
# ◎[美保]
# BeautySalon
# 82
# 美容
# ◎[美保]
# Japandrama
# 81
# 日劇
# ◎[日劇] 土22 森本慎太郎
# Japandrama
# 81
# 日劇
# ◎[日劇] 土22 森本慎太郎
# Gamesale
# 77
# 綜合
# ◎[GS] 遊戲交易板
# Gamesale
# 77
# 綜合
# ◎[GS] 遊戲交易板
# KR_Entertain
# 75
# 綜藝
# ◎[韓綜] Show Me The 新板主!
# KR_Entertain
# 75
# 綜藝
# ◎[韓綜] Show Me The 新板主!
# BabyProducts
# 74
# 買賣
# ◎婦嬰用品販售版
# BabyProducts
# 74
# 買賣
# ◎婦嬰用品販售版
# China-Drama
# 73
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
# China-Drama
# 73
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
# e-coupon
# 70
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# e-coupon
# 70
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# Drama-Ticket
# 68
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
# Drama-Ticket
# 68
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
# DigiCurrency
# 66
# 資訊
# ◎[數位貨幣] 地動山搖
# DigiCurrency
# 66
# 資訊
# ◎[數位貨幣] 地動山搖
# DSLR
# 65
# 攝影
# ◎[攝影] 2024
# DSLR
# 65
# 攝影
# ◎[攝影] 2024
# Hsinchu
# 63
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
# Hsinchu
# 63
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
# Lions
# 63
# CPBL
# ◎統一獅板
# Lions
# 63
# CPBL
# ◎統一獅板
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
# Headphone
# 59
# 資訊
# ◎水桶機器人值勤中 O口O
# Headphone
# 59
# 資訊
# ◎水桶機器人值勤中 O口O
# studyteacher
# 58
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
# studyteacher
# 58
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
# YuanChuang
# 56
# 原創
# ◎[原創] 年度必看 徵文詳見置底
# YuanChuang
# 56
# 原創
# ◎[原創] 年度必看 徵文詳見置底
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
# Salary
# 56
# 職場
# ◎[職場] 工作職場板
# Salary
# 56
# 職場
# ◎[職場] 工作職場板
# PublicServan
# 54
# 公職
# ◎[公職] 今年5/1軍公教不放假
# PublicServan
# 54
# 公職
# ◎[公職] 今年5/1軍公教不放假
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
# fastfood
# 53
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
# fastfood
# 53
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
# Teacher
# 50
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
# Teacher
# 50
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
# MuscleBeach
# 50
# 美體
# ◎[健身] 發文前請務必詳閱板規
# MuscleBeach
# 50
# 美體
# ◎[健身] 發文前請務必詳閱板規
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
# PokemonGO
# 50
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
# PokemonGO
# 50
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
# MLB
# 50
# #MLB
# ◎2024 Opening Day
# MLB
# 50
# #MLB
# ◎2024 Opening Day
# Hearthstone
# 49
# 線上
# ◎[爐石] 爐石十週年了!
# Hearthstone
# 49
# 線上
# ◎[爐石] 爐石十週年了!
# Wanted
# 47
# 徵求
# ◎[汪踢] 速揪吃早餐
# Wanted
# 47
# 徵求
# ◎[汪踢] 速揪吃早餐
# ToS
# 46
# 轉珠
# ◎[神魔] 四乃森蒼紫
# ToS
# 46
# 轉珠
# ◎[神魔] 四乃森蒼紫
# Badminton
# 46
# 羽球
# ◎[羽球版]
# Badminton
# 46
# 羽球
# ◎[羽球版]
# Road_Running
# 45
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
# Road_Running
# 45
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
# Audiophile
# 44
# 資訊
# ◎[喇音] 請詳閱置底板規公告
# Audiophile
# 44
# 資訊
# ◎[喇音] 請詳閱置底板規公告
# cat
# 44
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
# cat
# 44
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
# Tennis
# 42
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
# Tennis
# 42
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
# Option
# 41
# 學術
# ◎[期權] 違規檢舉請至置底文
# Option
# 41
# 學術
# ◎[期權] 違規檢舉請至置底文
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
# BlueArchive
# 40
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
# BlueArchive
# 40
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
# MakeUp
# 40
# 美容
# ◎[美妝]
# MakeUp
# 40
# 美容
# ◎[美妝]
# tabletennis
# 40
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
# tabletennis
# 40
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
# FAPL
# 38
# 聯賽
# ◎歡樂．三喵．足球
# FAPL
# 38
# 聯賽
# ◎歡樂．三喵．足球
# Food
# 37
# 美食
# ◎美食板
# Food
# 37
# 美食
# ◎美食板
# H-GAME
# 36
# 綜合
# ◎H-GAME板
# H-GAME
# 36
# 綜合
# ◎H-GAME板
# PathofExile
# 36
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
# PathofExile
# 36
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
# Brand
# 36
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
# Brand
# 36
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
# cookclub
# 36
# 烹飪
# ◎歡迎分享手做美食
# cookclub
# 36
# 烹飪
# ◎歡迎分享手做美食
# Railway
# 35
# 交通
# ◎[鐵道] 徵選板主
# Railway
# 35
# 交通
# ◎[鐵道] 徵選板主
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
# Key_Mou_Pad
# 33
# 生活
# ◎[鍵鼠] 2024新年快樂
# Key_Mou_Pad
# 33
# 生活
# ◎[鍵鼠] 2024新年快樂
# TaiwanDrama
# 33
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
# TaiwanDrama
# 33
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
# DIABLO
# 33
# 線上
# ◎[暗黑] 暗黑2024年到來!
# DIABLO
# 33
# 線上
# ◎[暗黑] 暗黑2024年到來!
# Guardians
# 33
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
# Guardians
# 33
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
# MRT
# 33
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
# MRT
# 33
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
# nb-shopping
# 32
# 硬體
# ◎[筆電蝦]
# nb-shopping
# 32
# 硬體
# ◎[筆電蝦]
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
# Broad_Band
# 30
# 網路
# ◎[寬頻板] 禁發廣告文/轉讓文
# Broad_Band
# 30
# 網路
# ◎[寬頻板] 禁發廣告文/轉讓文
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
# Insurance
# 30
# 理財
# ◎保險板-★徵業務、站內信★劣退
# Insurance
# 30
# 理財
# ◎保險板-★徵業務、站內信★劣退
# WOW
# 30
# 線上
# ◎[WoW] 10.2.6 上線
# WOW
# 30
# 線上
# ◎[WoW] 10.2.6 上線
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
# EatToDie
# 29
# 美食
# ◎[飽板] 能吃就是福
# EatToDie
# 29
# 美食
# ◎[飽板] 能吃就是福
# Digitalhome
# 29
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
# Digitalhome
# 29
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
# part-time
# 29
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
# part-time
# 29
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
# Soft_Job
# 28
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
# Soft_Job
# 28
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
# Taoyuan
# 28
# 桃園
# ◎[桃園]
# Taoyuan
# 28
# 桃園
# ◎[桃園]
# DMM_GAMES
# 28
# 遊戲
# ◎[DMMG] 歡迎光臨DMM GAMES
# DMM_GAMES
# 28
# 遊戲
# ◎[DMMG] 歡迎光臨DMM GAMES
# BikerShop
# 27
# 買賣
# ◎機車相關買賣板‧一天限發一篇文
# BikerShop
# 27
# 買賣
# ◎機車相關買賣板‧一天限發一篇文
# Loan
# 27
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
# Loan
# 27
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
# Gov_owned
# 27
# 國營
# ◎[國營] 徵求上榜心得文
# Gov_owned
# 27
# 國營
# ◎[國營] 徵求上榜心得文
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
# XBOX
# 26
# 主機
# ◎[XBOX] XGP疑問請先參閱置底/爬文
# XBOX
# 26
# 主機
# ◎[XBOX] XGP疑問請先參閱置底/爬文

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.ptt.cc/bbs/index.html'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # 將選擇器改回 'div', class_='title'
    title_links = soup.select('div', class_='title')

    for title_link in title_links:
        # 印出每個找到的標題文字（去除前後空白），並在後面加上短橫線分隔符
        print(title_link.text.strip())
        print('-' * 20)  # 這裡是20個短橫線，可以根據需要調整
# Out:
# 批踢踢實業坊
# 關於我們
# 聯絡資訊
# --------------------
# 批踢踢實業坊
# 關於我們
# 聯絡資訊
# --------------------
# 熱門看板
# 分類看板
#
#
#
#
#
#
# Gossiping
# 10412
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
#
#
#
#
# Stock
# 5072
# 學術
# ◎[股票] 地震來襲 請注意安全
#
#
#
#
# NBA
# 4189
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
#
#
#
#
# C_Chat
# 3588
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
#
#
#
#
# Baseball
# 2034
# 棒球
# ◎[棒球] Baseball is life
#
#
#
#
# HatePolitics
# 1368
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
#
#
#
#
# marriage
# 1230
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
#
#
#
#
# Lifeismoney
# 920
# 省錢
# ◎推薦碼板規已修改，推文前請注意
#
#
#
#
# KoreaStar
# 785
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
#
#
#
#
# LoL
# 775
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
#
#
#
#
# home-sale
# 720
# 房屋
# ◎[房版] 房屋買賣版
#
#
#
#
# car
# 591
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
#
#
#
#
# basketballTW
# 553
# 籃球
# ◎[台籃]        例行賽
#
#
#
#
# sex
# 510
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
#
#
#
#
# MobileComm
# 375
# 資訊
# ◎[通訊]
#
#
#
#
# movie
# 359
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
#
#
#
#
# Tech_Job
# 354
# 工作
# ◎[科技] 這裡是科技板
#
#
#
#
# Beauty
# 338
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
#
#
#
#
# Japan_Travel
# 337
# 旅遊
# ◎感謝各位參與富士山票選
#
#
#
#
# Military
# 303
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
#
#
#
#
# BaseballXXXX
# 286
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
#
#
#
#
# PC_Shopping
# 283
# 硬體
# ◎[電蝦] intel 13 14代災情回報
#
#
#
#
# PlayStation
# 281
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
#
#
#
#
# creditcard
# 268
# 理財
# ◎[卡板]
#
#
#
#
# BabyMother
# 241
# 家庭
# ◎[寶寶] 記得打流感疫苗
#
#
#
#
# KoreaDrama
# 238
# 韓劇
# ◎[韓劇]
#
#
#
#
# miHoYo
# 237
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
#
#
#
#
# Marginalman
# 218
# 心情
# ◎[邊緣] どう足掻いても明日はない
#
#
#
#
# WomenTalk
# 205
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
#
#
#
#
# TaichungBun
# 200
# 台中
# ◎[台中] 節約用水 節約用電
#
#
#
#
# Tainan
# 177
# 台南
# ◎[台南] 請詳閱交易文規範:)
#
#
#
#
# SportLottery
# 176
# 博弈
# ◎[運彩] 運彩板
#
#
#
#
# G-S-WARRIORS
# 175
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
#
#
#
#
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
#
#
#
#
# japanavgirls
# 166
# 綜合
# ◎AV女優板 清新、優質,神人照格式
#
#
#
#
# Boy-Girl
# 166
# 心情
# ◎[男女] 水桶很滿 推文請三思
#
#
#
#
# Steam
# 165
# 平台
# ◎本板禁止買賣合購代購代刷
#
#
#
#
# Kaohsiung
# 150
# 高雄
# ◎高雄板
#
#
#
#
# AllTogether
# 148
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
#
#
#
#
# HardwareSale
# 141
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
#
#
#
#
# Elephants
# 133
# CPBL
# ◎The Last Together 最後一齊
#
#
#
#
# marvel
# 132
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
#
#
#
#
# iOS
# 124
# 系統
# ◎[iOS] Apple®devices family
#
#
#
#
# CFantasy
# 115
# 玄幻
# ◎[玄幻] 玄幻小說板
#
#
#
#
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
#
#
#
#
# joke
# 112
# 娛樂
# ◎[就可] 貓貓可愛
#
#
#
#
# EAseries
# 110
# 歐美
# ◎[EA] 歐美影集版
#
#
#
#
# AC_In
# 108
# 閒談
# ◎[裏洽] 勤洗手
#
#
#
#
# CVS
# 108
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
#
#
#
#
# e-shopping
# 105
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
#
#
#
#
# Aviation
# 93
# 交通
# ◎[航空] 航空板 請先詳閱板規
#
#
#
#
# NSwitch
# 92
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
#
#
#
#
# ONE_PIECE
# 91
# 日本
# ◎[海賊王] 1111 「太陽之盾」
#
#
#
#
# PuzzleDragon
# 90
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
#
#
#
#
# biker
# 88
# 車車
# ◎[機車]殺人部長 王國才
#
#
#
#
# CarShop
# 86
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
#
#
#
#
# Japandrama
# 84
# 日劇
# ◎[日劇] 土22 森本慎太郎
#
#
#
#
# MacShop
# 82
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
#
#
#
#
# BabyProducts
# 77
# 買賣
# ◎婦嬰用品販售版
#
#
#
#
# KR_Entertain
# 77
# 綜藝
# ◎[韓綜] Show Me The 新板主!
#
#
#
#
# Gamesale
# 76
# 綜合
# ◎[GS] 遊戲交易板
#
#
#
#
# mobilesales
# 75
# 資訊
# ◎[Mobile] 板規不看，水桶就來
#
#
#
#
# BeautySalon
# 74
# 美容
# ◎[美保]
#
#
#
#
# China-Drama
# 70
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
#
#
#
#
# Hsinchu
# 69
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
#
#
#
#
# DSLR
# 68
# 攝影
# ◎[攝影] 2024
#
#
#
#
# Drama-Ticket
# 67
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
#
#
#
#
# studyteacher
# 64
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
#
#
#
#
# Headphone
# 64
# 資訊
# ◎水桶機器人值勤中 O口O
#
#
#
#
# DigiCurrency
# 62
# 資訊
# ◎[數位貨幣] 地動山搖
#
#
#
#
# e-coupon
# 60
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
#
#
#
#
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
#
#
#
#
# Salary
# 59
# 職場
# ◎[職場] 工作職場板
#
#
#
#
# PokemonGO
# 59
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
#
#
#
#
# Teacher
# 58
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
#
#
#
#
# Lions
# 57
# CPBL
# ◎統一獅板
#
#
#
#
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
#
#
#
#
# Hearthstone
# 53
# 線上
# ◎[爐石] 爐石十週年了!
#
#
#
#
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
#
#
#
#
# fastfood
# 50
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
#
#
#
#
# Wanted
# 50
# 徵求
# ◎[汪踢] 速揪吃早餐
#
#
#
#
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
#
#
#
#
# YuanChuang
# 49
# 原創
# ◎[原創] 年度必看 徵文詳見置底
#
#
#
#
# MLB
# 48
# #MLB
# ◎2024 Opening Day
#
#
#
#
# PublicServan
# 47
# 公職
# ◎[公職] 今年5/1軍公教不放假
#
#
#
#
# Food
# 47
# 美食
# ◎美食板
#
#
#
#
# Audiophile
# 45
# 資訊
# ◎[喇音] 請詳閱置底板規公告
#
#
#
#
# Tennis
# 45
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
#
#
#
#
# BlueArchive
# 44
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
#
#
#
#
# ToS
# 44
# 轉珠
# ◎[神魔] 四乃森蒼紫
#
#
#
#
# MuscleBeach
# 44
# 美體
# ◎[健身] 發文前請務必詳閱板規
#
#
#
#
# tabletennis
# 43
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
#
#
#
#
# cat
# 42
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
#
#
#
#
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
#
#
#
#
# Badminton
# 40
# 羽球
# ◎[羽球版]
#
#
#
#
# cookclub
# 39
# 烹飪
# ◎歡迎分享手做美食
#
#
#
#
# Option
# 38
# 學術
# ◎[期權] 違規檢舉請至置底文
#
#
#
#
# Guardians
# 38
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
#
#
#
#
# DIABLO
# 36
# 線上
# ◎[暗黑] 暗黑2024年到來!
#
#
#
#
# PathofExile
# 35
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
#
#
#
#
# MakeUp
# 35
# 美容
# ◎[美妝]
#
#
#
#
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
#
#
#
#
# FAPL
# 34
# 聯賽
# ◎歡樂．三喵．足球
#
#
#
#
# H-GAME
# 33
# 綜合
# ◎H-GAME板
#
#
#
#
# Soft_Job
# 32
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
#
#
#
#
# Key_Mou_Pad
# 31
# 生活
# ◎[鍵鼠] 2024新年快樂
#
#
#
#
# MobilePay
# 31
# 理財
# ◎刷卡回饋問題請至信用卡板
#
#
#
#
# Road_Running
# 31
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
#
#
#
#
# WOW
# 31
# 線上
# ◎[WoW] 10.2.6 上線
#
#
#
#
# TaiwanDrama
# 31
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
#
#
#
#
# part-time
# 31
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
#
#
#
#
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
#
#
#
#
# nb-shopping
# 30
# 硬體
# ◎[筆電蝦]
#
#
#
#
# Railway
# 30
# 交通
# ◎[鐵道] 徵選板主
#
#
#
#
# Brand
# 30
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
#
#
#
#
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
#
#
#
#
# Taoyuan
# 30
# 桃園
# ◎[桃園]
#
#
#
#
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
#
#
#
#
# Digitalhome
# 30
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
#
#
#
#
# Insurance
# 29
# 理財
# ◎保險板-★徵業務、站內信★劣退
#
#
#
#
# ChangHua
# 28
# 彰化
# ◎[彰化]
#
#
#
#
# Loan
# 28
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
#
#
#
#
# FORMULA1
# 28
# 賽車
# ◎F1板 燈滅起跑!
#
#
#
#
# MRT
# 28
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
#
#
#
#
# TW_Entertain
# 28
# 綜藝
# ◎[台綜]
#
#
#
#
# KoreanPop
# 27
# 音樂
# ◎抵制買榜 抵制作弊，韓樂需要正義
#
#
#
#
# SuperBike
# 27
# 車車
# ◎PTT重機板 ~ 發買賣文請詳閱置底
#
#
#
#
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
# --------------------
# 熱門看板
# 分類看板
# --------------------
# 熱門看板
# 分類看板
# --------------------
# 熱門看板
# 分類看板
# --------------------
# Gossiping
# 10412
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
#
#
#
#
# Stock
# 5072
# 學術
# ◎[股票] 地震來襲 請注意安全
#
#
#
#
# NBA
# 4189
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
#
#
#
#
# C_Chat
# 3588
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
#
#
#
#
# Baseball
# 2034
# 棒球
# ◎[棒球] Baseball is life
#
#
#
#
# HatePolitics
# 1368
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
#
#
#
#
# marriage
# 1230
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
#
#
#
#
# Lifeismoney
# 920
# 省錢
# ◎推薦碼板規已修改，推文前請注意
#
#
#
#
# KoreaStar
# 785
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
#
#
#
#
# LoL
# 775
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
#
#
#
#
# home-sale
# 720
# 房屋
# ◎[房版] 房屋買賣版
#
#
#
#
# car
# 591
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
#
#
#
#
# basketballTW
# 553
# 籃球
# ◎[台籃]        例行賽
#
#
#
#
# sex
# 510
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
#
#
#
#
# MobileComm
# 375
# 資訊
# ◎[通訊]
#
#
#
#
# movie
# 359
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
#
#
#
#
# Tech_Job
# 354
# 工作
# ◎[科技] 這裡是科技板
#
#
#
#
# Beauty
# 338
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
#
#
#
#
# Japan_Travel
# 337
# 旅遊
# ◎感謝各位參與富士山票選
#
#
#
#
# Military
# 303
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
#
#
#
#
# BaseballXXXX
# 286
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
#
#
#
#
# PC_Shopping
# 283
# 硬體
# ◎[電蝦] intel 13 14代災情回報
#
#
#
#
# PlayStation
# 281
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
#
#
#
#
# creditcard
# 268
# 理財
# ◎[卡板]
#
#
#
#
# BabyMother
# 241
# 家庭
# ◎[寶寶] 記得打流感疫苗
#
#
#
#
# KoreaDrama
# 238
# 韓劇
# ◎[韓劇]
#
#
#
#
# miHoYo
# 237
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
#
#
#
#
# Marginalman
# 218
# 心情
# ◎[邊緣] どう足掻いても明日はない
#
#
#
#
# WomenTalk
# 205
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
#
#
#
#
# TaichungBun
# 200
# 台中
# ◎[台中] 節約用水 節約用電
#
#
#
#
# Tainan
# 177
# 台南
# ◎[台南] 請詳閱交易文規範:)
#
#
#
#
# SportLottery
# 176
# 博弈
# ◎[運彩] 運彩板
#
#
#
#
# G-S-WARRIORS
# 175
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
#
#
#
#
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
#
#
#
#
# japanavgirls
# 166
# 綜合
# ◎AV女優板 清新、優質,神人照格式
#
#
#
#
# Boy-Girl
# 166
# 心情
# ◎[男女] 水桶很滿 推文請三思
#
#
#
#
# Steam
# 165
# 平台
# ◎本板禁止買賣合購代購代刷
#
#
#
#
# Kaohsiung
# 150
# 高雄
# ◎高雄板
#
#
#
#
# AllTogether
# 148
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
#
#
#
#
# HardwareSale
# 141
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
#
#
#
#
# Elephants
# 133
# CPBL
# ◎The Last Together 最後一齊
#
#
#
#
# marvel
# 132
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
#
#
#
#
# iOS
# 124
# 系統
# ◎[iOS] Apple®devices family
#
#
#
#
# CFantasy
# 115
# 玄幻
# ◎[玄幻] 玄幻小說板
#
#
#
#
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
#
#
#
#
# joke
# 112
# 娛樂
# ◎[就可] 貓貓可愛
#
#
#
#
# EAseries
# 110
# 歐美
# ◎[EA] 歐美影集版
#
#
#
#
# AC_In
# 108
# 閒談
# ◎[裏洽] 勤洗手
#
#
#
#
# CVS
# 108
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
#
#
#
#
# e-shopping
# 105
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
#
#
#
#
# Aviation
# 93
# 交通
# ◎[航空] 航空板 請先詳閱板規
#
#
#
#
# NSwitch
# 92
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
#
#
#
#
# ONE_PIECE
# 91
# 日本
# ◎[海賊王] 1111 「太陽之盾」
#
#
#
#
# PuzzleDragon
# 90
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
#
#
#
#
# biker
# 88
# 車車
# ◎[機車]殺人部長 王國才
#
#
#
#
# CarShop
# 86
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
#
#
#
#
# Japandrama
# 84
# 日劇
# ◎[日劇] 土22 森本慎太郎
#
#
#
#
# MacShop
# 82
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
#
#
#
#
# BabyProducts
# 77
# 買賣
# ◎婦嬰用品販售版
#
#
#
#
# KR_Entertain
# 77
# 綜藝
# ◎[韓綜] Show Me The 新板主!
#
#
#
#
# Gamesale
# 76
# 綜合
# ◎[GS] 遊戲交易板
#
#
#
#
# mobilesales
# 75
# 資訊
# ◎[Mobile] 板規不看，水桶就來
#
#
#
#
# BeautySalon
# 74
# 美容
# ◎[美保]
#
#
#
#
# China-Drama
# 70
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
#
#
#
#
# Hsinchu
# 69
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
#
#
#
#
# DSLR
# 68
# 攝影
# ◎[攝影] 2024
#
#
#
#
# Drama-Ticket
# 67
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
#
#
#
#
# studyteacher
# 64
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
#
#
#
#
# Headphone
# 64
# 資訊
# ◎水桶機器人值勤中 O口O
#
#
#
#
# DigiCurrency
# 62
# 資訊
# ◎[數位貨幣] 地動山搖
#
#
#
#
# e-coupon
# 60
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
#
#
#
#
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
#
#
#
#
# Salary
# 59
# 職場
# ◎[職場] 工作職場板
#
#
#
#
# PokemonGO
# 59
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
#
#
#
#
# Teacher
# 58
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
#
#
#
#
# Lions
# 57
# CPBL
# ◎統一獅板
#
#
#
#
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
#
#
#
#
# Hearthstone
# 53
# 線上
# ◎[爐石] 爐石十週年了!
#
#
#
#
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
#
#
#
#
# fastfood
# 50
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
#
#
#
#
# Wanted
# 50
# 徵求
# ◎[汪踢] 速揪吃早餐
#
#
#
#
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
#
#
#
#
# YuanChuang
# 49
# 原創
# ◎[原創] 年度必看 徵文詳見置底
#
#
#
#
# MLB
# 48
# #MLB
# ◎2024 Opening Day
#
#
#
#
# PublicServan
# 47
# 公職
# ◎[公職] 今年5/1軍公教不放假
#
#
#
#
# Food
# 47
# 美食
# ◎美食板
#
#
#
#
# Audiophile
# 45
# 資訊
# ◎[喇音] 請詳閱置底板規公告
#
#
#
#
# Tennis
# 45
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
#
#
#
#
# BlueArchive
# 44
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
#
#
#
#
# ToS
# 44
# 轉珠
# ◎[神魔] 四乃森蒼紫
#
#
#
#
# MuscleBeach
# 44
# 美體
# ◎[健身] 發文前請務必詳閱板規
#
#
#
#
# tabletennis
# 43
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
#
#
#
#
# cat
# 42
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
#
#
#
#
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
#
#
#
#
# Badminton
# 40
# 羽球
# ◎[羽球版]
#
#
#
#
# cookclub
# 39
# 烹飪
# ◎歡迎分享手做美食
#
#
#
#
# Option
# 38
# 學術
# ◎[期權] 違規檢舉請至置底文
#
#
#
#
# Guardians
# 38
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
#
#
#
#
# DIABLO
# 36
# 線上
# ◎[暗黑] 暗黑2024年到來!
#
#
#
#
# PathofExile
# 35
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
#
#
#
#
# MakeUp
# 35
# 美容
# ◎[美妝]
#
#
#
#
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
#
#
#
#
# FAPL
# 34
# 聯賽
# ◎歡樂．三喵．足球
#
#
#
#
# H-GAME
# 33
# 綜合
# ◎H-GAME板
#
#
#
#
# Soft_Job
# 32
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
#
#
#
#
# Key_Mou_Pad
# 31
# 生活
# ◎[鍵鼠] 2024新年快樂
#
#
#
#
# MobilePay
# 31
# 理財
# ◎刷卡回饋問題請至信用卡板
#
#
#
#
# Road_Running
# 31
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
#
#
#
#
# WOW
# 31
# 線上
# ◎[WoW] 10.2.6 上線
#
#
#
#
# TaiwanDrama
# 31
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
#
#
#
#
# part-time
# 31
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
#
#
#
#
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
#
#
#
#
# nb-shopping
# 30
# 硬體
# ◎[筆電蝦]
#
#
#
#
# Railway
# 30
# 交通
# ◎[鐵道] 徵選板主
#
#
#
#
# Brand
# 30
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
#
#
#
#
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
#
#
#
#
# Taoyuan
# 30
# 桃園
# ◎[桃園]
#
#
#
#
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
#
#
#
#
# Digitalhome
# 30
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
#
#
#
#
# Insurance
# 29
# 理財
# ◎保險板-★徵業務、站內信★劣退
#
#
#
#
# ChangHua
# 28
# 彰化
# ◎[彰化]
#
#
#
#
# Loan
# 28
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
#
#
#
#
# FORMULA1
# 28
# 賽車
# ◎F1板 燈滅起跑!
#
#
#
#
# MRT
# 28
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
#
#
#
#
# TW_Entertain
# 28
# 綜藝
# ◎[台綜]
#
#
#
#
# KoreanPop
# 27
# 音樂
# ◎抵制買榜 抵制作弊，韓樂需要正義
#
#
#
#
# SuperBike
# 27
# 車車
# ◎PTT重機板 ~ 發買賣文請詳閱置底
#
#
#
#
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
# --------------------
# Gossiping
# 10412
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
# --------------------
# Gossiping
# --------------------
# 10412
# --------------------
# 綜合
# --------------------
# ◎[八卦] 違反板規一直往水桶痛點踩
# --------------------
# Stock
# 5072
# 學術
# ◎[股票] 地震來襲 請注意安全
# --------------------
# Stock
# --------------------
# 5072
# --------------------
# 學術
# --------------------
# ◎[股票] 地震來襲 請注意安全
# --------------------
# NBA
# 4189
# NBA.
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
# --------------------
# NBA
# --------------------
# 4189
# --------------------
# NBA.
# --------------------
# ◎[NBA] W3附加賽湖人晉級 勇士淘汰
# --------------------
# C_Chat
# 3588
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
# --------------------
# C_Chat
# --------------------
# 3588
# --------------------
# 閒談
# --------------------
# ◎[希洽] 五十嵐梨花生日快樂!!!
# --------------------
# Baseball
# 2034
# 棒球
# ◎[棒球] Baseball is life
# --------------------
# Baseball
# --------------------
# 2034
# --------------------
# 棒球
# --------------------
# ◎[棒球] Baseball is life
# --------------------
# HatePolitics
# 1368
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
# --------------------
# HatePolitics
# --------------------
# 1368
# --------------------
# Hate
# --------------------
# ◎[政黑] 開冷氣開到股票賺錢
# --------------------
# marriage
# 1230
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
# --------------------
# marriage
# --------------------
# 1230
# --------------------
# 婚姻
# --------------------
# ◎[婚姻] 歡迎光臨婚姻板
# --------------------
# Lifeismoney
# 920
# 省錢
# ◎推薦碼板規已修改，推文前請注意
# --------------------
# Lifeismoney
# --------------------
# 920
# --------------------
# 省錢
# --------------------
# ◎推薦碼板規已修改，推文前請注意
# --------------------
# KoreaStar
# 785
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
# --------------------
# KoreaStar
# --------------------
# 785
# --------------------
# 韓國
# --------------------
# ◎[韓星] 0413 HAPPY JIWOO DAY~
# --------------------
# LoL
# 775
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
# --------------------
# LoL
# --------------------
# 775
# --------------------
# 遊戲
# --------------------
# ◎[LoL] GEN達成首次LCK四連霸
# --------------------
# home-sale
# 720
# 房屋
# ◎[房版] 房屋買賣版
# --------------------
# home-sale
# --------------------
# 720
# --------------------
# 房屋
# --------------------
# ◎[房版] 房屋買賣版
# --------------------
# car
# 591
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
# --------------------
# car
# --------------------
# 591
# --------------------
# 車車
# --------------------
# ◎[汽車] 恭喜Pellaeon成為新版主
# --------------------
# basketballTW
# 553
# 籃球
# ◎[台籃]        例行賽
# --------------------
# basketballTW
# --------------------
# 553
# --------------------
# 籃球
# --------------------
# ◎[台籃]        例行賽
# --------------------
# sex
# 510
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
# --------------------
# sex
# --------------------
# 510
# --------------------
# 男女
# --------------------
# ◎[西斯] 不要輕易幫別人買蒜味麵包
# --------------------
# MobileComm
# 375
# 資訊
# ◎[通訊]
# --------------------
# MobileComm
# --------------------
# 375
# --------------------
# 資訊
# --------------------
# ◎[通訊]
# --------------------
# movie
# 359
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
# --------------------
# movie
# --------------------
# 359
# --------------------
# 綜合
# --------------------
# ◎[電影] 禁政治版規延續 注意置底
# --------------------
# Tech_Job
# 354
# 工作
# ◎[科技] 這裡是科技板
# --------------------
# Tech_Job
# --------------------
# 354
# --------------------
# 工作
# --------------------
# ◎[科技] 這裡是科技板
# --------------------
# Beauty
# 338
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
# --------------------
# Beauty
# --------------------
# 338
# --------------------
# 聊天
# --------------------
# ◎[表特] 貼AI圖 一律水桶+退文
# --------------------
# Japan_Travel
# 337
# 旅遊
# ◎感謝各位參與富士山票選
# --------------------
# Japan_Travel
# --------------------
# 337
# --------------------
# 旅遊
# --------------------
# ◎感謝各位參與富士山票選
# --------------------
# Military
# 303
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
# --------------------
# Military
# --------------------
# 303
# --------------------
# 軍事
# --------------------
# ◎[軍事]理性討論軍事 請詳閱板規
# --------------------
# BaseballXXXX
# 286
# ４Ｘ
# ◎[四叉] 禮物可以換JESS球衣
# --------------------
# BaseballXXXX
# --------------------
# 286
# --------------------
# ４Ｘ
# --------------------
# ◎[四叉] 禮物可以換JESS球衣
# --------------------
# PC_Shopping
# 283
# 硬體
# ◎[電蝦] intel 13 14代災情回報
# --------------------
# PC_Shopping
# --------------------
# 283
# --------------------
# 硬體
# --------------------
# ◎[電蝦] intel 13 14代災情回報
# --------------------
# PlayStation
# 281
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
# --------------------
# PlayStation
# --------------------
# 281
# --------------------
# 主機
# --------------------
# ◎[PS5] 4/26 STELLAR BLADE 劍星
# --------------------
# creditcard
# 268
# 理財
# ◎[卡板]
# --------------------
# creditcard
# --------------------
# 268
# --------------------
# 理財
# --------------------
# ◎[卡板]
# --------------------
# BabyMother
# 241
# 家庭
# ◎[寶寶] 記得打流感疫苗
# --------------------
# BabyMother
# --------------------
# 241
# --------------------
# 家庭
# --------------------
# ◎[寶寶] 記得打流感疫苗
# --------------------
# KoreaDrama
# 238
# 韓劇
# ◎[韓劇]
# --------------------
# KoreaDrama
# --------------------
# 238
# --------------------
# 韓劇
# --------------------
# ◎[韓劇]
# --------------------
# miHoYo
# 237
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
# --------------------
# miHoYo
# --------------------
# 237
# --------------------
# 米哈
# --------------------
# ◎[米哈遊] 原神動畫短片-燼中歌
# --------------------
# Marginalman
# 218
# 心情
# ◎[邊緣] どう足掻いても明日はない
# --------------------
# Marginalman
# --------------------
# 218
# --------------------
# 心情
# --------------------
# ◎[邊緣] どう足掻いても明日はない
# --------------------
# WomenTalk
# 205
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
# --------------------
# WomenTalk
# --------------------
# 205
# --------------------
# 聊天
# --------------------
# ◎[女孩]請小心餘震注意安全<(@o@)/
# --------------------
# TaichungBun
# 200
# 台中
# ◎[台中] 節約用水 節約用電
# --------------------
# TaichungBun
# --------------------
# 200
# --------------------
# 台中
# --------------------
# ◎[台中] 節約用水 節約用電
# --------------------
# Tainan
# 177
# 台南
# ◎[台南] 請詳閱交易文規範:)
# --------------------
# Tainan
# --------------------
# 177
# --------------------
# 台南
# --------------------
# ◎[台南] 請詳閱交易文規範:)
# --------------------
# SportLottery
# 176
# 博弈
# ◎[運彩] 運彩板
# --------------------
# SportLottery
# --------------------
# 176
# --------------------
# 博弈
# --------------------
# ◎[運彩] 運彩板
# --------------------
# G-S-WARRIORS
# 175
# W-PA
# ◎附加賽1，04.17_10:00，@ 國王
# --------------------
# G-S-WARRIORS
# --------------------
# 175
# --------------------
# W-PA
# --------------------
# ◎附加賽1，04.17_10:00，@ 國王
# --------------------
# Lakers
# 172
# W-PA
# ◎[Lakers] Los Angeles Lakers
# --------------------
# Lakers
# --------------------
# 172
# --------------------
# W-PA
# --------------------
# ◎[Lakers] Los Angeles Lakers
# --------------------
# japanavgirls
# 166
# 綜合
# ◎AV女優板 清新、優質,神人照格式
# --------------------
# japanavgirls
# --------------------
# 166
# --------------------
# 綜合
# --------------------
# ◎AV女優板 清新、優質,神人照格式
# --------------------
# Boy-Girl
# 166
# 心情
# ◎[男女] 水桶很滿 推文請三思
# --------------------
# Boy-Girl
# --------------------
# 166
# --------------------
# 心情
# --------------------
# ◎[男女] 水桶很滿 推文請三思
# --------------------
# Steam
# 165
# 平台
# ◎本板禁止買賣合購代購代刷
# --------------------
# Steam
# --------------------
# 165
# --------------------
# 平台
# --------------------
# ◎本板禁止買賣合購代購代刷
# --------------------
# Kaohsiung
# 150
# 高雄
# ◎高雄板
# --------------------
# Kaohsiung
# --------------------
# 150
# --------------------
# 高雄
# --------------------
# ◎高雄板
# --------------------
# AllTogether
# 148
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
# --------------------
# AllTogether
# --------------------
# 148
# --------------------
# 聯誼
# --------------------
# ◎[歐兔] 愛是一道光 如此美妙
# --------------------
# HardwareSale
# 141
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
# --------------------
# HardwareSale
# --------------------
# 141
# --------------------
# 買賣
# --------------------
# ◎[硬交] 欲售之物品須入手時間>1M
# --------------------
# Elephants
# 133
# CPBL
# ◎The Last Together 最後一齊
# --------------------
# Elephants
# --------------------
# 133
# --------------------
# CPBL
# --------------------
# ◎The Last Together 最後一齊
# --------------------
# marvel
# 132
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
# --------------------
# marvel
# --------------------
# 132
# --------------------
# 生二
# --------------------
# ◎[媽佛] 恐怖x外星人x預知夢?
# --------------------
# iOS
# 124
# 系統
# ◎[iOS] Apple®devices family
# --------------------
# iOS
# --------------------
# 124
# --------------------
# 系統
# --------------------
# ◎[iOS] Apple®devices family
# --------------------
# CFantasy
# 115
# 玄幻
# ◎[玄幻] 玄幻小說板
# --------------------
# CFantasy
# --------------------
# 115
# --------------------
# 玄幻
# --------------------
# ◎[玄幻] 玄幻小說板
# --------------------
# watch
# 114
# 購一
# ◎[錶板] Show me your Watch!
# --------------------
# watch
# --------------------
# 114
# --------------------
# 購一
# --------------------
# ◎[錶板] Show me your Watch!
# --------------------
# joke
# 112
# 娛樂
# ◎[就可] 貓貓可愛
# --------------------
# joke
# --------------------
# 112
# --------------------
# 娛樂
# --------------------
# ◎[就可] 貓貓可愛
# --------------------
# EAseries
# 110
# 歐美
# ◎[EA] 歐美影集版
# --------------------
# EAseries
# --------------------
# 110
# --------------------
# 歐美
# --------------------
# ◎[EA] 歐美影集版
# --------------------
# AC_In
# 108
# 閒談
# ◎[裏洽] 勤洗手
# --------------------
# AC_In
# --------------------
# 108
# --------------------
# 閒談
# --------------------
# ◎[裏洽] 勤洗手
# --------------------
# CVS
# 108
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
# --------------------
# CVS
# --------------------
# 108
# --------------------
# 資訊
# --------------------
# ◎[CVS] 超商店員a.k.a.superman
# --------------------
# e-shopping
# 105
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
# --------------------
# e-shopping
# --------------------
# 105
# --------------------
# 網購
# --------------------
# ◎[ＥＳ] 注意板規 遠離水桶
# --------------------
# Aviation
# 93
# 交通
# ◎[航空] 航空板 請先詳閱板規
# --------------------
# Aviation
# --------------------
# 93
# --------------------
# 交通
# --------------------
# ◎[航空] 航空板 請先詳閱板規
# --------------------
# NSwitch
# 92
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
# --------------------
# NSwitch
# --------------------
# 92
# --------------------
# 主機
# --------------------
# ◎[NS] 紙片瑪利歐 RPG 5/23
# --------------------
# ONE_PIECE
# 91
# 日本
# ◎[海賊王] 1111 「太陽之盾」
# --------------------
# ONE_PIECE
# --------------------
# 91
# --------------------
# 日本
# --------------------
# ◎[海賊王] 1111 「太陽之盾」
# --------------------
# PuzzleDragon
# 90
# 轉珠
# ◎[P＆D] 4/17(三) 07~19 改版維修
# --------------------
# PuzzleDragon
# --------------------
# 90
# --------------------
# 轉珠
# --------------------
# ◎[P＆D] 4/17(三) 07~19 改版維修
# --------------------
# biker
# 88
# 車車
# ◎[機車]殺人部長 王國才
# --------------------
# biker
# --------------------
# 88
# --------------------
# 車車
# --------------------
# ◎[機車]殺人部長 王國才
# --------------------
# CarShop
# 86
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
# --------------------
# CarShop
# --------------------
# 86
# --------------------
# 買賣
# --------------------
# ◎[汽車買賣] 看【置底公告】再發文
# --------------------
# Japandrama
# 84
# 日劇
# ◎[日劇] 土22 森本慎太郎
# --------------------
# Japandrama
# --------------------
# 84
# --------------------
# 日劇
# --------------------
# ◎[日劇] 土22 森本慎太郎
# --------------------
# MacShop
# 82
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
# --------------------
# MacShop
# --------------------
# 82
# --------------------
# 資訊
# --------------------
# ◎[麥蝦] 發文前請先詳閱板規
# --------------------
# BabyProducts
# 77
# 買賣
# ◎婦嬰用品販售版
# --------------------
# BabyProducts
# --------------------
# 77
# --------------------
# 買賣
# --------------------
# ◎婦嬰用品販售版
# --------------------
# KR_Entertain
# 77
# 綜藝
# ◎[韓綜] Show Me The 新板主!
# --------------------
# KR_Entertain
# --------------------
# 77
# --------------------
# 綜藝
# --------------------
# ◎[韓綜] Show Me The 新板主!
# --------------------
# Gamesale
# 76
# 綜合
# ◎[GS] 遊戲交易板
# --------------------
# Gamesale
# --------------------
# 76
# --------------------
# 綜合
# --------------------
# ◎[GS] 遊戲交易板
# --------------------
# mobilesales
# 75
# 資訊
# ◎[Mobile] 板規不看，水桶就來
# --------------------
# mobilesales
# --------------------
# 75
# --------------------
# 資訊
# --------------------
# ◎[Mobile] 板規不看，水桶就來
# --------------------
# BeautySalon
# 74
# 美容
# ◎[美保]
# --------------------
# BeautySalon
# --------------------
# 74
# --------------------
# 美容
# --------------------
# ◎[美保]
# --------------------
# China-Drama
# 70
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
# --------------------
# China-Drama
# --------------------
# 70
# --------------------
# 中劇
# --------------------
# ◎[中劇] 禁止攻擊演員個人及長相
# --------------------
# Hsinchu
# 69
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
# --------------------
# Hsinchu
# --------------------
# 69
# --------------------
# 新竹
# --------------------
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
# --------------------
# DSLR
# 68
# 攝影
# ◎[攝影] 2024
# --------------------
# DSLR
# --------------------
# 68
# --------------------
# 攝影
# --------------------
# ◎[攝影] 2024
# --------------------
# Drama-Ticket
# 67
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
# --------------------
# Drama-Ticket
# --------------------
# 67
# --------------------
# 舞臺
# --------------------
# ◎藝文票券轉售板 禁止徵票小心詐騙
# --------------------
# studyteacher
# 64
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
# --------------------
# studyteacher
# --------------------
# 64
# --------------------
# 教師
# --------------------
# ◎實習教師! 看板規!代理置底推!^0^
# --------------------
# Headphone
# 64
# 資訊
# ◎水桶機器人值勤中 O口O
# --------------------
# Headphone
# --------------------
# 64
# --------------------
# 資訊
# --------------------
# ◎水桶機器人值勤中 O口O
# --------------------
# DigiCurrency
# 62
# 資訊
# ◎[數位貨幣] 地動山搖
# --------------------
# DigiCurrency
# --------------------
# 62
# --------------------
# 資訊
# --------------------
# ◎[數位貨幣] 地動山搖
# --------------------
# e-coupon
# 60
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# --------------------
# e-coupon
# --------------------
# 60
# --------------------
# 理財
# --------------------
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# --------------------
# DC_SALE
# 59
# 攝影
# ◎標題錯就刪，版主不是客服
# --------------------
# DC_SALE
# --------------------
# 59
# --------------------
# 攝影
# --------------------
# ◎標題錯就刪，版主不是客服
# --------------------
# Salary
# 59
# 職場
# ◎[職場] 工作職場板
# --------------------
# Salary
# --------------------
# 59
# --------------------
# 職場
# --------------------
# ◎[職場] 工作職場板
# --------------------
# PokemonGO
# 59
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
# --------------------
# PokemonGO
# --------------------
# 59
# --------------------
# 抓寶
# --------------------
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
# --------------------
# Teacher
# 58
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
# --------------------
# Teacher
# --------------------
# 58
# --------------------
# 教師
# --------------------
# ◎[踢雀] 通往開學的倒數計時~~
# --------------------
# Lions
# 57
# CPBL
# ◎統一獅板
# --------------------
# Lions
# --------------------
# 57
# --------------------
# CPBL
# --------------------
# ◎統一獅板
# --------------------
# E-appliance
# 56
# 資訊
# ◎[家電] 發文請照規定發文
# --------------------
# E-appliance
# --------------------
# 56
# --------------------
# 資訊
# --------------------
# ◎[家電] 發文請照規定發文
# --------------------
# Hearthstone
# 53
# 線上
# ◎[爐石] 爐石十週年了!
# --------------------
# Hearthstone
# --------------------
# 53
# --------------------
# 線上
# --------------------
# ◎[爐石] 爐石十週年了!
# --------------------
# give
# 53
# 贈送
# ◎[贈送] 標題不合置底文規定  刪
# --------------------
# give
# --------------------
# 53
# --------------------
# 贈送
# --------------------
# ◎[贈送] 標題不合置底文規定  刪
# --------------------
# fastfood
# 50
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
# --------------------
# fastfood
# --------------------
# 50
# --------------------
# 美食
# --------------------
# ◎[速食] 慟！麥香魚起士只放半片
# --------------------
# Wanted
# 50
# 徵求
# ◎[汪踢] 速揪吃早餐
# --------------------
# Wanted
# --------------------
# 50
# --------------------
# 徵求
# --------------------
# ◎[汪踢] 速揪吃早餐
# --------------------
# Bank_Service
# 50
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
# --------------------
# Bank_Service
# --------------------
# 50
# --------------------
# 銀行
# --------------------
# ◎[銀行服務板] 發文要有50字滿3行
# --------------------
# YuanChuang
# 49
# 原創
# ◎[原創] 年度必看 徵文詳見置底
# --------------------
# YuanChuang
# --------------------
# 49
# --------------------
# 原創
# --------------------
# ◎[原創] 年度必看 徵文詳見置底
# --------------------
# MLB
# 48
# #MLB
# ◎2024 Opening Day
# --------------------
# MLB
# --------------------
# 48
# --------------------
# #MLB
# --------------------
# ◎2024 Opening Day
# --------------------
# PublicServan
# 47
# 公職
# ◎[公職] 今年5/1軍公教不放假
# --------------------
# PublicServan
# --------------------
# 47
# --------------------
# 公職
# --------------------
# ◎[公職] 今年5/1軍公教不放假
# --------------------
# Food
# 47
# 美食
# ◎美食板
# --------------------
# Food
# --------------------
# 47
# --------------------
# 美食
# --------------------
# ◎美食板
# --------------------
# Audiophile
# 45
# 資訊
# ◎[喇音] 請詳閱置底板規公告
# --------------------
# Audiophile
# --------------------
# 45
# --------------------
# 資訊
# --------------------
# ◎[喇音] 請詳閱置底板規公告
# --------------------
# Tennis
# 45
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
# --------------------
# Tennis
# --------------------
# 45
# --------------------
# 網球
# --------------------
# ◎[網球] Sinner #1 & Sabalenka #2
# --------------------
# BlueArchive
# 44
# 蔚藍
# ◎[蔚藍] にぎにぎとゆきゆきて
# --------------------
# BlueArchive
# --------------------
# 44
# --------------------
# 蔚藍
# --------------------
# ◎[蔚藍] にぎにぎとゆきゆきて
# --------------------
# ToS
# 44
# 轉珠
# ◎[神魔] 四乃森蒼紫
# --------------------
# ToS
# --------------------
# 44
# --------------------
# 轉珠
# --------------------
# ◎[神魔] 四乃森蒼紫
# --------------------
# MuscleBeach
# 44
# 美體
# ◎[健身] 發文前請務必詳閱板規
# --------------------
# MuscleBeach
# --------------------
# 44
# --------------------
# 美體
# --------------------
# ◎[健身] 發文前請務必詳閱板規
# --------------------
# tabletennis
# 43
# 桌球
# ◎21:20林昀儒-松島輝空 世界盃4/17
# --------------------
# tabletennis
# --------------------
# 43
# --------------------
# 桌球
# --------------------
# ◎21:20林昀儒-松島輝空 世界盃4/17
# --------------------
# cat
# 42
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
# --------------------
# cat
# --------------------
# 42
# --------------------
# 寵物
# --------------------
# ◎[喵板]禁止交易贈送徵求醫療用品
# --------------------
# Monkeys
# 41
# CPBL
# ◎樂天桃猿！徵選版主中
# --------------------
# Monkeys
# --------------------
# 41
# --------------------
# CPBL
# --------------------
# ◎樂天桃猿！徵選版主中
# --------------------
# Badminton
# 40
# 羽球
# ◎[羽球版]
# --------------------
# Badminton
# --------------------
# 40
# --------------------
# 羽球
# --------------------
# ◎[羽球版]
# --------------------
# cookclub
# 39
# 烹飪
# ◎歡迎分享手做美食
# --------------------
# cookclub
# --------------------
# 39
# --------------------
# 烹飪
# --------------------
# ◎歡迎分享手做美食
# --------------------
# Option
# 38
# 學術
# ◎[期權] 違規檢舉請至置底文
# --------------------
# Option
# --------------------
# 38
# --------------------
# 學術
# --------------------
# ◎[期權] 違規檢舉請至置底文
# --------------------
# Guardians
# 38
# CPBL
# ◎[悍將] 恭喜黃保羅中職生涯首勝
# --------------------
# Guardians
# --------------------
# 38
# --------------------
# CPBL
# --------------------
# ◎[悍將] 恭喜黃保羅中職生涯首勝
# --------------------
# DIABLO
# 36
# 線上
# ◎[暗黑] 暗黑2024年到來!
# --------------------
# DIABLO
# --------------------
# 36
# --------------------
# 線上
# --------------------
# ◎[暗黑] 暗黑2024年到來!
# --------------------
# PathofExile
# 35
# 線上
# ◎[PoE] 勤洗手戴口罩 保持社交距離
# --------------------
# PathofExile
# --------------------
# 35
# --------------------
# 線上
# --------------------
# ◎[PoE] 勤洗手戴口罩 保持社交距離
# --------------------
# MakeUp
# 35
# 美容
# ◎[美妝]
# --------------------
# MakeUp
# --------------------
# 35
# --------------------
# 美容
# --------------------
# ◎[美妝]
# --------------------
# StupidClown
# 35
# 經歷
# ◎ 哼哼哼哼
# --------------------
# StupidClown
# --------------------
# 35
# --------------------
# 經歷
# --------------------
# ◎ 哼哼哼哼
# --------------------
# FAPL
# 34
# 聯賽
# ◎歡樂．三喵．足球
# --------------------
# FAPL
# --------------------
# 34
# --------------------
# 聯賽
# --------------------
# ◎歡樂．三喵．足球
# --------------------
# H-GAME
# 33
# 綜合
# ◎H-GAME板
# --------------------
# H-GAME
# --------------------
# 33
# --------------------
# 綜合
# --------------------
# ◎H-GAME板
# --------------------
# Soft_Job
# 32
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
# --------------------
# Soft_Job
# --------------------
# 32
# --------------------
# 工作
# --------------------
# ◎[軟工] 成為全宇宙のNo.1吧
# --------------------
# Key_Mou_Pad
# 31
# 生活
# ◎[鍵鼠] 2024新年快樂
# --------------------
# Key_Mou_Pad
# --------------------
# 31
# --------------------
# 生活
# --------------------
# ◎[鍵鼠] 2024新年快樂
# --------------------
# MobilePay
# 31
# 理財
# ◎刷卡回饋問題請至信用卡板
# --------------------
# MobilePay
# --------------------
# 31
# --------------------
# 理財
# --------------------
# ◎刷卡回饋問題請至信用卡板
# --------------------
# Road_Running
# 31
# 跑步
# ◎跑步版-抱歉我拖累了路跑版水準
# --------------------
# Road_Running
# --------------------
# 31
# --------------------
# 跑步
# --------------------
# ◎跑步版-抱歉我拖累了路跑版水準
# --------------------
# WOW
# 31
# 線上
# ◎[WoW] 10.2.6 上線
# --------------------
# WOW
# --------------------
# 31
# --------------------
# 線上
# --------------------
# ◎[WoW] 10.2.6 上線
# --------------------
# TaiwanDrama
# 31
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
# --------------------
# TaiwanDrama
# --------------------
# 31
# --------------------
# 臺劇
# --------------------
# ◎[臺劇] 4/6 不夠善良的我們
# --------------------
# part-time
# 31
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
# --------------------
# part-time
# --------------------
# 31
# --------------------
# 求職
# --------------------
# ◎[打工] 112/01/01起 工資 176/hr
# --------------------
# GBF
# 31
# 扮演
# ◎[碧藍] 預兆解除後會有預兆
# --------------------
# GBF
# --------------------
# 31
# --------------------
# 扮演
# --------------------
# ◎[碧藍] 預兆解除後會有預兆
# --------------------
# nb-shopping
# 30
# 硬體
# ◎[筆電蝦]
# --------------------
# nb-shopping
# --------------------
# 30
# --------------------
# 硬體
# --------------------
# ◎[筆電蝦]
# --------------------
# Railway
# 30
# 交通
# ◎[鐵道] 徵選板主
# --------------------
# Railway
# --------------------
# 30
# --------------------
# 交通
# --------------------
# ◎[鐵道] 徵選板主
# --------------------
# Brand
# 30
# 資訊
# ◎   ＊* 布蘭德 細節的價值 ＊*
# --------------------
# Brand
# --------------------
# 30
# --------------------
# 資訊
# --------------------
# ◎   ＊* 布蘭德 細節的價值 ＊*
# --------------------
# points
# 30
# 旅遊
# ◎點數哩程板 交易文發文請看板規
# --------------------
# points
# --------------------
# 30
# --------------------
# 旅遊
# --------------------
# ◎點數哩程板 交易文發文請看板規
# --------------------
# Taoyuan
# 30
# 桃園
# ◎[桃園]
# --------------------
# Taoyuan
# --------------------
# 30
# --------------------
# 桃園
# --------------------
# ◎[桃園]
# --------------------
# facelift
# 30
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
# --------------------
# facelift
# --------------------
# 30
# --------------------
# 美容
# --------------------
# ◎[醫學美容版]　嚴禁揪團買賣廣告
# --------------------
# Digitalhome
# 30
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
# --------------------
# Digitalhome
# --------------------
# 30
# --------------------
# 數位
# --------------------
# ◎[電視] 2024 留意舊機出清撿便宜
# --------------------
# Insurance
# 29
# 理財
# ◎保險板-★徵業務、站內信★劣退
# --------------------
# Insurance
# --------------------
# 29
# --------------------
# 理財
# --------------------
# ◎保險板-★徵業務、站內信★劣退
# --------------------
# ChangHua
# 28
# 彰化
# ◎[彰化]
# --------------------
# ChangHua
# --------------------
# 28
# --------------------
# 彰化
# --------------------
# ◎[彰化]
# --------------------
# Loan
# 28
# 理財
# ◎【銀行貸款專板】房貸-信貸-車貸
# --------------------
# Loan
# --------------------
# 28
# --------------------
# 理財
# --------------------
# ◎【銀行貸款專板】房貸-信貸-車貸
# --------------------
# FORMULA1
# 28
# 賽車
# ◎F1板 燈滅起跑!
# --------------------
# FORMULA1
# --------------------
# 28
# --------------------
# 賽車
# --------------------
# ◎F1板 燈滅起跑!
# --------------------
# MRT
# 28
# 交通
# ◎[捷運] 環狀線板橋-中和仍停駛
# --------------------
# MRT
# --------------------
# 28
# --------------------
# 交通
# --------------------
# ◎[捷運] 環狀線板橋-中和仍停駛
# --------------------
# TW_Entertain
# 28
# 綜藝
# ◎[台綜]
# --------------------
# TW_Entertain
# --------------------
# 28
# --------------------
# 綜藝
# --------------------
# ◎[台綜]
# --------------------
# KoreanPop
# 27
# 音樂
# ◎抵制買榜 抵制作弊，韓樂需要正義
# --------------------
# KoreanPop
# --------------------
# 27
# --------------------
# 音樂
# --------------------
# ◎抵制買榜 抵制作弊，韓樂需要正義
# --------------------
# SuperBike
# 27
# 車車
# ◎PTT重機板 ~ 發買賣文請詳閱置底
# --------------------
# SuperBike
# --------------------
# 27
# --------------------
# 車車
# --------------------
# ◎PTT重機板 ~ 發買賣文請詳閱置底
# --------------------
# Examination
# 27
# 考試
# ◎[國考] 徵求上榜心得文
# --------------------
# Examination
# --------------------
# 27
# --------------------
# 考試
# --------------------
# ◎[國考] 徵求上榜心得文
# --------------------

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.ptt.cc/bbs/index.html'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # 選擇所有 class 為 'title' 的 div 標籤
    title_divs = soup.find_all('div.title')

    for title_div in title_divs:
        # 印出每個找到的標題文字（去除前後空白）
        print(title_div.text.strip())

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'https://www.ptt.cc/bbs/index.html'
response = requests.get(url)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # 選擇所有 class 為 'title' 的 div 標籤
    title_divs = soup.find_all('div.title')

    for title_div in title_divs:
        # 印出每個找到的標題文字（去除前後空白）
        print(title_div.text.strip())

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri May 29 00:38:13 2020
@author: ASUS
"""

# 導入 模組(module) 
import requests 
# 導入 BeautifulSoup 模組(module)：解析HTML 語法工具
import bs4

# 文章連結
URL = "https://www.ptt.cc/bbs/Gossiping/M.1590678355.A.246.html"
# 設定Header與Cookie
my_headers = {'cookie': 'over18=1;'}
# 發送get 請求 到 ptt 八卦版
response = requests.get(URL, headers = my_headers)


#  把網頁程式碼(HTML) 丟入 bs4模組分析
soup = bs4.BeautifulSoup(response.text,"html.parser")

## PTT 上方4個欄位
header = soup.find_all('span','article-meta-value')




## 查找所有html 元素 抓出內容
main_container = soup.find(id='main-container')
# 把所有文字都抓出來
all_text = main_container.text
# 把整個內容切割透過 "-- " 切割成2個陣列
pre_text = all_text.split('--')[0]
    
# 把每段文字 根據 '\n' 切開
texts = pre_text.split('\n')
# 如果你爬多篇你會發現 
contents = texts[2:]
# 內容
content = '\n'.join(contents)


# 顯示
print('作者：'+author)
print('看板：'+board)
print('標題：'+title)
print('日期：'+date)
print('內容：'+content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 32
#      30 main_container = soup.find(id='main-container')
#      31 # 把所有文字都抓出來
# ---> 32 all_text = main_container.text
#      33 # 把整個內容切割透過 "-- " 切割成2個陣列
#      34 pre_text = all_text.split('--')[0]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
pip install requests requests_html rich lxml PyQuery
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
response = requests.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
import requests

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !

# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')
for element in elements:
    # 提取資訊...
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
#   Cell In[1], line 1
#     pip install requests requests_html rich lxml PyQuery
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install requests requests_html rich lxml PyQueryimport requests
# !pip install requests_html
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
response = requests.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
import requests

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !

# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')
for element in elements:
    # 提取資訊...
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# ERROR: Could not find a version that satisfies the requirement PyQueryimport (from versions: none)
# ERROR: No matching distribution found for PyQueryimport
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (2.31.0)
# Collecting requests_html
#   Obtaining dependency information for requests_html from https://files.pythonhosted.org/packages/24/bc/a4380f09bab3a776182578ce6b2771e57259d0d4dbce178205779abdc347/requests_html-0.10.0-py3-none-any.whl.metadata
#   Downloading requests_html-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting rich
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: lxml in c:\users\qweas\anaconda3\lib\site-packages (4.9.3)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 8
#       6 response = requests.get(url)
#       7 print(response.text)
# ----> 8 from requests_html import HTMLSession
#      10 # 建立 HTML 會話
#      11 session = HTMLSession()
#
# ModuleNotFoundError: No module named 'requests_html'

# %%
# !pip install requests requests_html rich lxml PyQueryimport requests
# !pip install requests_html
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
response = requests.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
import requests

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !

# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')
for element in elements:
    # 提取資訊...
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (2.31.0)
# Collecting requests_html
#   Obtaining dependency information for requests_html from https://files.pythonhosted.org/packages/24/bc/a4380f09bab3a776182578ce6b2771e57259d0d4dbce178205779abdc347/requests_html-0.10.0-py3-none-any.whl.metadata
#   Using cached requests_html-0.10.0-py3-none-any.whl.metadata (15 kB)
# Collecting rich
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: lxml in c:\users\qweas\anaconda3\lib\site-packages (4.9.3)
# ERROR: Could not find a version that satisfies the requirement PyQueryimport (from versions: none)
# ERROR: No matching distribution found for PyQueryimport
# Collecting requests_html
#   Obtaining dependency information for requests_html from https://files.pythonhosted.org/packages/24/bc/a4380f09bab3a776182578ce6b2771e57259d0d4dbce178205779abdc347/requests_html-0.10.0-py3-none-any.whl.metadata
#   Using cached requests_html-0.10.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.31.0)
# Collecting pyquery (from requests_html)
#   Obtaining dependency information for pyquery from https://files.pythonhosted.org/packages/36/b7/f7ccf9e52e2817e1265d3719c600fa4ef33c07de4d5ef0ced3f43ab1cef2/pyquery-2.0.0-py3-none-any.whl.metadata
#   Downloading pyquery-2.0.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting fake-useragent (from requests_html)
#   Obtaining dependency information for fake-useragent from https://files.pythonhosted.org/packages/e4/99/60d8cf1b26938c2e0a57e232f7f15641dfcd6f8deda454d73e4145910ff6/fake_useragent-1.5.1-py3-none-any.whl.metadata
#   Downloading fake_useragent-1.5.1-py3-none-any.whl.metadata (15 kB)
# Collecting parse (from requests_html)
#   Obtaining dependency information for parse from https://files.pythonhosted.org/packages/ce/f0/30fe1494f1910ad3ea40639b13ac48cdb16a8600e8861cbfc2c560661ddf/parse-1.20.1-py2.py3-none-any.whl.metadata
#   Downloading parse-1.20.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting bs4 (from requests_html)
#   Obtaining dependency information for bs4 from https://files.pythonhosted.org/packages/51/bb/bf7aab772a159614954d84aa832c129624ba6c32faa559dfb200a534e50b/bs4-0.0.2-py2.py3-none-any.whl.metadata
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: w3lib in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Collecting pyppeteer>=0.0.14 (from requests_html)
#   Obtaining dependency information for pyppeteer>=0.0.14 from https://files.pythonhosted.org/packages/3d/ee/fb2757a38025421fd3844a0ed0a230b78c9c04a66355024436cf3005a70c/pyppeteer-2.0.0-py3-none-any.whl.metadata
#   Downloading pyppeteer-2.0.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (6.0.0)
# Collecting pyee<12.0.0,>=11.0.0 (from pyppeteer>=0.0.14->requests_html)
#   Obtaining dependency information for pyee<12.0.0,>=11.0.0 from https://files.pythonhosted.org/packages/16/cc/5cea8a0a0d3deb90b5a0d39ad1a6a1ccaa40a9ea86d793eb8a49d32a6ed0/pyee-11.1.0-py3-none-any.whl.metadata
#   Downloading pyee-11.1.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.16)
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests_html)
#   Obtaining dependency information for websockets<11.0,>=10.0 from https://files.pythonhosted.org/packages/27/bb/6327e8c7d4dd7d5b450b409a461be278968ce05c54da13da581ac87661db/websockets-10.4-cp311-cp311-win_amd64.whl.metadata
#   Downloading websockets-10.4-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\qweas\anaconda3\lib\site-packages (from bs4->requests_html) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.3)
# Collecting cssselect>=1.2.0 (from pyquery->requests_html)
#   Obtaining dependency information for cssselect>=1.2.0 from https://files.pythonhosted.org/packages/06/a9/2da08717a6862c48f1d61ef957a7bba171e7eefa6c0aa0ceb96a140c2a6b/cssselect-1.2.0-py2.py3-none-any.whl.metadata
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (3.4)
# Requirement already satisfied: six>=1.4.1 in c:\users\qweas\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\qweas\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.11.0)
# Requirement already satisfied: typing-extensions in c:\users\qweas\anaconda3\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests_html) (4.7.1)
# Requirement already satisfied: colorama in c:\users\qweas\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\qweas\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.4)
# Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Downloading pyppeteer-2.0.0-py3-none-any.whl (82 kB)
#    ---------------------------------------- 0.0/82.9 kB ? eta -:--:--
#    -------------- ------------------------- 30.7/82.9 kB 640.0 kB/s eta 0:00:01
#    ------------------- -------------------- 41.0/82.9 kB 653.6 kB/s eta 0:00:01
#    ------------------- -------------------- 41.0/82.9 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 71.7/82.9 kB 491.5 kB/s eta 0:00:01
#    ---------------------------------------- 82.9/82.9 kB 515.3 kB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Downloading parse-1.20.1-py2.py3-none-any.whl (20 kB)
# Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Downloading websockets-10.4-cp311-cp311-win_amd64.whl (101 kB)
#    ---------------------------------------- 0.0/101.4 kB ? eta -:--:--
#    ------------------------ --------------- 61.4/101.4 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 101.4/101.4 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: parse, fake-useragent, websockets, pyee, cssselect, pyquery, pyppeteer, bs4, requests_html
#   Attempting uninstall: cssselect
#     Found existing installation: cssselect 1.1.0
#     Uninstalling cssselect-1.1.0:
#       Successfully uninstalled cssselect-1.1.0
# Successfully installed bs4-0.0.2 cssselect-1.2.0 fake-useragent-1.5.1 parse-1.20.1 pyee-11.1.0 pyppeteer-2.0.0 pyquery-2.0.0 requests_html-0.10.0 websockets-10.4
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div class="bbs-screen bbs-content">
#     <div class="over18-notice">
#         <p>本網站已依網站內容分級規定處理</p>
#
#         <p>警告︰您即將進入之看板內容需滿十八歲方可瀏覽。</p>
#
#         <p>若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。</p>
#     </div>
# </div>
#
# <div class="bbs-screen bbs-content center clear">
#     <form action="/ask/over18" method="post">
#         <input type="hidden" name="from" value="/bbs/Gossiping/index.html">
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="yes" value="yes">我同意，我已年滿十八歲<br><small>進入</small></button>
#         </div>
#         <div class="over18-button-container">
#             <button class="btn-big" type="submit" name="no" value="no">未滿十八歲或不同意本條款<br><small>離開</small></button>
#         </div>
#     </form>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
#
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39198.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371323.A.102.html">[問卦] 遇到一樓隔壁住戶亂停車無法可管怎辦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ElvesDaniel</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%81%87%E5%88%B0%E4%B8%80%E6%A8%93%E9%9A%94%E5%A3%81%E4%BD%8F%E6%88%B6%E4%BA%82%E5%81%9C%E8%BB%8A%E7%84%A1%E6%B3%95%E5%8F%AF%E7%AE%A1%E6%80%8E%E8%BE%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AElvesDaniel">搜尋看板內 ElvesDaniel 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371325.A.B24.html">[問卦] 為何有些人睡覺會一直流口水??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">whiteadam</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%82%BA%E4%BD%95%E6%9C%89%E4%BA%9B%E4%BA%BA%E7%9D%A1%E8%A6%BA%E6%9C%83%E4%B8%80%E7%9B%B4%E6%B5%81%E5%8F%A3%E6%B0%B4%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Awhiteadam">搜尋看板內 whiteadam 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371349.A.4CC.html">[問卦] 怎樣？吵什麼吵啊？怎樣</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Aurora5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%80%8E%E6%A8%A3%EF%BC%9F%E5%90%B5%E4%BB%80%E9%BA%BC%E5%90%B5%E5%95%8A%EF%BC%9F%E6%80%8E%E6%A8%A3">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAurora5566">搜尋看板內 Aurora5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1699632792.A.2CB.html">[公告] 八卦板板規(2023.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">lwt501cx</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282023.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Alwt501cx">搜尋看板內 lwt501cx 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">99</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712286517.A.F21.html">[公告] ETtoday未確實查證警告，禁發記者陳韻如新聞</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;ETtoday%E6%9C%AA%E7%A2%BA%E5%AF%A6%E6%9F%A5%E8%AD%89%E8%AD%A6%E5%91%8A%EF%BC%8C%E7%A6%81%E7%99%BC%E8%A8%98%E8%80%85%E9%99%B3%E9%9F%BB%E5%A6%82%E6%96%B0%E8%81%9E">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712412585.A.D57.html">[協尋] 求助！ 朋友家人車禍行車紀錄</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">kingkong1105</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E6%B1%82%E5%8A%A9%EF%BC%81&#43;%E6%9C%8B%E5%8F%8B%E5%AE%B6%E4%BA%BA%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Akingkong1105">搜尋看板內 kingkong1105 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/06</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">25</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712662710.A.6A7.html">[協尋] 求助!家人車禍行車紀錄</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">derrick1680</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E6%B1%82%E5%8A%A9%21%E5%AE%B6%E4%BA%BA%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aderrick1680">搜尋看板內 derrick1680 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
# 推文數:
# 標記:
# 標題: [問卦] 遇到一樓隔壁住戶亂停車無法可管怎辦?
# 作者: ElvesDaniel
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371323.A.102.html
# ---
# 推文數:
# 標記:
# 標題: [問卦] 為何有些人睡覺會一直流口水??
# 作者: whiteadam
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371325.A.B24.html
# ---
# 推文數: 2
# 標記:
# 標題: [問卦] 怎樣？吵什麼吵啊？怎樣
# 作者: Aurora5566
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371349.A.4CC.html
# ---
# 推文數: 4
# 標記: !
# 標題: [公告] 八卦板板規(2023.11.11)
# 作者: lwt501cx
# 發文日期: 11/11
# 文章網址: /bbs/Gossiping/M.1699632792.A.2CB.html
# ---
# 推文數: 99
# 標記:
# 標題: [公告] ETtoday未確實查證警告，禁發記者陳韻如新聞
# 作者: ubcs
# 發文日期: 4/05
# 文章網址: /bbs/Gossiping/M.1712286517.A.F21.html
# ---
# 推文數: 19
# 標記:
# 標題: [協尋] 求助！ 朋友家人車禍行車紀錄
# 作者: kingkong1105
# 發文日期: 4/06
# 文章網址: /bbs/Gossiping/M.1712412585.A.D57.html
# ---
# 推文數: 25
# 標記:
# 標題: [協尋] 求助!家人車禍行車紀錄
# 作者: derrick1680
# 發文日期: 4/09
# 文章網址: /bbs/Gossiping/M.1712662710.A.6A7.html
# ---

# %%
# !pip install requests requests_html rich lxml PyQueryimport requests
# !pip install requests_html
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
import requests

url = 'https://www.ptt.cc/bbs/Gossiping/index.html'
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !

# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
print(response.text)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')
for element in elements:
    # 提取資訊...
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: requests_html in c:\users\qweas\anaconda3\lib\site-packages (0.10.0)
# Collecting rich
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: lxml in c:\users\qweas\anaconda3\lib\site-packages (4.9.3)
# ERROR: Could not find a version that satisfies the requirement PyQueryimport (from versions: none)
# ERROR: No matching distribution found for PyQueryimport
# Requirement already satisfied: requests_html in c:\users\qweas\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.31.0)
# Requirement already satisfied: pyquery in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: fake-useragent in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.5.1)
# Requirement already satisfied: parse in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.20.1)
# Requirement already satisfied: bs4 in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (0.0.2)
# Requirement already satisfied: w3lib in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (6.0.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (11.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\qweas\anaconda3\lib\site-packages (from bs4->requests_html) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyquery->requests_html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (3.4)
# Requirement already satisfied: six>=1.4.1 in c:\users\qweas\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\qweas\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.11.0)
# Requirement already satisfied: typing-extensions in c:\users\qweas\anaconda3\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests_html) (4.7.1)
# Requirement already satisfied: colorama in c:\users\qweas\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\qweas\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.4)
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-cls">
# 				<a class="btn selected" href="/bbs/hotboards.html">熱門看板</a>
#                 <a class="btn" href="/cls/1">分類看板</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="b-list-container action-bar-margin bbs-screen">
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gossiping/index.html">
#                 <div class="board-name">Gossiping</div>
#                 <div class="board-nuser"><span class="hl f4">9505</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[八卦] 違反板規一直往水桶痛點踩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Stock/index.html">
#                 <div class="board-name">Stock</div>
#                 <div class="board-nuser"><span class="hl f1">4814</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[股票] 地震來襲 請注意安全</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/C_Chat/index.html">
#                 <div class="board-name">C_Chat</div>
#                 <div class="board-nuser"><span class="hl f1">3700</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[希洽] 五十嵐梨花生日快樂!!!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Baseball/index.html">
#                 <div class="board-name">Baseball</div>
#                 <div class="board-nuser"><span class="hl f1">2949</span></div>
#                 <div class="board-class">棒球</div>
#                 <div class="board-title">&#9678;[棒球] 三地開魯閣囉!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NBA/index.html">
#                 <div class="board-name">NBA</div>
#                 <div class="board-nuser"><span class="hl f1">2404</span></div>
#                 <div class="board-class">NBA.</div>
#                 <div class="board-title">&#9678;[NBA] W4附加賽 熱火76 老鷹公牛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lifeismoney/index.html">
#                 <div class="board-name">Lifeismoney</div>
#                 <div class="board-nuser"><span class="hl">1827</span></div>
#                 <div class="board-class">省錢</div>
#                 <div class="board-title">&#9678;推薦碼板規已修改，推文前請注意</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marriage/index.html">
#                 <div class="board-name">marriage</div>
#                 <div class="board-nuser"><span class="hl">1580</span></div>
#                 <div class="board-class">婚姻</div>
#                 <div class="board-title">&#9678;[婚姻] 歡迎光臨婚姻板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaStar/index.html">
#                 <div class="board-name">KoreaStar</div>
#                 <div class="board-nuser"><span class="hl">1222</span></div>
#                 <div class="board-class">韓國</div>
#                 <div class="board-title">&#9678;[韓星] 0413 HAPPY JIWOO DAY~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HatePolitics/index.html">
#                 <div class="board-name">HatePolitics</div>
#                 <div class="board-nuser"><span class="hl">759</span></div>
#                 <div class="board-class">Hate</div>
#                 <div class="board-title">&#9678;[政黑] 開冷氣開到股票賺錢</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/LoL/index.html">
#                 <div class="board-name">LoL</div>
#                 <div class="board-nuser"><span class="hl">708</span></div>
#                 <div class="board-class">遊戲</div>
#                 <div class="board-title">&#9678;[LoL] GEN達成首次LCK四連霸</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/sex/index.html">
#                 <div class="board-name">sex</div>
#                 <div class="board-nuser"><span class="hl">647</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[西斯] 不要輕易幫別人買蒜味麵包</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/car/index.html">
#                 <div class="board-name">car</div>
#                 <div class="board-nuser"><span class="hl">630</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[汽車] 恭喜Pellaeon成為新版主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/home-sale/index.html">
#                 <div class="board-name">home-sale</div>
#                 <div class="board-nuser"><span class="hl">628</span></div>
#                 <div class="board-class">房屋</div>
#                 <div class="board-title">&#9678;[房版] 房屋買賣版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/basketballTW/index.html">
#                 <div class="board-name">basketballTW</div>
#                 <div class="board-nuser"><span class="hl">529</span></div>
#                 <div class="board-class">籃球</div>
#                 <div class="board-title">&#9678;[台籃]        例行賽</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Military/index.html">
#                 <div class="board-name">Military</div>
#                 <div class="board-nuser"><span class="hl">513</span></div>
#                 <div class="board-class">軍事</div>
#                 <div class="board-title">&#9678;[軍事]理性討論軍事 請詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Beauty/index.html">
#                 <div class="board-name">Beauty</div>
#                 <div class="board-nuser"><span class="hl">499</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[表特] 貼AI圖 一律水桶+退文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tech_Job/index.html">
#                 <div class="board-name">Tech_Job</div>
#                 <div class="board-nuser"><span class="hl">452</span></div>
#                 <div class="board-class">工作</div>
#                 <div class="board-title">&#9678;[科技] 這裡是科技板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japan_Travel/index.html">
#                 <div class="board-name">Japan_Travel</div>
#                 <div class="board-nuser"><span class="hl">402</span></div>
#                 <div class="board-class">旅遊</div>
#                 <div class="board-title">&#9678;感謝各位參與富士山票選</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaDrama/index.html">
#                 <div class="board-name">KoreaDrama</div>
#                 <div class="board-nuser"><span class="hl">367</span></div>
#                 <div class="board-class">韓劇</div>
#                 <div class="board-title">&#9678;[韓劇]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SportLottery/index.html">
#                 <div class="board-name">SportLottery</div>
#                 <div class="board-nuser"><span class="hl">362</span></div>
#                 <div class="board-class">博弈</div>
#                 <div class="board-title">&#9678;[運彩] 運彩板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PC_Shopping/index.html">
#                 <div class="board-name">PC_Shopping</div>
#                 <div class="board-nuser"><span class="hl">359</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[電蝦] intel 13 14代災情回報</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/movie/index.html">
#                 <div class="board-name">movie</div>
#                 <div class="board-nuser"><span class="hl">356</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[電影] 禁政治版規延續 注意置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BaseballXXXX/index.html">
#                 <div class="board-name">BaseballXXXX</div>
#                 <div class="board-nuser"><span class="hl">333</span></div>
#                 <div class="board-class">４Ｘ</div>
#                 <div class="board-title">&#9678;[四叉] 工程師身上有乖乖很合理的</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MobileComm/index.html">
#                 <div class="board-name">MobileComm</div>
#                 <div class="board-nuser"><span class="hl">332</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[通訊] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/japanavgirls/index.html">
#                 <div class="board-name">japanavgirls</div>
#                 <div class="board-nuser"><span class="hl">292</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;AV女優板 清新、優質,神人照格式</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyMother/index.html">
#                 <div class="board-name">BabyMother</div>
#                 <div class="board-nuser"><span class="hl">259</span></div>
#                 <div class="board-class">家庭</div>
#                 <div class="board-title">&#9678;[寶寶] 記得打流感疫苗</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PlayStation/index.html">
#                 <div class="board-name">PlayStation</div>
#                 <div class="board-nuser"><span class="hl">248</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[PS5] 4/26 STELLAR BLADE 劍星</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Elephants/index.html">
#                 <div class="board-name">Elephants</div>
#                 <div class="board-nuser"><span class="hl">245</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;The Last Together 最後一齊</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/creditcard/index.html">
#                 <div class="board-name">creditcard</div>
#                 <div class="board-nuser"><span class="hl">242</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;[卡板] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AllTogether/index.html">
#                 <div class="board-name">AllTogether</div>
#                 <div class="board-nuser"><span class="hl">232</span></div>
#                 <div class="board-class">聯誼</div>
#                 <div class="board-title">&#9678;[歐兔] 愛是一道光 如此美妙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WomenTalk/index.html">
#                 <div class="board-name">WomenTalk</div>
#                 <div class="board-nuser"><span class="hl">228</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[女孩]請小心餘震注意安全&lt;(@o@)/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Marginalman/index.html">
#                 <div class="board-name">Marginalman</div>
#                 <div class="board-nuser"><span class="hl">226</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[邊緣] どう足掻いても明日はない</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/miHoYo/index.html">
#                 <div class="board-name">miHoYo</div>
#                 <div class="board-nuser"><span class="hl">206</span></div>
#                 <div class="board-class">米哈</div>
#                 <div class="board-title">&#9678;[米哈遊] 原神動畫短片-燼中歌</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Boy-Girl/index.html">
#                 <div class="board-name">Boy-Girl</div>
#                 <div class="board-nuser"><span class="hl">202</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[男女] 水桶很滿 推文請三思</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Steam/index.html">
#                 <div class="board-name">Steam</div>
#                 <div class="board-nuser"><span class="hl">195</span></div>
#                 <div class="board-class">平台</div>
#                 <div class="board-title">&#9678;本板禁止買賣合購代購代刷</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tainan/index.html">
#                 <div class="board-name">Tainan</div>
#                 <div class="board-nuser"><span class="hl">187</span></div>
#                 <div class="board-class">台南</div>
#                 <div class="board-title">&#9678;[台南] 請詳閱交易文規範:)</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Kaohsiung/index.html">
#                 <div class="board-name">Kaohsiung</div>
#                 <div class="board-nuser"><span class="hl">185</span></div>
#                 <div class="board-class">高雄</div>
#                 <div class="board-title">&#9678;行車紀錄器-4/15AM9:00路竹區</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DigiCurrency/index.html">
#                 <div class="board-name">DigiCurrency</div>
#                 <div class="board-nuser"><span class="hl">182</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[數位貨幣] 地動山搖</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lions/index.html">
#                 <div class="board-name">Lions</div>
#                 <div class="board-nuser"><span class="hl">171</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;統一獅板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaichungBun/index.html">
#                 <div class="board-name">TaichungBun</div>
#                 <div class="board-nuser"><span class="hl">170</span></div>
#                 <div class="board-class">台中</div>
#                 <div class="board-title">&#9678;[台中] 節約用水 節約用電</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NSwitch/index.html">
#                 <div class="board-name">NSwitch</div>
#                 <div class="board-nuser"><span class="hl">160</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[NS] 紙片瑪利歐 RPG 5/23</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/iOS/index.html">
#                 <div class="board-name">iOS</div>
#                 <div class="board-nuser"><span class="hl">152</span></div>
#                 <div class="board-class">系統</div>
#                 <div class="board-title">&#9678;[iOS] Apple®devices family</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CVS/index.html">
#                 <div class="board-name">CVS</div>
#                 <div class="board-nuser"><span class="hl">152</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[CVS] 超商店員a.k.a.superman</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HardwareSale/index.html">
#                 <div class="board-name">HardwareSale</div>
#                 <div class="board-nuser"><span class="hl">147</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[硬交] 欲售之物品須入手時間&gt;1M</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CFantasy/index.html">
#                 <div class="board-name">CFantasy</div>
#                 <div class="board-nuser"><span class="hl">144</span></div>
#                 <div class="board-class">玄幻</div>
#                 <div class="board-title">&#9678;[玄幻] 玄幻小說板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japandrama/index.html">
#                 <div class="board-name">Japandrama</div>
#                 <div class="board-nuser"><span class="hl">141</span></div>
#                 <div class="board-class">日劇</div>
#                 <div class="board-title">&#9678;[日劇] 土22 森本慎太郎</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tennis/index.html">
#                 <div class="board-name">Tennis</div>
#                 <div class="board-nuser"><span class="hl">140</span></div>
#                 <div class="board-class">網球</div>
#                 <div class="board-title">&#9678;[網球] Sinner #1 &amp; Sabalenka #2</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/watch/index.html">
#                 <div class="board-name">watch</div>
#                 <div class="board-nuser"><span class="hl">137</span></div>
#                 <div class="board-class">購一</div>
#                 <div class="board-title">&#9678;[錶板] Show me your Watch!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Aviation/index.html">
#                 <div class="board-name">Aviation</div>
#                 <div class="board-nuser"><span class="hl">131</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[航空] 航空板 請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/joke/index.html">
#                 <div class="board-name">joke</div>
#                 <div class="board-nuser"><span class="hl">123</span></div>
#                 <div class="board-class">娛樂</div>
#                 <div class="board-title">&#9678;[就可] 貓貓可愛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AC_In/index.html">
#                 <div class="board-name">AC_In</div>
#                 <div class="board-nuser"><span class="hl">121</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[裏洽] 勤洗手</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lakers/index.html">
#                 <div class="board-name">Lakers</div>
#                 <div class="board-nuser"><span class="hl">118</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;[Lakers] Los Angeles Lakers</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/EAseries/index.html">
#                 <div class="board-name">EAseries</div>
#                 <div class="board-nuser"><span class="hl">117</span></div>
#                 <div class="board-class">歐美</div>
#                 <div class="board-title">&#9678;[EA] 歐美影集版 </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ONE_PIECE/index.html">
#                 <div class="board-name">ONE_PIECE</div>
#                 <div class="board-nuser"><span class="hl">117</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;[海賊王] 1111 「太陽之盾」</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PuzzleDragon/index.html">
#                 <div class="board-name">PuzzleDragon</div>
#                 <div class="board-nuser"><span class="hl">116</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[P＆D] 鋼彈系列 合作復刻</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CarShop/index.html">
#                 <div class="board-name">CarShop</div>
#                 <div class="board-nuser"><span class="hl">112</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[汽車買賣] 看【置底公告】再發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/mobilesales/index.html">
#                 <div class="board-name">mobilesales</div>
#                 <div class="board-nuser"><span class="hl">108</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[Mobile] 板規不看，水桶就來</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/biker/index.html">
#                 <div class="board-name">biker</div>
#                 <div class="board-nuser"><span class="hl">102</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[機車]殺人部長 王國才</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-shopping/index.html">
#                 <div class="board-name">e-shopping</div>
#                 <div class="board-nuser"><span class="hl">99</span></div>
#                 <div class="board-class">網購</div>
#                 <div class="board-title">&#9678;[ＥＳ] 注意板規 遠離水桶</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/China-Drama/index.html">
#                 <div class="board-name">China-Drama</div>
#                 <div class="board-nuser"><span class="hl">98</span></div>
#                 <div class="board-class">中劇</div>
#                 <div class="board-title">&#9678;[中劇] 禁止攻擊演員個人及長相</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MacShop/index.html">
#                 <div class="board-name">MacShop</div>
#                 <div class="board-nuser"><span class="hl">95</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[麥蝦] 發文前請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gamesale/index.html">
#                 <div class="board-name">Gamesale</div>
#                 <div class="board-nuser"><span class="hl">90</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[GS] 遊戲交易板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BeautySalon/index.html">
#                 <div class="board-name">BeautySalon</div>
#                 <div class="board-nuser"><span class="hl">90</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美保]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Headphone/index.html">
#                 <div class="board-name">Headphone</div>
#                 <div class="board-nuser"><span class="hl">87</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;水桶機器人值勤中 O口O</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/YuanChuang/index.html">
#                 <div class="board-name">YuanChuang</div>
#                 <div class="board-nuser"><span class="hl">86</span></div>
#                 <div class="board-class">原創</div>
#                 <div class="board-title">&#9678;[原創] 年度必看 徵文詳見置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KR_Entertain/index.html">
#                 <div class="board-name">KR_Entertain</div>
#                 <div class="board-nuser"><span class="hl">82</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[韓綜] Show Me The 新板主!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Drama-Ticket/index.html">
#                 <div class="board-name">Drama-Ticket</div>
#                 <div class="board-nuser"><span class="hl">82</span></div>
#                 <div class="board-class">舞臺</div>
#                 <div class="board-title">&#9678;藝文票券轉售板 禁止徵票小心詐騙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Bank_Service/index.html">
#                 <div class="board-name">Bank_Service</div>
#                 <div class="board-nuser"><span class="hl">81</span></div>
#                 <div class="board-class">銀行</div>
#                 <div class="board-title">&#9678;[銀行服務板] 發文要有50字滿3行</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hsinchu/index.html">
#                 <div class="board-name">Hsinchu</div>
#                 <div class="board-nuser"><span class="hl">79</span></div>
#                 <div class="board-class">新竹</div>
#                 <div class="board-title">&#9678;[新竹] 新板主要來了~~\⊙▽⊙/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PokemonGO/index.html">
#                 <div class="board-name">PokemonGO</div>
#                 <div class="board-nuser"><span class="hl">79</span></div>
#                 <div class="board-class">抓寶</div>
#                 <div class="board-title">&#9678;[PMGO] 4/20:喇叭芽社群日14~17點</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marvel/index.html">
#                 <div class="board-name">marvel</div>
#                 <div class="board-nuser"><span class="hl">72</span></div>
#                 <div class="board-class">生二</div>
#                 <div class="board-title">&#9678;[媽佛] 恐怖x外星人x預知夢?</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DC_SALE/index.html">
#                 <div class="board-name">DC_SALE</div>
#                 <div class="board-nuser"><span class="hl">71</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;標題錯就刪，版主不是客服</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DSLR/index.html">
#                 <div class="board-name">DSLR</div>
#                 <div class="board-nuser"><span class="hl">71</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;[攝影] 2024</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MuscleBeach/index.html">
#                 <div class="board-name">MuscleBeach</div>
#                 <div class="board-nuser"><span class="hl">71</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[健身] 發文前請務必詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Monkeys/index.html">
#                 <div class="board-name">Monkeys</div>
#                 <div class="board-nuser"><span class="hl">71</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;樂天桃猿！徵選版主中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/G-S-WARRIORS/index.html">
#                 <div class="board-name">G-S-WARRIORS</div>
#                 <div class="board-nuser"><span class="hl">70</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;我勇諸位好好休息，展望下賽季。</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/studyteacher/index.html">
#                 <div class="board-name">studyteacher</div>
#                 <div class="board-nuser"><span class="hl">67</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;實習教師! 看板規!代理置底推!^0^</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MakeUp/index.html">
#                 <div class="board-name">MakeUp</div>
#                 <div class="board-nuser"><span class="hl">66</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美妝]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/E-appliance/index.html">
#                 <div class="board-name">E-appliance</div>
#                 <div class="board-nuser"><span class="hl">64</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[家電] 發文請照規定發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SuperBike/index.html">
#                 <div class="board-name">SuperBike</div>
#                 <div class="board-nuser"><span class="hl">63</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;PTT重機板 ~ 發買賣文請詳閱置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Salary/index.html">
#                 <div class="board-name">Salary</div>
#                 <div class="board-nuser"><span class="hl">58</span></div>
#                 <div class="board-class">職場</div>
#                 <div class="board-title">&#9678;[職場] 工作職場板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Wanted/index.html">
#                 <div class="board-name">Wanted</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">徵求</div>
#                 <div class="board-title">&#9678;[汪踢] 速揪吃早餐</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Guardians/index.html">
#                 <div class="board-name">Guardians</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;[悍將] 滿壘狂攻！夠悍</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PublicServan/index.html">
#                 <div class="board-name">PublicServan</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">公職</div>
#                 <div class="board-title">&#9678;[公職] 今年5/1軍公教不放假</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ToS/index.html">
#                 <div class="board-name">ToS</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[神魔] 四乃森蒼紫</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/part-time/index.html">
#                 <div class="board-name">part-time</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;[打工] 112/01/01起 工資 176/hr</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaiwanDrama/index.html">
#                 <div class="board-name">TaiwanDrama</div>
#                 <div class="board-nuser"><span class="hl">54</span></div>
#                 <div class="board-class">臺劇</div>
#                 <div class="board-title">&#9678;[臺劇] 4/6 不夠善良的我們</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hearthstone/index.html">
#                 <div class="board-name">Hearthstone</div>
#                 <div class="board-nuser"><span class="hl">53</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[爐石] 爐石十週年了! </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-coupon/index.html">
#                 <div class="board-name">e-coupon</div>
#                 <div class="board-nuser"><span class="hl">51</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;e-coupon板規#1XewXRTO/#1Zxrj5t0</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cat/index.html">
#                 <div class="board-name">cat</div>
#                 <div class="board-nuser"><span class="hl f3">50</span></div>
#                 <div class="board-class">寵物</div>
#                 <div class="board-title">&#9678;[喵板]禁止交易贈送徵求醫療用品</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Food/index.html">
#                 <div class="board-name">Food</div>
#                 <div class="board-nuser"><span class="hl f3">49</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;美食板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreanPop/index.html">
#                 <div class="board-name">KoreanPop</div>
#                 <div class="board-nuser"><span class="hl f3">45</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;抵制買榜 抵制作弊，韓樂需要正義</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FAPL/index.html">
#                 <div class="board-name">FAPL</div>
#                 <div class="board-nuser"><span class="hl f3">45</span></div>
#                 <div class="board-class">聯賽</div>
#                 <div class="board-title">&#9678;歡樂．三喵．足球</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/give/index.html">
#                 <div class="board-name">give</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">贈送</div>
#                 <div class="board-title">&#9678;[贈送] 標題不合置底文規定  刪</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Brand/index.html">
#                 <div class="board-name">Brand</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;   ＊* 布蘭德 細節的價值 ＊*</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Teacher/index.html">
#                 <div class="board-name">Teacher</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;[踢雀] 通往開學的倒數計時~~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DIABLO/index.html">
#                 <div class="board-name">DIABLO</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[暗黑] 暗黑2024年到來!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/StupidClown/index.html">
#                 <div class="board-name">StupidClown</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">經歷</div>
#                 <div class="board-title">&#9678; 哼哼哼哼</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SakaTalk/index.html">
#                 <div class="board-name">SakaTalk</div>
#                 <div class="board-nuser"><span class="hl f3">43</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;坂道閒聊板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Audiophile/index.html">
#                 <div class="board-name">Audiophile</div>
#                 <div class="board-nuser"><span class="hl f3">43</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[喇音] 請詳閱置底板規公告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hip-Hop/index.html">
#                 <div class="board-name">Hip-Hop</div>
#                 <div class="board-nuser"><span class="hl f3">43</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;[嘻哈] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/fastfood/index.html">
#                 <div class="board-name">fastfood</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;[速食] 慟！麥香魚起士只放半片</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Option/index.html">
#                 <div class="board-name">Option</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[期權] 違規檢舉請至置底文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FORMULA1/index.html">
#                 <div class="board-name">FORMULA1</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">賽車</div>
#                 <div class="board-title">&#9678;F1板 燈滅起跑!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WOW/index.html">
#                 <div class="board-name">WOW</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[WoW] 10.2.6 上線</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cookclub/index.html">
#                 <div class="board-name">cookclub</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">烹飪</div>
#                 <div class="board-title">&#9678;歡迎分享手做美食</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MLB/index.html">
#                 <div class="board-name">MLB</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">#MLB</div>
#                 <div class="board-title">&#9678;2024 Opening Day</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyProducts/index.html">
#                 <div class="board-name">BabyProducts</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;婦嬰用品販售版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/H-GAME/index.html">
#                 <div class="board-name">H-GAME</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;H-GAME板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Digitalhome/index.html">
#                 <div class="board-name">Digitalhome</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">數位</div>
#                 <div class="board-title">&#9678;[電視] 2024 留意舊機出清撿便宜</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Badminton/index.html">
#                 <div class="board-name">Badminton</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">羽球</div>
#                 <div class="board-title">&#9678;[羽球版]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BlueArchive/index.html">
#                 <div class="board-name">BlueArchive</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">蔚藍</div>
#                 <div class="board-title">&#9678;[蔚藍] 0420生放送，樂透開盤中</div>
#             </a>
# ...
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TW_Entertain/index.html">
#                 <div class="board-name">TW_Entertain</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[台綜] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/tabletennis/index.html">
#                 <div class="board-name">tabletennis</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">桌球</div>
#                 <div class="board-title">&#9678;13:30林昀儒-張禹珍 世界盃4/18</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gov_owned/index.html">
#                 <div class="board-name">Gov_owned</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">國營</div>
#                 <div class="board-title">&#9678;[國營] 徵求上榜心得文</div>
#             </a>
#         </div>
#
# 	</div>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Gossiping 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-dir">
# 				<a class="btn selected" href="/bbs/Gossiping/index.html">看板</a>
# 				<a class="btn" href="/man/Gossiping/index.html">精華區</a>
# 			</div>
# 			<div class="btn-group btn-group-paging">
# 				<a class="btn wide" href="/bbs/Gossiping/index1.html">最舊</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index39198.html">&lsaquo; 上頁</a>
# 				<a class="btn wide disabled">下頁 &rsaquo;</a>
# 				<a class="btn wide" href="/bbs/Gossiping/index.html">最新</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="r-list-container action-bar-margin bbs-screen">
# 		<div class="search-bar">
# 			<form type="get" action="search" id="search-bar">
# 				<input class="query" type="text" name="q" value="" placeholder="搜尋文章&#x22ef;">
# 			</form>
# 		</div>
#
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371323.A.102.html">[問卦] 遇到一樓隔壁住戶亂停車無法可管怎辦?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ElvesDaniel</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E9%81%87%E5%88%B0%E4%B8%80%E6%A8%93%E9%9A%94%E5%A3%81%E4%BD%8F%E6%88%B6%E4%BA%82%E5%81%9C%E8%BB%8A%E7%84%A1%E6%B3%95%E5%8F%AF%E7%AE%A1%E6%80%8E%E8%BE%A6%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AElvesDaniel">搜尋看板內 ElvesDaniel 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371325.A.B24.html">[問卦] 為何有些人睡覺會一直流口水??</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">whiteadam</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%82%BA%E4%BD%95%E6%9C%89%E4%BA%9B%E4%BA%BA%E7%9D%A1%E8%A6%BA%E6%9C%83%E4%B8%80%E7%9B%B4%E6%B5%81%E5%8F%A3%E6%B0%B4%3F%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Awhiteadam">搜尋看板內 whiteadam 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">2</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371349.A.4CC.html">[問卦] 怎樣？吵什麼吵啊？怎樣</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">Aurora5566</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%80%8E%E6%A8%A3%EF%BC%9F%E5%90%B5%E4%BB%80%E9%BA%BC%E5%90%B5%E5%95%8A%EF%BC%9F%E6%80%8E%E6%A8%A3">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3AAurora5566">搜尋看板內 Aurora5566 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371477.A.D90.html">[問卦] 喜劇社怎一堆宅男?</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">arsl400</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E5%96%9C%E5%8A%87%E7%A4%BE%E6%80%8E%E4%B8%80%E5%A0%86%E5%AE%85%E7%94%B7%3F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aarsl400">搜尋看板內 arsl400 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371544.A.A80.html">Re: [問卦] 罵iwin 跟挺統神的是不是同一批人？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">d8888</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E7%BD%B5iwin&#43;%E8%B7%9F%E6%8C%BA%E7%B5%B1%E7%A5%9E%E7%9A%84%E6%98%AF%E4%B8%8D%E6%98%AF%E5%90%8C%E4%B8%80%E6%89%B9%E4%BA%BA%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Ad8888">搜尋看板內 d8888 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371557.A.15B.html">[新聞] 潛入台積電女廁偷窺 他辯稱「想變性、了解</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">rsreason</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D&#43;%E6%BD%9B%E5%85%A5%E5%8F%B0%E7%A9%8D%E9%9B%BB%E5%A5%B3%E5%BB%81%E5%81%B7%E7%AA%BA&#43;%E4%BB%96%E8%BE%AF%E7%A8%B1%E3%80%8C%E6%83%B3%E8%AE%8A%E6%80%A7%E3%80%81%E4%BA%86%E8%A7%A3">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Arsreason">搜尋看板內 rsreason 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">1</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1713371565.A.02B.html">[問卦] 月薪33K的工作 辭職要考慮多久？</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">zhxl</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%95%8F%E5%8D%A6%5D&#43;%E6%9C%88%E8%96%AA33K%E7%9A%84%E5%B7%A5%E4%BD%9C&#43;%E8%BE%AD%E8%81%B7%E8%A6%81%E8%80%83%E6%85%AE%E5%A4%9A%E4%B9%85%EF%BC%9F">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Azhxl">搜尋看板內 zhxl 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/18</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#         <div class="r-list-sep"></div>
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f2">4</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1699632792.A.2CB.html">[公告] 八卦板板規(2023.11.11)</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">lwt501cx</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;%E5%85%AB%E5%8D%A6%E6%9D%BF%E6%9D%BF%E8%A6%8F%282023.11.11%29">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Alwt501cx">搜尋看板內 lwt501cx 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date">11/11</div>
# 				<div class="mark">!</div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">99</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712286517.A.F21.html">[公告] ETtoday未確實查證警告，禁發記者陳韻如新聞</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">ubcs</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D&#43;ETtoday%E6%9C%AA%E7%A2%BA%E5%AF%A6%E6%9F%A5%E8%AD%89%E8%AD%A6%E5%91%8A%EF%BC%8C%E7%A6%81%E7%99%BC%E8%A8%98%E8%80%85%E9%99%B3%E9%9F%BB%E5%A6%82%E6%96%B0%E8%81%9E">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aubcs">搜尋看板內 ubcs 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/05</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">19</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712412585.A.D57.html">[協尋] 求助！ 朋友家人車禍行車紀錄</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">kingkong1105</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E6%B1%82%E5%8A%A9%EF%BC%81&#43;%E6%9C%8B%E5%8F%8B%E5%AE%B6%E4%BA%BA%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Akingkong1105">搜尋看板內 kingkong1105 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/06</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">25</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Gossiping/M.1712662710.A.6A7.html">[協尋] 求助!家人車禍行車紀錄</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">derrick1680</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Gossiping/search?q=thread%3A%5B%E5%8D%94%E5%B0%8B%5D&#43;%E6%B1%82%E5%8A%A9%21%E5%AE%B6%E4%BA%BA%E8%BB%8A%E7%A6%8D%E8%A1%8C%E8%BB%8A%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Gossiping/search?q=author%3Aderrick1680">搜尋看板內 derrick1680 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 4/09</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>
# 推文數:
# 標記:
# 標題: [問卦] 遇到一樓隔壁住戶亂停車無法可管怎辦?
# 作者: ElvesDaniel
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371323.A.102.html
# ---
# 推文數:
# 標記:
# 標題: [問卦] 為何有些人睡覺會一直流口水??
# 作者: whiteadam
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371325.A.B24.html
# ---
# 推文數: 2
# 標記:
# 標題: [問卦] 怎樣？吵什麼吵啊？怎樣
# 作者: Aurora5566
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371349.A.4CC.html
# ---
# 推文數:
# 標記:
# 標題: [問卦] 喜劇社怎一堆宅男?
# 作者: arsl400
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371477.A.D90.html
# ---
# 推文數:
# 標記:
# 標題: Re: [問卦] 罵iwin 跟挺統神的是不是同一批人？
# 作者: d8888
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371544.A.A80.html
# ---
# 推文數: 1
# 標記:
# 標題: [新聞] 潛入台積電女廁偷窺 他辯稱「想變性、了解
# 作者: rsreason
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371557.A.15B.html
# ---
# 推文數: 4
# 標記:
# 標題: [問卦] 月薪33K的工作 辭職要考慮多久？
# 作者: zhxl
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371565.A.02B.html
# ---
# 推文數:
# 標記:
# 標題: [問卦] 為啥周瑜要說服孫權抗魏寶吳?
# 作者: abc12812
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371629.A.6D4.html
# ---
# 推文數:
# 標記:
# 標題: [問卦] 第一個肛交的人是怎麼想到的？
# 作者: engineer1
# 發文日期: 4/18
# 文章網址: /bbs/Gossiping/M.1713371636.A.479.html
# ---
# 推文數: 4
# 標記: !
# 標題: [公告] 八卦板板規(2023.11.11)
# 作者: lwt501cx
# 發文日期: 11/11
# 文章網址: /bbs/Gossiping/M.1699632792.A.2CB.html
# ---
# 推文數: 99
# 標記:
# 標題: [公告] ETtoday未確實查證警告，禁發記者陳韻如新聞
# 作者: ubcs
# 發文日期: 4/05
# 文章網址: /bbs/Gossiping/M.1712286517.A.F21.html
# ---
# 推文數: 19
# 標記:
# 標題: [協尋] 求助！ 朋友家人車禍行車紀錄
# 作者: kingkong1105
# 發文日期: 4/06
# 文章網址: /bbs/Gossiping/M.1712412585.A.D57.html
# ---
# 推文數: 25
# 標記:
# 標題: [協尋] 求助!家人車禍行車紀錄
# 作者: derrick1680
# 發文日期: 4/09
# 文章網址: /bbs/Gossiping/M.1712662710.A.6A7.html
# ---

# %%
# !pip install requests requests_html rich lxml PyQueryimport requests
# !pip install requests_html
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
import requests

url = 'https://www.ptt.cc/bbs/hotboards.html'
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !

# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
session.cookies.set('over18', '1')  # 向網站回答滿 18 歲了 !
# 發送 HTTP GET 請求並獲取網頁內容
response = session.get(url)

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')
for element in elements:
    # 提取資訊...
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: requests_html in c:\users\qweas\anaconda3\lib\site-packages (0.10.0)
# Collecting rich
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: lxml in c:\users\qweas\anaconda3\lib\site-packages (4.9.3)
# ERROR: Could not find a version that satisfies the requirement PyQueryimport (from versions: none)
# ERROR: No matching distribution found for PyQueryimport
# Requirement already satisfied: requests_html in c:\users\qweas\anaconda3\lib\site-packages (0.10.0)
# Requirement already satisfied: requests in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.31.0)
# Requirement already satisfied: pyquery in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: fake-useragent in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.5.1)
# Requirement already satisfied: parse in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.20.1)
# Requirement already satisfied: bs4 in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (0.0.2)
# Requirement already satisfied: w3lib in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (1.21.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in c:\users\qweas\anaconda3\lib\site-packages (from requests_html) (2.0.0)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: certifi>=2023 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (2023.7.22)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (6.0.0)
# Requirement already satisfied: pyee<12.0.0,>=11.0.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (11.1.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (4.65.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (1.26.16)
# Requirement already satisfied: websockets<11.0,>=10.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyppeteer>=0.0.14->requests_html) (10.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\qweas\anaconda3\lib\site-packages (from bs4->requests_html) (4.12.2)
# Requirement already satisfied: lxml>=2.1 in c:\users\qweas\anaconda3\lib\site-packages (from pyquery->requests_html) (4.9.3)
# Requirement already satisfied: cssselect>=1.2.0 in c:\users\qweas\anaconda3\lib\site-packages (from pyquery->requests_html) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\qweas\anaconda3\lib\site-packages (from requests->requests_html) (3.4)
# Requirement already satisfied: six>=1.4.1 in c:\users\qweas\anaconda3\lib\site-packages (from w3lib->requests_html) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\qweas\anaconda3\lib\site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.11.0)
# Requirement already satisfied: typing-extensions in c:\users\qweas\anaconda3\lib\site-packages (from pyee<12.0.0,>=11.0.0->pyppeteer>=0.0.14->requests_html) (4.7.1)
# Requirement already satisfied: colorama in c:\users\qweas\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.42.1->pyppeteer>=0.0.14->requests_html) (0.4.6)
# Requirement already satisfied: soupsieve>1.2 in c:\users\qweas\anaconda3\lib\site-packages (from beautifulsoup4->bs4->requests_html) (2.4)

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
elements = response.html.find('div.r-ent')
for element in elements:
import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-cls">
# 				<a class="btn selected" href="/bbs/hotboards.html">熱門看板</a>
#                 <a class="btn" href="/cls/1">分類看板</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="b-list-container action-bar-margin bbs-screen">
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gossiping/index.html">
#                 <div class="board-name">Gossiping</div>
#                 <div class="board-nuser"><span class="hl f4">9117</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[八卦] 違反板規一直往水桶痛點踩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Stock/index.html">
#                 <div class="board-name">Stock</div>
#                 <div class="board-nuser"><span class="hl f1">4721</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[股票] 地震來襲 請注意安全</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/C_Chat/index.html">
#                 <div class="board-name">C_Chat</div>
#                 <div class="board-nuser"><span class="hl f1">3600</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[希洽] 五十嵐梨花生日快樂!!!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Baseball/index.html">
#                 <div class="board-name">Baseball</div>
#                 <div class="board-nuser"><span class="hl f1">2718</span></div>
#                 <div class="board-class">棒球</div>
#                 <div class="board-title">&#9678;[棒球] 三地開魯閣囉!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NBA/index.html">
#                 <div class="board-name">NBA</div>
#                 <div class="board-nuser"><span class="hl f1">2365</span></div>
#                 <div class="board-class">NBA.</div>
#                 <div class="board-title">&#9678;[NBA] W4附加賽 熱火76 老鷹公牛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lifeismoney/index.html">
#                 <div class="board-name">Lifeismoney</div>
#                 <div class="board-nuser"><span class="hl">1629</span></div>
#                 <div class="board-class">省錢</div>
#                 <div class="board-title">&#9678;推薦碼板規已修改，推文前請注意</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marriage/index.html">
#                 <div class="board-name">marriage</div>
#                 <div class="board-nuser"><span class="hl">1449</span></div>
#                 <div class="board-class">婚姻</div>
#                 <div class="board-title">&#9678;[婚姻] 歡迎光臨婚姻板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaStar/index.html">
#                 <div class="board-name">KoreaStar</div>
#                 <div class="board-nuser"><span class="hl">1147</span></div>
#                 <div class="board-class">韓國</div>
#                 <div class="board-title">&#9678;[韓星] 0413 HAPPY JIWOO DAY~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HatePolitics/index.html">
#                 <div class="board-name">HatePolitics</div>
#                 <div class="board-nuser"><span class="hl">729</span></div>
#                 <div class="board-class">Hate</div>
#                 <div class="board-title">&#9678;[政黑] 開冷氣開到股票賺錢</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/LoL/index.html">
#                 <div class="board-name">LoL</div>
#                 <div class="board-nuser"><span class="hl">690</span></div>
#                 <div class="board-class">遊戲</div>
#                 <div class="board-title">&#9678;[LoL] GEN達成首次LCK四連霸</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/sex/index.html">
#                 <div class="board-name">sex</div>
#                 <div class="board-nuser"><span class="hl">663</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[西斯] 不要輕易幫別人買蒜味麵包</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/car/index.html">
#                 <div class="board-name">car</div>
#                 <div class="board-nuser"><span class="hl">596</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[汽車] 恭喜Pellaeon成為新版主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/home-sale/index.html">
#                 <div class="board-name">home-sale</div>
#                 <div class="board-nuser"><span class="hl">573</span></div>
#                 <div class="board-class">房屋</div>
#                 <div class="board-title">&#9678;[房版] 房屋買賣版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/basketballTW/index.html">
#                 <div class="board-name">basketballTW</div>
#                 <div class="board-nuser"><span class="hl">520</span></div>
#                 <div class="board-class">籃球</div>
#                 <div class="board-title">&#9678;[台籃]        例行賽</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Beauty/index.html">
#                 <div class="board-name">Beauty</div>
#                 <div class="board-nuser"><span class="hl">487</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[表特] 貼AI圖 一律水桶+退文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Military/index.html">
#                 <div class="board-name">Military</div>
#                 <div class="board-nuser"><span class="hl">461</span></div>
#                 <div class="board-class">軍事</div>
#                 <div class="board-title">&#9678;[軍事]理性討論軍事 請詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tech_Job/index.html">
#                 <div class="board-name">Tech_Job</div>
#                 <div class="board-nuser"><span class="hl">417</span></div>
#                 <div class="board-class">工作</div>
#                 <div class="board-title">&#9678;[科技] 這裡是科技板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japan_Travel/index.html">
#                 <div class="board-name">Japan_Travel</div>
#                 <div class="board-nuser"><span class="hl">372</span></div>
#                 <div class="board-class">旅遊</div>
#                 <div class="board-title">&#9678;感謝各位參與富士山票選</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/movie/index.html">
#                 <div class="board-name">movie</div>
#                 <div class="board-nuser"><span class="hl">359</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[電影] 禁政治版規延續 注意置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaDrama/index.html">
#                 <div class="board-name">KoreaDrama</div>
#                 <div class="board-nuser"><span class="hl">349</span></div>
#                 <div class="board-class">韓劇</div>
#                 <div class="board-title">&#9678;[韓劇]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SportLottery/index.html">
#                 <div class="board-name">SportLottery</div>
#                 <div class="board-nuser"><span class="hl">338</span></div>
#                 <div class="board-class">博弈</div>
#                 <div class="board-title">&#9678;[運彩] 運彩板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PC_Shopping/index.html">
#                 <div class="board-name">PC_Shopping</div>
#                 <div class="board-nuser"><span class="hl">328</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[電蝦] intel 13 14代災情回報</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MobileComm/index.html">
#                 <div class="board-name">MobileComm</div>
#                 <div class="board-nuser"><span class="hl">319</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[通訊] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BaseballXXXX/index.html">
#                 <div class="board-name">BaseballXXXX</div>
#                 <div class="board-nuser"><span class="hl">306</span></div>
#                 <div class="board-class">４Ｘ</div>
#                 <div class="board-title">&#9678;[四叉] 工程師身上有乖乖很合理的</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/japanavgirls/index.html">
#                 <div class="board-name">japanavgirls</div>
#                 <div class="board-nuser"><span class="hl">284</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;AV女優板 清新、優質,神人照格式</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Marginalman/index.html">
#                 <div class="board-name">Marginalman</div>
#                 <div class="board-nuser"><span class="hl">251</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[邊緣] どう足掻いても明日はない</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/creditcard/index.html">
#                 <div class="board-name">creditcard</div>
#                 <div class="board-nuser"><span class="hl">244</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;[卡板] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyMother/index.html">
#                 <div class="board-name">BabyMother</div>
#                 <div class="board-nuser"><span class="hl">232</span></div>
#                 <div class="board-class">家庭</div>
#                 <div class="board-title">&#9678;[寶寶] 記得打流感疫苗</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Elephants/index.html">
#                 <div class="board-name">Elephants</div>
#                 <div class="board-nuser"><span class="hl">232</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;The Last Together 最後一齊</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PlayStation/index.html">
#                 <div class="board-name">PlayStation</div>
#                 <div class="board-nuser"><span class="hl">229</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[PS5] 4/26 STELLAR BLADE 劍星</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WomenTalk/index.html">
#                 <div class="board-name">WomenTalk</div>
#                 <div class="board-nuser"><span class="hl">216</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[女孩]請小心餘震注意安全&lt;(@o@)/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AllTogether/index.html">
#                 <div class="board-name">AllTogether</div>
#                 <div class="board-nuser"><span class="hl">203</span></div>
#                 <div class="board-class">聯誼</div>
#                 <div class="board-title">&#9678;[歐兔] 愛是一道光 如此美妙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/miHoYo/index.html">
#                 <div class="board-name">miHoYo</div>
#                 <div class="board-nuser"><span class="hl">201</span></div>
#                 <div class="board-class">米哈</div>
#                 <div class="board-title">&#9678;[米哈遊] 原神動畫短片-燼中歌</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Boy-Girl/index.html">
#                 <div class="board-name">Boy-Girl</div>
#                 <div class="board-nuser"><span class="hl">183</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[男女] 水桶很滿 推文請三思</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Steam/index.html">
#                 <div class="board-name">Steam</div>
#                 <div class="board-nuser"><span class="hl">181</span></div>
#                 <div class="board-class">平台</div>
#                 <div class="board-title">&#9678;本板禁止買賣合購代購代刷</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Kaohsiung/index.html">
#                 <div class="board-name">Kaohsiung</div>
#                 <div class="board-nuser"><span class="hl">166</span></div>
#                 <div class="board-class">高雄</div>
#                 <div class="board-title">&#9678;行車紀錄器-4/15AM9:00路竹區</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tainan/index.html">
#                 <div class="board-name">Tainan</div>
#                 <div class="board-nuser"><span class="hl">164</span></div>
#                 <div class="board-class">台南</div>
#                 <div class="board-title">&#9678;[台南] 請詳閱交易文規範:)</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DigiCurrency/index.html">
#                 <div class="board-name">DigiCurrency</div>
#                 <div class="board-nuser"><span class="hl">162</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[數位貨幣] 地動山搖</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HardwareSale/index.html">
#                 <div class="board-name">HardwareSale</div>
#                 <div class="board-nuser"><span class="hl">157</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[硬交] 欲售之物品須入手時間&gt;1M</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NSwitch/index.html">
#                 <div class="board-name">NSwitch</div>
#                 <div class="board-nuser"><span class="hl">153</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[NS] 紙片瑪利歐 RPG 5/23</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaichungBun/index.html">
#                 <div class="board-name">TaichungBun</div>
#                 <div class="board-nuser"><span class="hl">146</span></div>
#                 <div class="board-class">台中</div>
#                 <div class="board-title">&#9678;[台中] 節約用水 節約用電</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lions/index.html">
#                 <div class="board-name">Lions</div>
#                 <div class="board-nuser"><span class="hl">146</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;統一獅板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/iOS/index.html">
#                 <div class="board-name">iOS</div>
#                 <div class="board-nuser"><span class="hl">140</span></div>
#                 <div class="board-class">系統</div>
#                 <div class="board-title">&#9678;[iOS] Apple®devices family</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CVS/index.html">
#                 <div class="board-name">CVS</div>
#                 <div class="board-nuser"><span class="hl">133</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[CVS] 超商店員a.k.a.superman</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AC_In/index.html">
#                 <div class="board-name">AC_In</div>
#                 <div class="board-nuser"><span class="hl">129</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[裏洽] 勤洗手</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tennis/index.html">
#                 <div class="board-name">Tennis</div>
#                 <div class="board-nuser"><span class="hl">128</span></div>
#                 <div class="board-class">網球</div>
#                 <div class="board-title">&#9678;[網球] Sinner #1 &amp; Sabalenka #2</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Aviation/index.html">
#                 <div class="board-name">Aviation</div>
#                 <div class="board-nuser"><span class="hl">124</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[航空] 航空板 請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/watch/index.html">
#                 <div class="board-name">watch</div>
#                 <div class="board-nuser"><span class="hl">123</span></div>
#                 <div class="board-class">購一</div>
#                 <div class="board-title">&#9678;[錶板] Show me your Watch!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japandrama/index.html">
#                 <div class="board-name">Japandrama</div>
#                 <div class="board-nuser"><span class="hl">123</span></div>
#                 <div class="board-class">日劇</div>
#                 <div class="board-title">&#9678;[日劇] 土22 森本慎太郎</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CFantasy/index.html">
#                 <div class="board-name">CFantasy</div>
#                 <div class="board-nuser"><span class="hl">121</span></div>
#                 <div class="board-class">玄幻</div>
#                 <div class="board-title">&#9678;[玄幻] 玄幻小說板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lakers/index.html">
#                 <div class="board-name">Lakers</div>
#                 <div class="board-nuser"><span class="hl">116</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;[Lakers] Los Angeles Lakers</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/EAseries/index.html">
#                 <div class="board-name">EAseries</div>
#                 <div class="board-nuser"><span class="hl">114</span></div>
#                 <div class="board-class">歐美</div>
#                 <div class="board-title">&#9678;[EA] 歐美影集版 </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/biker/index.html">
#                 <div class="board-name">biker</div>
#                 <div class="board-nuser"><span class="hl">112</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[機車]殺人部長 王國才</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/joke/index.html">
#                 <div class="board-name">joke</div>
#                 <div class="board-nuser"><span class="hl">109</span></div>
#                 <div class="board-class">娛樂</div>
#                 <div class="board-title">&#9678;[就可] 貓貓可愛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/mobilesales/index.html">
#                 <div class="board-name">mobilesales</div>
#                 <div class="board-nuser"><span class="hl">106</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[Mobile] 板規不看，水桶就來</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/China-Drama/index.html">
#                 <div class="board-name">China-Drama</div>
#                 <div class="board-nuser"><span class="hl">100</span></div>
#                 <div class="board-class">中劇</div>
#                 <div class="board-title">&#9678;[中劇] 禁止攻擊演員個人及長相</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MacShop/index.html">
#                 <div class="board-name">MacShop</div>
#                 <div class="board-nuser"><span class="hl">100</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[麥蝦] 發文前請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CarShop/index.html">
#                 <div class="board-name">CarShop</div>
#                 <div class="board-nuser"><span class="hl">99</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[汽車買賣] 看【置底公告】再發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ONE_PIECE/index.html">
#                 <div class="board-name">ONE_PIECE</div>
#                 <div class="board-nuser"><span class="hl">97</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;[海賊王] 1111 「太陽之盾」</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BeautySalon/index.html">
#                 <div class="board-name">BeautySalon</div>
#                 <div class="board-nuser"><span class="hl">95</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美保]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Headphone/index.html">
#                 <div class="board-name">Headphone</div>
#                 <div class="board-nuser"><span class="hl">91</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;水桶機器人值勤中 O口O</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-shopping/index.html">
#                 <div class="board-name">e-shopping</div>
#                 <div class="board-nuser"><span class="hl">91</span></div>
#                 <div class="board-class">網購</div>
#                 <div class="board-title">&#9678;[ＥＳ] 注意板規 遠離水桶</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PuzzleDragon/index.html">
#                 <div class="board-name">PuzzleDragon</div>
#                 <div class="board-nuser"><span class="hl">90</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[P＆D] 鋼彈系列 合作復刻</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gamesale/index.html">
#                 <div class="board-name">Gamesale</div>
#                 <div class="board-nuser"><span class="hl">82</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[GS] 遊戲交易板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marvel/index.html">
#                 <div class="board-name">marvel</div>
#                 <div class="board-nuser"><span class="hl">82</span></div>
#                 <div class="board-class">生二</div>
#                 <div class="board-title">&#9678;[媽佛] 恐怖x外星人x預知夢?</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DSLR/index.html">
#                 <div class="board-name">DSLR</div>
#                 <div class="board-nuser"><span class="hl">81</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;[攝影] 2024</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Bank_Service/index.html">
#                 <div class="board-name">Bank_Service</div>
#                 <div class="board-nuser"><span class="hl">80</span></div>
#                 <div class="board-class">銀行</div>
#                 <div class="board-title">&#9678;[銀行服務板] 發文要有50字滿3行</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KR_Entertain/index.html">
#                 <div class="board-name">KR_Entertain</div>
#                 <div class="board-nuser"><span class="hl">78</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[韓綜] Show Me The 新板主!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hsinchu/index.html">
#                 <div class="board-name">Hsinchu</div>
#                 <div class="board-nuser"><span class="hl">78</span></div>
#                 <div class="board-class">新竹</div>
#                 <div class="board-title">&#9678;[新竹] 新板主要來了~~\⊙▽⊙/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/YuanChuang/index.html">
#                 <div class="board-name">YuanChuang</div>
#                 <div class="board-nuser"><span class="hl">76</span></div>
#                 <div class="board-class">原創</div>
#                 <div class="board-title">&#9678;[原創] 年度必看 徵文詳見置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DC_SALE/index.html">
#                 <div class="board-name">DC_SALE</div>
#                 <div class="board-nuser"><span class="hl">73</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;標題錯就刪，版主不是客服</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Monkeys/index.html">
#                 <div class="board-name">Monkeys</div>
#                 <div class="board-nuser"><span class="hl">69</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;樂天桃猿！徵選版主中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Drama-Ticket/index.html">
#                 <div class="board-name">Drama-Ticket</div>
#                 <div class="board-nuser"><span class="hl">66</span></div>
#                 <div class="board-class">舞臺</div>
#                 <div class="board-title">&#9678;藝文票券轉售板 禁止徵票小心詐騙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/studyteacher/index.html">
#                 <div class="board-name">studyteacher</div>
#                 <div class="board-nuser"><span class="hl">65</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;實習教師! 看板規!代理置底推!^0^</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Guardians/index.html">
#                 <div class="board-name">Guardians</div>
#                 <div class="board-nuser"><span class="hl">63</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;[悍將] 滿壘狂攻！夠悍</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/E-appliance/index.html">
#                 <div class="board-name">E-appliance</div>
#                 <div class="board-nuser"><span class="hl">61</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[家電] 發文請照規定發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PokemonGO/index.html">
#                 <div class="board-name">PokemonGO</div>
#                 <div class="board-nuser"><span class="hl">61</span></div>
#                 <div class="board-class">抓寶</div>
#                 <div class="board-title">&#9678;[PMGO] 4/20:喇叭芽社群日14~17點</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/G-S-WARRIORS/index.html">
#                 <div class="board-name">G-S-WARRIORS</div>
#                 <div class="board-nuser"><span class="hl">60</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;我勇諸位好好休息，展望下賽季。</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MakeUp/index.html">
#                 <div class="board-name">MakeUp</div>
#                 <div class="board-nuser"><span class="hl">60</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美妝]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Wanted/index.html">
#                 <div class="board-name">Wanted</div>
#                 <div class="board-nuser"><span class="hl">59</span></div>
#                 <div class="board-class">徵求</div>
#                 <div class="board-title">&#9678;[汪踢] 速揪吃早餐</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Salary/index.html">
#                 <div class="board-name">Salary</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">職場</div>
#                 <div class="board-title">&#9678;[職場] 工作職場板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-coupon/index.html">
#                 <div class="board-name">e-coupon</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;e-coupon板規#1XewXRTO/#1Zxrj5t0</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FORMULA1/index.html">
#                 <div class="board-name">FORMULA1</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">賽車</div>
#                 <div class="board-title">&#9678;F1板 燈滅起跑!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MuscleBeach/index.html">
#                 <div class="board-name">MuscleBeach</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[健身] 發文前請務必詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hearthstone/index.html">
#                 <div class="board-name">Hearthstone</div>
#                 <div class="board-nuser"><span class="hl">54</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[爐石] 爐石十週年了! </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/fastfood/index.html">
#                 <div class="board-name">fastfood</div>
#                 <div class="board-nuser"><span class="hl">54</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;[速食] 慟！麥香魚起士只放半片</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ToS/index.html">
#                 <div class="board-name">ToS</div>
#                 <div class="board-nuser"><span class="hl">53</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[神魔] 四乃森蒼紫</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaiwanDrama/index.html">
#                 <div class="board-name">TaiwanDrama</div>
#                 <div class="board-nuser"><span class="hl f3">50</span></div>
#                 <div class="board-class">臺劇</div>
#                 <div class="board-title">&#9678;[臺劇] 4/6 不夠善良的我們</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PublicServan/index.html">
#                 <div class="board-name">PublicServan</div>
#                 <div class="board-nuser"><span class="hl f3">49</span></div>
#                 <div class="board-class">公職</div>
#                 <div class="board-title">&#9678;[公職] 今年5/1軍公教不放假</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Option/index.html">
#                 <div class="board-name">Option</div>
#                 <div class="board-nuser"><span class="hl f3">49</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[期權] 違規檢舉請至置底文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SuperBike/index.html">
#                 <div class="board-name">SuperBike</div>
#                 <div class="board-nuser"><span class="hl f3">49</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;PTT重機板 ~ 發買賣文請詳閱置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SakaTalk/index.html">
#                 <div class="board-name">SakaTalk</div>
#                 <div class="board-nuser"><span class="hl f3">48</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;坂道閒聊板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MLB/index.html">
#                 <div class="board-name">MLB</div>
#                 <div class="board-nuser"><span class="hl f3">48</span></div>
#                 <div class="board-class">#MLB</div>
#                 <div class="board-title">&#9678;2024 Opening Day</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Brand/index.html">
#                 <div class="board-name">Brand</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;   ＊* 布蘭德 細節的價值 ＊*</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FAPL/index.html">
#                 <div class="board-name">FAPL</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">聯賽</div>
#                 <div class="board-title">&#9678;歡樂．三喵．足球</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreanPop/index.html">
#                 <div class="board-name">KoreanPop</div>
#                 <div class="board-nuser"><span class="hl f3">46</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;抵制買榜 抵制作弊，韓樂需要正義</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cat/index.html">
#                 <div class="board-name">cat</div>
#                 <div class="board-nuser"><span class="hl f3">46</span></div>
#                 <div class="board-class">寵物</div>
#                 <div class="board-title">&#9678;[喵板]禁止交易贈送徵求醫療用品</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DIABLO/index.html">
#                 <div class="board-name">DIABLO</div>
#                 <div class="board-nuser"><span class="hl f3">45</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[暗黑] 暗黑2024年到來!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Food/index.html">
#                 <div class="board-name">Food</div>
#                 <div class="board-nuser"><span class="hl f3">45</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;美食板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WOW/index.html">
#                 <div class="board-name">WOW</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[WoW] 10.2.6 上線</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Coffee/index.html">
#                 <div class="board-name">Coffee</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">咖啡</div>
#                 <div class="board-title">&#9678;咖啡 秋意漸濃</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/give/index.html">
#                 <div class="board-name">give</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">贈送</div>
#                 <div class="board-title">&#9678;[贈送] 標題不合置底文規定  刪</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/StupidClown/index.html">
#                 <div class="board-name">StupidClown</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">經歷</div>
#                 <div class="board-title">&#9678; 哼哼哼哼</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Taoyuan/index.html">
#                 <div class="board-name">Taoyuan</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">桃園</div>
#                 <div class="board-title">&#9678;[桃園] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/part-time/index.html">
#                 <div class="board-name">part-time</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;[打工] 112/01/01起 工資 176/hr</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cookclub/index.html">
#                 <div class="board-name">cookclub</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">烹飪</div>
#                 <div class="board-title">&#9678;歡迎分享手做美食</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Badminton/index.html">
#                 <div class="board-name">Badminton</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">羽球</div>
#                 <div class="board-title">&#9678;[羽球版]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BlueArchive/index.html">
#                 <div class="board-name">BlueArchive</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">蔚藍</div>
#                 <div class="board-title">&#9678;[蔚藍] 0420生放送，樂透開盤中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyProducts/index.html">
#                 <div class="board-name">BabyProducts</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;婦嬰用品販售版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hip-Hop/index.html">
#                 <div class="board-name">Hip-Hop</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;[嘻哈] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Audiophile/index.html">
#                 <div class="board-name">Audiophile</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[喇音] 請詳閱置底板規公告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Digitalhome/index.html">
#                 <div class="board-name">Digitalhome</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">數位</div>
#                 <div class="board-title">&#9678;[電視] 2024 留意舊機出清撿便宜</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/nb-shopping/index.html">
#                 <div class="board-name">nb-shopping</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[筆電蝦] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Teacher/index.html">
#                 <div class="board-name">Teacher</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;[踢雀] 通往開學的倒數計時~~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/facelift/index.html">
#                 <div class="board-name">facelift</div>
#                 <div class="board-nuser"><span class="hl f3">35</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[醫學美容版]　嚴禁揪團買賣廣告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Examination/index.html">
#                 <div class="board-name">Examination</div>
#                 <div class="board-nuser"><span class="hl f3">34</span></div>
#                 <div class="board-class">考試</div>
#                 <div class="board-title">&#9678;[國考] 徵求上榜心得文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FATE_GO/index.html">
#                 <div class="board-name">FATE_GO</div>
#                 <div class="board-nuser"><span class="hl f3">33</span></div>
#                 <div class="board-class">手遊</div>
#                 <div class="board-title">&#9678;[FGO] 台 周二維修後 八犬傳</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/H-GAME/index.html">
#                 <div class="board-name">H-GAME</div>
#                 <div class="board-nuser"><span class="hl f3">33</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;H-GAME板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Road_Running/index.html">
#                 <div class="board-name">Road_Running</div>
#                 <div class="board-nuser"><span class="hl f3">32</span></div>
#                 <div class="board-class">跑步</div>
#                 <div class="board-title">&#9678;跑步版-抱歉我拖累了路跑版水準</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FITNESS/index.html">
#                 <div class="board-name">FITNESS</div>
#                 <div class="board-nuser"><span class="hl f3">32</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[體適能] 徵人/轉讓文會被水桶7天</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CheerGirlsTW/index.html">
#                 <div class="board-name">CheerGirlsTW</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">應援</div>
#                 <div class="board-title">&#9678;[真香] 參加活動請務必尊重女孩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Railway/index.html">
#                 <div class="board-name">Railway</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[鐵道] 徵選板主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/bicycle/index.html">
#                 <div class="board-name">bicycle</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[單車] 大家來看環台賽吧！</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/job/index.html">
#                 <div class="board-name">job</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;要求先提供照片 一律刪文水桶一週</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/tabletennis/index.html">
#                 <div class="board-name">tabletennis</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">桌球</div>
#                 <div class="board-title">&#9678;13:30林昀儒-張禹珍 世界盃4/18</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PathofExile/index.html">
#                 <div class="board-name">PathofExile</div>
#                 <div class="board-nuser"><span class="hl f3">29</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[PoE] 勤洗手戴口罩 保持社交距離</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Key_Mou_Pad/index.html">
#                 <div class="board-name">Key_Mou_Pad</div>
#                 <div class="board-nuser"><span class="hl f3">28</span></div>
#                 <div class="board-class">生活</div>
#                 <div class="board-title">&#9678;[鍵鼠] 2024新年快樂</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DMM_GAMES/index.html">
#                 <div class="board-name">DMM_GAMES</div>
#                 <div class="board-nuser"><span class="hl f3">28</span></div>
#                 <div class="board-class">遊戲</div>
#                 <div class="board-title">&#9678;[DMMG] 歡迎光臨DMM GAMES</div>
#             </a>
#         </div>
#
# 	</div>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
elements = response.html.find('div.r-ent')
for element in elements:
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
#   Cell In[7], line 8
#     import re
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
elements = response.html.find('div.r-ent')
for element in elements:
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 6
#       4 url = 'https://www.ptt.cc/bbs/hotboards.html'
#       5 response = requests.get(url)
# ----> 6 elements = response.html.find('div.r-ent')
#       7 for element in elements:
#       8     import re
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
from requests_html import HTMLSession

# 建立 HTML 會話
session = HTMLSession()
elements = response.html.find('div.r-ent')
for element in elements:
    import re

# 使用 CSS 選擇器定位目標元素
elements = response.html.find('div.r-ent')

# 逐個處理每個元素
for element in elements:
    # 可能會遇上文章已刪除的狀況，所以用例外處理 try-catch 包起來
    try:
        push = element.find('.nrec', first=True).text  # 推文數
        mark = element.find('.mark', first=True).text  # 標記
        title = element.find('.title', first=True).text  # 標題
        author = element.find('.meta > .author', first=True).text  # 作者
        date = element.find('.meta > .date', first=True).text  # 發文日期
        link = element.find('.title > a', first=True).attrs['href']  # 文章網址
    except AttributeError:
        # 處理已經刪除的文章資訊
        if '(本文已被刪除)' in title:
            # e.g., "(本文已被刪除) [haudai]"
            match_author = re.search('\[(\w*)\]', title)
            if match_author:
                author = match_author.group(1)
        elif re.search('已被\w*刪除', title):
            # e.g., "(已被cappa刪除) <edisonchu> op"
            match_author = re.search('\<(\w*)\>', title)
            if match_author:
                author = match_author.group(1)

    print('推文數:', push)
    print('標記:', mark)
    print('標題:', title)
    print('作者:', author)
    print('發文日期:', date)
    print('文章網址:', link)
    print('---')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 10
#       8 # 建立 HTML 會話
#       9 session = HTMLSession()
# ---> 10 elements = response.html.find('div.r-ent')
#      11 for element in elements:
#      12     import re
#
# AttributeError: 'Response' object has no attribute 'html'

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-cls">
# 				<a class="btn selected" href="/bbs/hotboards.html">熱門看板</a>
#                 <a class="btn" href="/cls/1">分類看板</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="b-list-container action-bar-margin bbs-screen">
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gossiping/index.html">
#                 <div class="board-name">Gossiping</div>
#                 <div class="board-nuser"><span class="hl f4">8793</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[八卦] 違反板規一直往水桶痛點踩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Stock/index.html">
#                 <div class="board-name">Stock</div>
#                 <div class="board-nuser"><span class="hl f1">4511</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[股票] 地震來襲 請注意安全</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/C_Chat/index.html">
#                 <div class="board-name">C_Chat</div>
#                 <div class="board-nuser"><span class="hl f1">3483</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[希洽] 五十嵐梨花生日快樂!!!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Baseball/index.html">
#                 <div class="board-name">Baseball</div>
#                 <div class="board-nuser"><span class="hl f1">2561</span></div>
#                 <div class="board-class">棒球</div>
#                 <div class="board-title">&#9678;[棒球] 三地開魯閣囉!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NBA/index.html">
#                 <div class="board-name">NBA</div>
#                 <div class="board-nuser"><span class="hl f1">2181</span></div>
#                 <div class="board-class">NBA.</div>
#                 <div class="board-title">&#9678;[NBA] W4附加賽 熱火76 老鷹公牛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lifeismoney/index.html">
#                 <div class="board-name">Lifeismoney</div>
#                 <div class="board-nuser"><span class="hl">1583</span></div>
#                 <div class="board-class">省錢</div>
#                 <div class="board-title">&#9678;推薦碼板規已修改，推文前請注意</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marriage/index.html">
#                 <div class="board-name">marriage</div>
#                 <div class="board-nuser"><span class="hl">1384</span></div>
#                 <div class="board-class">婚姻</div>
#                 <div class="board-title">&#9678;[婚姻] 歡迎光臨婚姻板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaStar/index.html">
#                 <div class="board-name">KoreaStar</div>
#                 <div class="board-nuser"><span class="hl">1090</span></div>
#                 <div class="board-class">韓國</div>
#                 <div class="board-title">&#9678;[韓星] 0413 HAPPY JIWOO DAY~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HatePolitics/index.html">
#                 <div class="board-name">HatePolitics</div>
#                 <div class="board-nuser"><span class="hl">735</span></div>
#                 <div class="board-class">Hate</div>
#                 <div class="board-title">&#9678;[政黑] 開冷氣開到股票賺錢</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/LoL/index.html">
#                 <div class="board-name">LoL</div>
#                 <div class="board-nuser"><span class="hl">635</span></div>
#                 <div class="board-class">遊戲</div>
#                 <div class="board-title">&#9678;[LoL] GEN達成首次LCK四連霸</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/car/index.html">
#                 <div class="board-name">car</div>
#                 <div class="board-nuser"><span class="hl">632</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[汽車] 恭喜Pellaeon成為新版主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/sex/index.html">
#                 <div class="board-name">sex</div>
#                 <div class="board-nuser"><span class="hl">605</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[西斯] 不要輕易幫別人買蒜味麵包</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/home-sale/index.html">
#                 <div class="board-name">home-sale</div>
#                 <div class="board-nuser"><span class="hl">535</span></div>
#                 <div class="board-class">房屋</div>
#                 <div class="board-title">&#9678;[房版] 房屋買賣版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/basketballTW/index.html">
#                 <div class="board-name">basketballTW</div>
#                 <div class="board-nuser"><span class="hl">511</span></div>
#                 <div class="board-class">籃球</div>
#                 <div class="board-title">&#9678;[台籃]        例行賽</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Beauty/index.html">
#                 <div class="board-name">Beauty</div>
#                 <div class="board-nuser"><span class="hl">462</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[表特] 貼AI圖 一律水桶+退文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Military/index.html">
#                 <div class="board-name">Military</div>
#                 <div class="board-nuser"><span class="hl">449</span></div>
#                 <div class="board-class">軍事</div>
#                 <div class="board-title">&#9678;[軍事]理性討論軍事 請詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tech_Job/index.html">
#                 <div class="board-name">Tech_Job</div>
#                 <div class="board-nuser"><span class="hl">431</span></div>
#                 <div class="board-class">工作</div>
#                 <div class="board-title">&#9678;[科技] 這裡是科技板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japan_Travel/index.html">
#                 <div class="board-name">Japan_Travel</div>
#                 <div class="board-nuser"><span class="hl">363</span></div>
#                 <div class="board-class">旅遊</div>
#                 <div class="board-title">&#9678;感謝各位參與富士山票選</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/movie/index.html">
#                 <div class="board-name">movie</div>
#                 <div class="board-nuser"><span class="hl">335</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[電影] 禁政治版規延續 注意置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SportLottery/index.html">
#                 <div class="board-name">SportLottery</div>
#                 <div class="board-nuser"><span class="hl">333</span></div>
#                 <div class="board-class">博弈</div>
#                 <div class="board-title">&#9678;[運彩] 運彩板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaDrama/index.html">
#                 <div class="board-name">KoreaDrama</div>
#                 <div class="board-nuser"><span class="hl">330</span></div>
#                 <div class="board-class">韓劇</div>
#                 <div class="board-title">&#9678;[韓劇]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PC_Shopping/index.html">
#                 <div class="board-name">PC_Shopping</div>
#                 <div class="board-nuser"><span class="hl">315</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[電蝦] intel 13 14代災情回報</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BaseballXXXX/index.html">
#                 <div class="board-name">BaseballXXXX</div>
#                 <div class="board-nuser"><span class="hl">306</span></div>
#                 <div class="board-class">４Ｘ</div>
#                 <div class="board-title">&#9678;[四叉] 工程師身上有乖乖很合理的</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MobileComm/index.html">
#                 <div class="board-name">MobileComm</div>
#                 <div class="board-nuser"><span class="hl">293</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[通訊] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/japanavgirls/index.html">
#                 <div class="board-name">japanavgirls</div>
#                 <div class="board-nuser"><span class="hl">269</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;AV女優板 清新、優質,神人照格式</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/creditcard/index.html">
#                 <div class="board-name">creditcard</div>
#                 <div class="board-nuser"><span class="hl">249</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;[卡板] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Marginalman/index.html">
#                 <div class="board-name">Marginalman</div>
#                 <div class="board-nuser"><span class="hl">233</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[邊緣] どう足掻いても明日はない</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PlayStation/index.html">
#                 <div class="board-name">PlayStation</div>
#                 <div class="board-nuser"><span class="hl">224</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[PS5] 4/26 STELLAR BLADE 劍星</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AllTogether/index.html">
#                 <div class="board-name">AllTogether</div>
#                 <div class="board-nuser"><span class="hl">222</span></div>
#                 <div class="board-class">聯誼</div>
#                 <div class="board-title">&#9678;[歐兔] 愛是一道光 如此美妙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyMother/index.html">
#                 <div class="board-name">BabyMother</div>
#                 <div class="board-nuser"><span class="hl">217</span></div>
#                 <div class="board-class">家庭</div>
#                 <div class="board-title">&#9678;[寶寶] 記得打流感疫苗</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Elephants/index.html">
#                 <div class="board-name">Elephants</div>
#                 <div class="board-nuser"><span class="hl">214</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;The Last Together 最後一齊</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Steam/index.html">
#                 <div class="board-name">Steam</div>
#                 <div class="board-nuser"><span class="hl">204</span></div>
#                 <div class="board-class">平台</div>
#                 <div class="board-title">&#9678;本板禁止買賣合購代購代刷</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WomenTalk/index.html">
#                 <div class="board-name">WomenTalk</div>
#                 <div class="board-nuser"><span class="hl">201</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[女孩]請小心餘震注意安全&lt;(@o@)/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/miHoYo/index.html">
#                 <div class="board-name">miHoYo</div>
#                 <div class="board-nuser"><span class="hl">197</span></div>
#                 <div class="board-class">米哈</div>
#                 <div class="board-title">&#9678;[米哈遊] 原神動畫短片-燼中歌</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Boy-Girl/index.html">
#                 <div class="board-name">Boy-Girl</div>
#                 <div class="board-nuser"><span class="hl">177</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[男女] 水桶很滿 推文請三思</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Kaohsiung/index.html">
#                 <div class="board-name">Kaohsiung</div>
#                 <div class="board-nuser"><span class="hl">175</span></div>
#                 <div class="board-class">高雄</div>
#                 <div class="board-title">&#9678;行車紀錄器-4/15AM9:00路竹區</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tainan/index.html">
#                 <div class="board-name">Tainan</div>
#                 <div class="board-nuser"><span class="hl">161</span></div>
#                 <div class="board-class">台南</div>
#                 <div class="board-title">&#9678;[台南] 請詳閱交易文規範:)</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DigiCurrency/index.html">
#                 <div class="board-name">DigiCurrency</div>
#                 <div class="board-nuser"><span class="hl">161</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[數位貨幣] 地動山搖</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/iOS/index.html">
#                 <div class="board-name">iOS</div>
#                 <div class="board-nuser"><span class="hl">156</span></div>
#                 <div class="board-class">系統</div>
#                 <div class="board-title">&#9678;[iOS] Apple®devices family</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lions/index.html">
#                 <div class="board-name">Lions</div>
#                 <div class="board-nuser"><span class="hl">146</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;統一獅板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NSwitch/index.html">
#                 <div class="board-name">NSwitch</div>
#                 <div class="board-nuser"><span class="hl">144</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[NS] 紙片瑪利歐 RPG 5/23</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HardwareSale/index.html">
#                 <div class="board-name">HardwareSale</div>
#                 <div class="board-nuser"><span class="hl">142</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[硬交] 欲售之物品須入手時間&gt;1M</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaichungBun/index.html">
#                 <div class="board-name">TaichungBun</div>
#                 <div class="board-nuser"><span class="hl">137</span></div>
#                 <div class="board-class">台中</div>
#                 <div class="board-title">&#9678;[台中] 節約用水 節約用電</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CVS/index.html">
#                 <div class="board-name">CVS</div>
#                 <div class="board-nuser"><span class="hl">131</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[CVS] 超商店員a.k.a.superman</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CFantasy/index.html">
#                 <div class="board-name">CFantasy</div>
#                 <div class="board-nuser"><span class="hl">124</span></div>
#                 <div class="board-class">玄幻</div>
#                 <div class="board-title">&#9678;[玄幻] 玄幻小說板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Aviation/index.html">
#                 <div class="board-name">Aviation</div>
#                 <div class="board-nuser"><span class="hl">119</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[航空] 航空板 請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AC_In/index.html">
#                 <div class="board-name">AC_In</div>
#                 <div class="board-nuser"><span class="hl">116</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[裏洽] 勤洗手</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tennis/index.html">
#                 <div class="board-name">Tennis</div>
#                 <div class="board-nuser"><span class="hl">116</span></div>
#                 <div class="board-class">網球</div>
#                 <div class="board-title">&#9678;[網球] Sinner #1 &amp; Sabalenka #2</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/EAseries/index.html">
#                 <div class="board-name">EAseries</div>
#                 <div class="board-nuser"><span class="hl">115</span></div>
#                 <div class="board-class">歐美</div>
#                 <div class="board-title">&#9678;[EA] 歐美影集版 </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japandrama/index.html">
#                 <div class="board-name">Japandrama</div>
#                 <div class="board-nuser"><span class="hl">112</span></div>
#                 <div class="board-class">日劇</div>
#                 <div class="board-title">&#9678;[日劇] 土22 森本慎太郎</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lakers/index.html">
#                 <div class="board-name">Lakers</div>
#                 <div class="board-nuser"><span class="hl">110</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;[Lakers] Los Angeles Lakers</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/watch/index.html">
#                 <div class="board-name">watch</div>
#                 <div class="board-nuser"><span class="hl">108</span></div>
#                 <div class="board-class">購一</div>
#                 <div class="board-title">&#9678;[錶板] Show me your Watch!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CarShop/index.html">
#                 <div class="board-name">CarShop</div>
#                 <div class="board-nuser"><span class="hl">106</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[汽車買賣] 看【置底公告】再發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/biker/index.html">
#                 <div class="board-name">biker</div>
#                 <div class="board-nuser"><span class="hl">101</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[機車]殺人部長 王國才</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/joke/index.html">
#                 <div class="board-name">joke</div>
#                 <div class="board-nuser"><span class="hl">101</span></div>
#                 <div class="board-class">娛樂</div>
#                 <div class="board-title">&#9678;[就可] 貓貓可愛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/mobilesales/index.html">
#                 <div class="board-name">mobilesales</div>
#                 <div class="board-nuser"><span class="hl">99</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[Mobile] 板規不看，水桶就來</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ONE_PIECE/index.html">
#                 <div class="board-name">ONE_PIECE</div>
#                 <div class="board-nuser"><span class="hl">99</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;[海賊王] 1111 「太陽之盾」</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-shopping/index.html">
#                 <div class="board-name">e-shopping</div>
#                 <div class="board-nuser"><span class="hl">97</span></div>
#                 <div class="board-class">網購</div>
#                 <div class="board-title">&#9678;[ＥＳ] 注意板規 遠離水桶</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/China-Drama/index.html">
#                 <div class="board-name">China-Drama</div>
#                 <div class="board-nuser"><span class="hl">95</span></div>
#                 <div class="board-class">中劇</div>
#                 <div class="board-title">&#9678;[中劇] 禁止攻擊演員個人及長相</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BeautySalon/index.html">
#                 <div class="board-name">BeautySalon</div>
#                 <div class="board-nuser"><span class="hl">93</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美保]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MacShop/index.html">
#                 <div class="board-name">MacShop</div>
#                 <div class="board-nuser"><span class="hl">90</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[麥蝦] 發文前請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PuzzleDragon/index.html">
#                 <div class="board-name">PuzzleDragon</div>
#                 <div class="board-nuser"><span class="hl">87</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[P＆D] 鋼彈系列 合作復刻</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DSLR/index.html">
#                 <div class="board-name">DSLR</div>
#                 <div class="board-nuser"><span class="hl">86</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;[攝影] 2024</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marvel/index.html">
#                 <div class="board-name">marvel</div>
#                 <div class="board-nuser"><span class="hl">86</span></div>
#                 <div class="board-class">生二</div>
#                 <div class="board-title">&#9678;[媽佛] 恐怖x外星人x預知夢?</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KR_Entertain/index.html">
#                 <div class="board-name">KR_Entertain</div>
#                 <div class="board-nuser"><span class="hl">84</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[韓綜] Show Me The 新板主!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Headphone/index.html">
#                 <div class="board-name">Headphone</div>
#                 <div class="board-nuser"><span class="hl">84</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;水桶機器人值勤中 O口O</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gamesale/index.html">
#                 <div class="board-name">Gamesale</div>
#                 <div class="board-nuser"><span class="hl">76</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[GS] 遊戲交易板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hsinchu/index.html">
#                 <div class="board-name">Hsinchu</div>
#                 <div class="board-nuser"><span class="hl">74</span></div>
#                 <div class="board-class">新竹</div>
#                 <div class="board-title">&#9678;[新竹] 新板主要來了~~\⊙▽⊙/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Bank_Service/index.html">
#                 <div class="board-name">Bank_Service</div>
#                 <div class="board-nuser"><span class="hl">72</span></div>
#                 <div class="board-class">銀行</div>
#                 <div class="board-title">&#9678;[銀行服務板] 發文要有50字滿3行</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/YuanChuang/index.html">
#                 <div class="board-name">YuanChuang</div>
#                 <div class="board-nuser"><span class="hl">71</span></div>
#                 <div class="board-class">原創</div>
#                 <div class="board-title">&#9678;[原創] 年度必看 徵文詳見置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/G-S-WARRIORS/index.html">
#                 <div class="board-name">G-S-WARRIORS</div>
#                 <div class="board-nuser"><span class="hl">68</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;我勇諸位好好休息，展望下賽季。</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Drama-Ticket/index.html">
#                 <div class="board-name">Drama-Ticket</div>
#                 <div class="board-nuser"><span class="hl">67</span></div>
#                 <div class="board-class">舞臺</div>
#                 <div class="board-title">&#9678;藝文票券轉售板 禁止徵票小心詐騙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DC_SALE/index.html">
#                 <div class="board-name">DC_SALE</div>
#                 <div class="board-nuser"><span class="hl">66</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;標題錯就刪，版主不是客服</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Monkeys/index.html">
#                 <div class="board-name">Monkeys</div>
#                 <div class="board-nuser"><span class="hl">66</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;樂天桃猿！徵選版主中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MuscleBeach/index.html">
#                 <div class="board-name">MuscleBeach</div>
#                 <div class="board-nuser"><span class="hl">62</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[健身] 發文前請務必詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Salary/index.html">
#                 <div class="board-name">Salary</div>
#                 <div class="board-nuser"><span class="hl">60</span></div>
#                 <div class="board-class">職場</div>
#                 <div class="board-title">&#9678;[職場] 工作職場板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MakeUp/index.html">
#                 <div class="board-name">MakeUp</div>
#                 <div class="board-nuser"><span class="hl">59</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美妝]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PokemonGO/index.html">
#                 <div class="board-name">PokemonGO</div>
#                 <div class="board-nuser"><span class="hl">58</span></div>
#                 <div class="board-class">抓寶</div>
#                 <div class="board-title">&#9678;[PMGO] 4/20:喇叭芽社群日14~17點</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/studyteacher/index.html">
#                 <div class="board-name">studyteacher</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;實習教師! 看板規!代理置底推!^0^</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/E-appliance/index.html">
#                 <div class="board-name">E-appliance</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[家電] 發文請照規定發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-coupon/index.html">
#                 <div class="board-name">e-coupon</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;e-coupon板規#1XewXRTO/#1Zxrj5t0</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PublicServan/index.html">
#                 <div class="board-name">PublicServan</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">公職</div>
#                 <div class="board-title">&#9678;[公職] 今年5/1軍公教不放假</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/fastfood/index.html">
#                 <div class="board-name">fastfood</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;[速食] 慟！麥香魚起士只放半片</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Wanted/index.html">
#                 <div class="board-name">Wanted</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">徵求</div>
#                 <div class="board-title">&#9678;[汪踢] 速揪吃早餐</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SuperBike/index.html">
#                 <div class="board-name">SuperBike</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;PTT重機板 ~ 發買賣文請詳閱置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hearthstone/index.html">
#                 <div class="board-name">Hearthstone</div>
#                 <div class="board-nuser"><span class="hl">53</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[爐石] 爐石十週年了! </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Guardians/index.html">
#                 <div class="board-name">Guardians</div>
#                 <div class="board-nuser"><span class="hl">52</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;[悍將] 滿壘狂攻！夠悍</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ToS/index.html">
#                 <div class="board-name">ToS</div>
#                 <div class="board-nuser"><span class="hl f3">50</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[神魔] 四乃森蒼紫</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MLB/index.html">
#                 <div class="board-name">MLB</div>
#                 <div class="board-nuser"><span class="hl f3">50</span></div>
#                 <div class="board-class">#MLB</div>
#                 <div class="board-title">&#9678;2024 Opening Day</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Option/index.html">
#                 <div class="board-name">Option</div>
#                 <div class="board-nuser"><span class="hl f3">48</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[期權] 違規檢舉請至置底文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaiwanDrama/index.html">
#                 <div class="board-name">TaiwanDrama</div>
#                 <div class="board-nuser"><span class="hl f3">48</span></div>
#                 <div class="board-class">臺劇</div>
#                 <div class="board-title">&#9678;[臺劇] 4/6 不夠善良的我們</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FORMULA1/index.html">
#                 <div class="board-name">FORMULA1</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">賽車</div>
#                 <div class="board-title">&#9678;F1板 燈滅起跑!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Food/index.html">
#                 <div class="board-name">Food</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;美食板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cat/index.html">
#                 <div class="board-name">cat</div>
#                 <div class="board-nuser"><span class="hl f3">46</span></div>
#                 <div class="board-class">寵物</div>
#                 <div class="board-title">&#9678;[喵板]禁止交易贈送徵求醫療用品</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreanPop/index.html">
#                 <div class="board-name">KoreanPop</div>
#                 <div class="board-nuser"><span class="hl f3">43</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;抵制買榜 抵制作弊，韓樂需要正義</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SakaTalk/index.html">
#                 <div class="board-name">SakaTalk</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;坂道閒聊板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Badminton/index.html">
#                 <div class="board-name">Badminton</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">羽球</div>
#                 <div class="board-title">&#9678;[羽球版]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hip-Hop/index.html">
#                 <div class="board-name">Hip-Hop</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;[嘻哈] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Coffee/index.html">
#                 <div class="board-name">Coffee</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">咖啡</div>
#                 <div class="board-title">&#9678;咖啡 秋意漸濃</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WOW/index.html">
#                 <div class="board-name">WOW</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[WoW] 10.2.6 上線</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Teacher/index.html">
#                 <div class="board-name">Teacher</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;[踢雀] 通往開學的倒數計時~~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/part-time/index.html">
#                 <div class="board-name">part-time</div>
#                 <div class="board-nuser"><span class="hl f3">40</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;[打工] 112/01/01起 工資 176/hr</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Brand/index.html">
#                 <div class="board-name">Brand</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;   ＊* 布蘭德 細節的價值 ＊*</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/facelift/index.html">
#                 <div class="board-name">facelift</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[醫學美容版]　嚴禁揪團買賣廣告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyProducts/index.html">
#                 <div class="board-name">BabyProducts</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;婦嬰用品販售版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cookclub/index.html">
#                 <div class="board-name">cookclub</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">烹飪</div>
#                 <div class="board-title">&#9678;歡迎分享手做美食</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/nb-shopping/index.html">
#                 <div class="board-name">nb-shopping</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[筆電蝦] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Taoyuan/index.html">
#                 <div class="board-name">Taoyuan</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">桃園</div>
#                 <div class="board-title">&#9678;[桃園] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DIABLO/index.html">
#                 <div class="board-name">DIABLO</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[暗黑] 暗黑2024年到來!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/StupidClown/index.html">
#                 <div class="board-name">StupidClown</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">經歷</div>
#                 <div class="board-title">&#9678; 哼哼哼哼</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Audiophile/index.html">
#                 <div class="board-name">Audiophile</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[喇音] 請詳閱置底板規公告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/H-GAME/index.html">
#                 <div class="board-name">H-GAME</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;H-GAME板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FAPL/index.html">
#                 <div class="board-name">FAPL</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">聯賽</div>
#                 <div class="board-title">&#9678;歡樂．三喵．足球</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BlueArchive/index.html">
#                 <div class="board-name">BlueArchive</div>
#                 <div class="board-nuser"><span class="hl f3">33</span></div>
#                 <div class="board-class">蔚藍</div>
#                 <div class="board-title">&#9678;[蔚藍] 0420生放送，樂透開盤中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Key_Mou_Pad/index.html">
#                 <div class="board-name">Key_Mou_Pad</div>
#                 <div class="board-nuser"><span class="hl f3">33</span></div>
#                 <div class="board-class">生活</div>
#                 <div class="board-title">&#9678;[鍵鼠] 2024新年快樂</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Examination/index.html">
#                 <div class="board-name">Examination</div>
#                 <div class="board-nuser"><span class="hl f3">32</span></div>
#                 <div class="board-class">考試</div>
#                 <div class="board-title">&#9678;[國考] 徵求上榜心得文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FATE_GO/index.html">
#                 <div class="board-name">FATE_GO</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">手遊</div>
#                 <div class="board-title">&#9678;[FGO] 台 周二維修後 八犬傳</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/bicycle/index.html">
#                 <div class="board-name">bicycle</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[單車] 大家來看環台賽吧！</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Digitalhome/index.html">
#                 <div class="board-name">Digitalhome</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">數位</div>
#                 <div class="board-title">&#9678;[電視] 2024 留意舊機出清撿便宜</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/job/index.html">
#                 <div class="board-name">job</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;要求先提供照片 一律刪文水桶一週</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/gay/index.html">
#                 <div class="board-name">gay</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[甲板]勇気爆発Bang Bravern</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/give/index.html">
#                 <div class="board-name">give</div>
#                 <div class="board-nuser"><span class="hl f3">29</span></div>
#                 <div class="board-class">贈送</div>
#                 <div class="board-title">&#9678;[贈送] 標題不合置底文規定  刪</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Railway/index.html">
#                 <div class="board-name">Railway</div>
#                 <div class="board-nuser"><span class="hl f3">28</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[鐵道] 徵選板主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TW_Entertain/index.html">
#                 <div class="board-name">TW_Entertain</div>
#                 <div class="board-nuser"><span class="hl f3">28</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[台綜] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PathofExile/index.html">
#                 <div class="board-name">PathofExile</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[PoE] 勤洗手戴口罩 保持社交距離</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gov_owned/index.html">
#                 <div class="board-name">Gov_owned</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">國營</div>
#                 <div class="board-title">&#9678;[國營] 徵求上榜心得文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/lesbian/index.html">
#                 <div class="board-name">lesbian</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[拉板] welcome to 拉版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/tabletennis/index.html">
#                 <div class="board-name">tabletennis</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">桌球</div>
#                 <div class="board-title">&#9678;13:30林昀儒-張禹珍 世界盃4/18</div>
#             </a>
#         </div>
#
# 	</div>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
import requests
from requests_html import HTMLSession

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)

# 將 Response 物件轉換為 HTMLSession 物件
session = HTMLSession()
session = session.get(url)

# 使用 HTMLSession 物件的 `html` 屬性來獲取 HTML 內容
html_content = session.html

# 現在您可以使用 requests_html 中的功能來解析 HTML
# 例如，獲取所有的超連結
links = html_content.links

# 顯示超連結
print(links)
# Out:
# {'/bbs/gay/index.html', '/bbs/Lions/index.html', '/bbs/NBA/index.html', '/cls/1', '/bbs/KR_Entertain/index.html', '/bbs/ToS/index.html', '/bbs/Military/index.html', '/bbs/FITNESS/index.html', '/bbs/CVS/index.html', '/bbs/biker/index.html', '/bbs/Boy-Girl/index.html', '/bbs/PublicServan/index.html', '/bbs/Hearthstone/index.html', '/bbs/Guardians/index.html', '/bbs/DC_SALE/index.html', '/bbs/PlayStation/index.html', '/bbs/marvel/index.html', '/bbs/miHoYo/index.html', '/bbs/Railway/index.html', '/bbs/basketballTW/index.html', '/bbs/joke/index.html', '/bbs/NSwitch/index.html', '/bbs/marriage/index.html', '/bbs/japanavgirls/index.html', '/bbs/AllTogether/index.html', '/bbs/DigiCurrency/index.html', '/contact.html', '/bbs/e-shopping/index.html', '/bbs/bicycle/index.html', '/bbs/cat/index.html', '/bbs/PokemonGO/index.html', '/bbs/Salary/index.html', '/bbs/LoL/index.html', '/bbs/KoreanPop/index.html', '/bbs/Digitalhome/index.html', '/bbs/SakaTalk/index.html', '/bbs/tabletennis/index.html', '/bbs/Examination/index.html', '/bbs/KoreaDrama/index.html', '/bbs/creditcard/index.html', '/bbs/fastfood/index.html', '/bbs/Steam/index.html', '/bbs/Aviation/index.html', '/bbs/Drama-Ticket/index.html', '/bbs/EAseries/index.html', '/bbs/Wanted/index.html', '/bbs/home-sale/index.html', '/bbs/iOS/index.html', '/bbs/Audiophile/index.html', '/bbs/Bank_Service/index.html', '/bbs/StupidClown/index.html', '/bbs/HatePolitics/index.html', '/bbs/facelift/index.html', '/bbs/Badminton/index.html', '/bbs/BlueArchive/index.html', '/bbs/Hip-Hop/index.html', '/bbs/China-Drama/index.html', '/bbs/Food/index.html', '/bbs/FAPL/index.html', '/bbs/studyteacher/index.html', '/bbs/Lakers/index.html', '/bbs/DIABLO/index.html', '/bbs/car/index.html', '/bbs/YuanChuang/index.html', '/bbs/Taoyuan/index.html', '/bbs/job/index.html', '/bbs/MacShop/index.html', '/bbs/WOW/index.html', '/bbs/e-coupon/index.html', '/bbs/Lifeismoney/index.html', '/bbs/WomenTalk/index.html', '/bbs/mobilesales/index.html', '/bbs/Tennis/index.html', '/bbs/PC_Shopping/index.html', '/bbs/E-appliance/index.html', '/bbs/Beauty/index.html', '/bbs/DSLR/index.html', '/bbs/BaseballXXXX/index.html', '/bbs/Gov_owned/index.html', '/bbs/Marginalman/index.html', '/bbs/sex/index.html', '/bbs/Kaohsiung/index.html', '/bbs/CarShop/index.html', '/bbs/watch/index.html', '/about.html', '/bbs/part-time/index.html', '/bbs/Elephants/index.html', '/bbs/EatToDie/index.html', '/bbs/TaichungBun/index.html', '/bbs/SportLottery/index.html', '/bbs/Gossiping/index.html', '/bbs/Gamesale/index.html', '/bbs/Key_Mou_Pad/index.html', '/bbs/hotboards.html', '/bbs/MLB/index.html', '/bbs/Teacher/index.html', '/bbs/BabyProducts/index.html', '/bbs/Monkeys/index.html', '/bbs/MobileComm/index.html', '/bbs/nb-shopping/index.html', '/bbs/MakeUp/index.html', '/bbs/H-GAME/index.html', '/bbs/KoreaStar/index.html', '/bbs/Japan_Travel/index.html', '/bbs/Coffee/index.html', '/bbs/Tech_Job/index.html', '/bbs/Baseball/index.html', '/bbs/HardwareSale/index.html', '/bbs/Brand/index.html', '/bbs/cookclub/index.html', '/bbs/MuscleBeach/index.html', '/bbs/Tainan/index.html', '/bbs/PathofExile/index.html', '/bbs/G-S-WARRIORS/index.html', '/bbs/Japandrama/index.html', '/bbs/Option/index.html', '/bbs/C_Chat/index.html', '/bbs/AC_In/index.html', '/bbs/Headphone/index.html', '/bbs/Stock/index.html', '/bbs/movie/index.html', '/bbs/TaiwanDrama/index.html', '/bbs/FATE_GO/index.html', '/bbs/BabyMother/index.html', '/bbs/', '/bbs/Hsinchu/index.html', '/bbs/SuperBike/index.html', '/bbs/ONE_PIECE/index.html', '/bbs/CFantasy/index.html', '/bbs/FORMULA1/index.html', '/bbs/give/index.html', '/bbs/PuzzleDragon/index.html', '/bbs/BeautySalon/index.html'}

# %%
import requests

# 發送 HTTP GET 請求並獲取網頁內容
url = 'https://www.ptt.cc/bbs/hotboards.html'
response = requests.get(url)

# 打印 HTML 內容
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>熱門看板 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
#
# <div id="main-container">
# 	<div id="action-bar-container">
# 		<div class="action-bar">
# 			<div class="btn-group btn-group-cls">
# 				<a class="btn selected" href="/bbs/hotboards.html">熱門看板</a>
#                 <a class="btn" href="/cls/1">分類看板</a>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="b-list-container action-bar-margin bbs-screen">
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gossiping/index.html">
#                 <div class="board-name">Gossiping</div>
#                 <div class="board-nuser"><span class="hl f4">8610</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[八卦] 違反板規一直往水桶痛點踩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Stock/index.html">
#                 <div class="board-name">Stock</div>
#                 <div class="board-nuser"><span class="hl f1">4494</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[股票] 地震來襲 請注意安全</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/C_Chat/index.html">
#                 <div class="board-name">C_Chat</div>
#                 <div class="board-nuser"><span class="hl f1">3470</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[希洽] 五十嵐梨花生日快樂!!!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Baseball/index.html">
#                 <div class="board-name">Baseball</div>
#                 <div class="board-nuser"><span class="hl f1">2505</span></div>
#                 <div class="board-class">棒球</div>
#                 <div class="board-title">&#9678;[棒球] 三地開魯閣囉!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NBA/index.html">
#                 <div class="board-name">NBA</div>
#                 <div class="board-nuser"><span class="hl f1">2184</span></div>
#                 <div class="board-class">NBA.</div>
#                 <div class="board-title">&#9678;[NBA] W4附加賽 熱火76 老鷹公牛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lifeismoney/index.html">
#                 <div class="board-name">Lifeismoney</div>
#                 <div class="board-nuser"><span class="hl">1532</span></div>
#                 <div class="board-class">省錢</div>
#                 <div class="board-title">&#9678;推薦碼板規已修改，推文前請注意</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marriage/index.html">
#                 <div class="board-name">marriage</div>
#                 <div class="board-nuser"><span class="hl">1339</span></div>
#                 <div class="board-class">婚姻</div>
#                 <div class="board-title">&#9678;[婚姻] 歡迎光臨婚姻板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaStar/index.html">
#                 <div class="board-name">KoreaStar</div>
#                 <div class="board-nuser"><span class="hl">1071</span></div>
#                 <div class="board-class">韓國</div>
#                 <div class="board-title">&#9678;[韓星] 0413 HAPPY JIWOO DAY~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HatePolitics/index.html">
#                 <div class="board-name">HatePolitics</div>
#                 <div class="board-nuser"><span class="hl">710</span></div>
#                 <div class="board-class">Hate</div>
#                 <div class="board-title">&#9678;[政黑] 開冷氣開到股票賺錢</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/LoL/index.html">
#                 <div class="board-name">LoL</div>
#                 <div class="board-nuser"><span class="hl">635</span></div>
#                 <div class="board-class">遊戲</div>
#                 <div class="board-title">&#9678;[LoL] GEN達成首次LCK四連霸</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/sex/index.html">
#                 <div class="board-name">sex</div>
#                 <div class="board-nuser"><span class="hl">618</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[西斯] 不要輕易幫別人買蒜味麵包</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/car/index.html">
#                 <div class="board-name">car</div>
#                 <div class="board-nuser"><span class="hl">596</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[汽車] 恭喜Pellaeon成為新版主</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/home-sale/index.html">
#                 <div class="board-name">home-sale</div>
#                 <div class="board-nuser"><span class="hl">525</span></div>
#                 <div class="board-class">房屋</div>
#                 <div class="board-title">&#9678;[房版] 房屋買賣版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/basketballTW/index.html">
#                 <div class="board-name">basketballTW</div>
#                 <div class="board-nuser"><span class="hl">490</span></div>
#                 <div class="board-class">籃球</div>
#                 <div class="board-title">&#9678;[台籃]        例行賽</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Beauty/index.html">
#                 <div class="board-name">Beauty</div>
#                 <div class="board-nuser"><span class="hl">464</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[表特] 貼AI圖 一律水桶+退文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Military/index.html">
#                 <div class="board-name">Military</div>
#                 <div class="board-nuser"><span class="hl">437</span></div>
#                 <div class="board-class">軍事</div>
#                 <div class="board-title">&#9678;[軍事]理性討論軍事 請詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tech_Job/index.html">
#                 <div class="board-name">Tech_Job</div>
#                 <div class="board-nuser"><span class="hl">412</span></div>
#                 <div class="board-class">工作</div>
#                 <div class="board-title">&#9678;[科技] 這裡是科技板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japan_Travel/index.html">
#                 <div class="board-name">Japan_Travel</div>
#                 <div class="board-nuser"><span class="hl">356</span></div>
#                 <div class="board-class">旅遊</div>
#                 <div class="board-title">&#9678;感謝各位參與富士山票選</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PC_Shopping/index.html">
#                 <div class="board-name">PC_Shopping</div>
#                 <div class="board-nuser"><span class="hl">344</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[電蝦] intel 13 14代災情回報</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/movie/index.html">
#                 <div class="board-name">movie</div>
#                 <div class="board-nuser"><span class="hl">339</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[電影] 禁政治版規延續 注意置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SportLottery/index.html">
#                 <div class="board-name">SportLottery</div>
#                 <div class="board-nuser"><span class="hl">324</span></div>
#                 <div class="board-class">博弈</div>
#                 <div class="board-title">&#9678;[運彩] 運彩板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreaDrama/index.html">
#                 <div class="board-name">KoreaDrama</div>
#                 <div class="board-nuser"><span class="hl">317</span></div>
#                 <div class="board-class">韓劇</div>
#                 <div class="board-title">&#9678;[韓劇]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BaseballXXXX/index.html">
#                 <div class="board-name">BaseballXXXX</div>
#                 <div class="board-nuser"><span class="hl">304</span></div>
#                 <div class="board-class">４Ｘ</div>
#                 <div class="board-title">&#9678;[四叉] 工程師身上有乖乖很合理的</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MobileComm/index.html">
#                 <div class="board-name">MobileComm</div>
#                 <div class="board-nuser"><span class="hl">295</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[通訊] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/japanavgirls/index.html">
#                 <div class="board-name">japanavgirls</div>
#                 <div class="board-nuser"><span class="hl">274</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;AV女優板 清新、優質,神人照格式</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Marginalman/index.html">
#                 <div class="board-name">Marginalman</div>
#                 <div class="board-nuser"><span class="hl">237</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[邊緣] どう足掻いても明日はない</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyMother/index.html">
#                 <div class="board-name">BabyMother</div>
#                 <div class="board-nuser"><span class="hl">225</span></div>
#                 <div class="board-class">家庭</div>
#                 <div class="board-title">&#9678;[寶寶] 記得打流感疫苗</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/creditcard/index.html">
#                 <div class="board-name">creditcard</div>
#                 <div class="board-nuser"><span class="hl">218</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;[卡板] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PlayStation/index.html">
#                 <div class="board-name">PlayStation</div>
#                 <div class="board-nuser"><span class="hl">215</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[PS5] 4/26 STELLAR BLADE 劍星</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Steam/index.html">
#                 <div class="board-name">Steam</div>
#                 <div class="board-nuser"><span class="hl">210</span></div>
#                 <div class="board-class">平台</div>
#                 <div class="board-title">&#9678;本板禁止買賣合購代購代刷</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AllTogether/index.html">
#                 <div class="board-name">AllTogether</div>
#                 <div class="board-nuser"><span class="hl">208</span></div>
#                 <div class="board-class">聯誼</div>
#                 <div class="board-title">&#9678;[歐兔] 愛是一道光 如此美妙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Elephants/index.html">
#                 <div class="board-name">Elephants</div>
#                 <div class="board-nuser"><span class="hl">208</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;The Last Together 最後一齊</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/miHoYo/index.html">
#                 <div class="board-name">miHoYo</div>
#                 <div class="board-nuser"><span class="hl">191</span></div>
#                 <div class="board-class">米哈</div>
#                 <div class="board-title">&#9678;[米哈遊] 原神動畫短片-燼中歌</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WomenTalk/index.html">
#                 <div class="board-name">WomenTalk</div>
#                 <div class="board-nuser"><span class="hl">188</span></div>
#                 <div class="board-class">聊天</div>
#                 <div class="board-title">&#9678;[女孩]請小心餘震注意安全&lt;(@o@)/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Boy-Girl/index.html">
#                 <div class="board-name">Boy-Girl</div>
#                 <div class="board-nuser"><span class="hl">182</span></div>
#                 <div class="board-class">心情</div>
#                 <div class="board-title">&#9678;[男女] 水桶很滿 推文請三思</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Kaohsiung/index.html">
#                 <div class="board-name">Kaohsiung</div>
#                 <div class="board-nuser"><span class="hl">162</span></div>
#                 <div class="board-class">高雄</div>
#                 <div class="board-title">&#9678;行車紀錄器-4/15AM9:00路竹區</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DigiCurrency/index.html">
#                 <div class="board-name">DigiCurrency</div>
#                 <div class="board-nuser"><span class="hl">161</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[數位貨幣] 地動山搖</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/iOS/index.html">
#                 <div class="board-name">iOS</div>
#                 <div class="board-nuser"><span class="hl">152</span></div>
#                 <div class="board-class">系統</div>
#                 <div class="board-title">&#9678;[iOS] Apple®devices family</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tainan/index.html">
#                 <div class="board-name">Tainan</div>
#                 <div class="board-nuser"><span class="hl">152</span></div>
#                 <div class="board-class">台南</div>
#                 <div class="board-title">&#9678;[台南] 請詳閱交易文規範:)</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/HardwareSale/index.html">
#                 <div class="board-name">HardwareSale</div>
#                 <div class="board-nuser"><span class="hl">149</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[硬交] 欲售之物品須入手時間&gt;1M</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lions/index.html">
#                 <div class="board-name">Lions</div>
#                 <div class="board-nuser"><span class="hl">143</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;統一獅板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/NSwitch/index.html">
#                 <div class="board-name">NSwitch</div>
#                 <div class="board-nuser"><span class="hl">139</span></div>
#                 <div class="board-class">主機</div>
#                 <div class="board-title">&#9678;[NS] 紙片瑪利歐 RPG 5/23</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaichungBun/index.html">
#                 <div class="board-name">TaichungBun</div>
#                 <div class="board-nuser"><span class="hl">137</span></div>
#                 <div class="board-class">台中</div>
#                 <div class="board-title">&#9678;[台中] 節約用水 節約用電</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CVS/index.html">
#                 <div class="board-name">CVS</div>
#                 <div class="board-nuser"><span class="hl">134</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[CVS] 超商店員a.k.a.superman</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CFantasy/index.html">
#                 <div class="board-name">CFantasy</div>
#                 <div class="board-nuser"><span class="hl">122</span></div>
#                 <div class="board-class">玄幻</div>
#                 <div class="board-title">&#9678;[玄幻] 玄幻小說板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Japandrama/index.html">
#                 <div class="board-name">Japandrama</div>
#                 <div class="board-nuser"><span class="hl">118</span></div>
#                 <div class="board-class">日劇</div>
#                 <div class="board-title">&#9678;[日劇] 土22 森本慎太郎</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/AC_In/index.html">
#                 <div class="board-name">AC_In</div>
#                 <div class="board-nuser"><span class="hl">117</span></div>
#                 <div class="board-class">閒談</div>
#                 <div class="board-title">&#9678;[裏洽] 勤洗手</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Tennis/index.html">
#                 <div class="board-name">Tennis</div>
#                 <div class="board-nuser"><span class="hl">116</span></div>
#                 <div class="board-class">網球</div>
#                 <div class="board-title">&#9678;[網球] Sinner #1 &amp; Sabalenka #2</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Aviation/index.html">
#                 <div class="board-name">Aviation</div>
#                 <div class="board-nuser"><span class="hl">113</span></div>
#                 <div class="board-class">交通</div>
#                 <div class="board-title">&#9678;[航空] 航空板 請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/EAseries/index.html">
#                 <div class="board-name">EAseries</div>
#                 <div class="board-nuser"><span class="hl">111</span></div>
#                 <div class="board-class">歐美</div>
#                 <div class="board-title">&#9678;[EA] 歐美影集版 </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Lakers/index.html">
#                 <div class="board-name">Lakers</div>
#                 <div class="board-nuser"><span class="hl">110</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;[Lakers] Los Angeles Lakers</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/joke/index.html">
#                 <div class="board-name">joke</div>
#                 <div class="board-nuser"><span class="hl">108</span></div>
#                 <div class="board-class">娛樂</div>
#                 <div class="board-title">&#9678;[就可] 貓貓可愛</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ONE_PIECE/index.html">
#                 <div class="board-name">ONE_PIECE</div>
#                 <div class="board-nuser"><span class="hl">106</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;[海賊王] 1111 「太陽之盾」</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/watch/index.html">
#                 <div class="board-name">watch</div>
#                 <div class="board-nuser"><span class="hl">101</span></div>
#                 <div class="board-class">購一</div>
#                 <div class="board-title">&#9678;[錶板] Show me your Watch!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/mobilesales/index.html">
#                 <div class="board-name">mobilesales</div>
#                 <div class="board-nuser"><span class="hl">100</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[Mobile] 板規不看，水桶就來</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CarShop/index.html">
#                 <div class="board-name">CarShop</div>
#                 <div class="board-nuser"><span class="hl">99</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;[汽車買賣] 看【置底公告】再發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/biker/index.html">
#                 <div class="board-name">biker</div>
#                 <div class="board-nuser"><span class="hl">95</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[機車]殺人部長 王國才</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BeautySalon/index.html">
#                 <div class="board-name">BeautySalon</div>
#                 <div class="board-nuser"><span class="hl">95</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美保]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DSLR/index.html">
#                 <div class="board-name">DSLR</div>
#                 <div class="board-nuser"><span class="hl">89</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;[攝影] 2024</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/China-Drama/index.html">
#                 <div class="board-name">China-Drama</div>
#                 <div class="board-nuser"><span class="hl">88</span></div>
#                 <div class="board-class">中劇</div>
#                 <div class="board-title">&#9678;[中劇] 禁止攻擊演員個人及長相</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-shopping/index.html">
#                 <div class="board-name">e-shopping</div>
#                 <div class="board-nuser"><span class="hl">87</span></div>
#                 <div class="board-class">網購</div>
#                 <div class="board-title">&#9678;[ＥＳ] 注意板規 遠離水桶</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MacShop/index.html">
#                 <div class="board-name">MacShop</div>
#                 <div class="board-nuser"><span class="hl">85</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[麥蝦] 發文前請先詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/marvel/index.html">
#                 <div class="board-name">marvel</div>
#                 <div class="board-nuser"><span class="hl">84</span></div>
#                 <div class="board-class">生二</div>
#                 <div class="board-title">&#9678;[媽佛] 恐怖x外星人x預知夢?</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PuzzleDragon/index.html">
#                 <div class="board-name">PuzzleDragon</div>
#                 <div class="board-nuser"><span class="hl">83</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[P＆D] 鋼彈系列 合作復刻</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Headphone/index.html">
#                 <div class="board-name">Headphone</div>
#                 <div class="board-nuser"><span class="hl">82</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;水桶機器人值勤中 O口O</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KR_Entertain/index.html">
#                 <div class="board-name">KR_Entertain</div>
#                 <div class="board-nuser"><span class="hl">79</span></div>
#                 <div class="board-class">綜藝</div>
#                 <div class="board-title">&#9678;[韓綜] Show Me The 新板主!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hsinchu/index.html">
#                 <div class="board-name">Hsinchu</div>
#                 <div class="board-nuser"><span class="hl">78</span></div>
#                 <div class="board-class">新竹</div>
#                 <div class="board-title">&#9678;[新竹] 新板主要來了~~\⊙▽⊙/</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/YuanChuang/index.html">
#                 <div class="board-name">YuanChuang</div>
#                 <div class="board-nuser"><span class="hl">77</span></div>
#                 <div class="board-class">原創</div>
#                 <div class="board-title">&#9678;[原創] 年度必看 徵文詳見置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gamesale/index.html">
#                 <div class="board-name">Gamesale</div>
#                 <div class="board-nuser"><span class="hl">72</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;[GS] 遊戲交易板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DC_SALE/index.html">
#                 <div class="board-name">DC_SALE</div>
#                 <div class="board-nuser"><span class="hl">70</span></div>
#                 <div class="board-class">攝影</div>
#                 <div class="board-title">&#9678;標題錯就刪，版主不是客服</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Bank_Service/index.html">
#                 <div class="board-name">Bank_Service</div>
#                 <div class="board-nuser"><span class="hl">69</span></div>
#                 <div class="board-class">銀行</div>
#                 <div class="board-title">&#9678;[銀行服務板] 發文要有50字滿3行</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Drama-Ticket/index.html">
#                 <div class="board-name">Drama-Ticket</div>
#                 <div class="board-nuser"><span class="hl">66</span></div>
#                 <div class="board-class">舞臺</div>
#                 <div class="board-title">&#9678;藝文票券轉售板 禁止徵票小心詐騙</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Monkeys/index.html">
#                 <div class="board-name">Monkeys</div>
#                 <div class="board-nuser"><span class="hl">65</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;樂天桃猿！徵選版主中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/studyteacher/index.html">
#                 <div class="board-name">studyteacher</div>
#                 <div class="board-nuser"><span class="hl">63</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;實習教師! 看板規!代理置底推!^0^</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/G-S-WARRIORS/index.html">
#                 <div class="board-name">G-S-WARRIORS</div>
#                 <div class="board-nuser"><span class="hl">63</span></div>
#                 <div class="board-class">W-PA</div>
#                 <div class="board-title">&#9678;我勇諸位好好休息，展望下賽季。</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MakeUp/index.html">
#                 <div class="board-name">MakeUp</div>
#                 <div class="board-nuser"><span class="hl">63</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[美妝]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MuscleBeach/index.html">
#                 <div class="board-name">MuscleBeach</div>
#                 <div class="board-nuser"><span class="hl">62</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[健身] 發文前請務必詳閱板規</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/E-appliance/index.html">
#                 <div class="board-name">E-appliance</div>
#                 <div class="board-nuser"><span class="hl">58</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[家電] 發文請照規定發文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Wanted/index.html">
#                 <div class="board-name">Wanted</div>
#                 <div class="board-nuser"><span class="hl">58</span></div>
#                 <div class="board-class">徵求</div>
#                 <div class="board-title">&#9678;[汪踢] 速揪吃早餐</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/e-coupon/index.html">
#                 <div class="board-name">e-coupon</div>
#                 <div class="board-nuser"><span class="hl">58</span></div>
#                 <div class="board-class">理財</div>
#                 <div class="board-title">&#9678;e-coupon板規#1XewXRTO/#1Zxrj5t0</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PublicServan/index.html">
#                 <div class="board-name">PublicServan</div>
#                 <div class="board-nuser"><span class="hl">57</span></div>
#                 <div class="board-class">公職</div>
#                 <div class="board-title">&#9678;[公職] 今年5/1軍公教不放假</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Salary/index.html">
#                 <div class="board-name">Salary</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">職場</div>
#                 <div class="board-title">&#9678;[職場] 工作職場板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PokemonGO/index.html">
#                 <div class="board-name">PokemonGO</div>
#                 <div class="board-nuser"><span class="hl">56</span></div>
#                 <div class="board-class">抓寶</div>
#                 <div class="board-title">&#9678;[PMGO] 4/20:喇叭芽社群日14~17點</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/fastfood/index.html">
#                 <div class="board-name">fastfood</div>
#                 <div class="board-nuser"><span class="hl">55</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;[速食] 慟！麥香魚起士只放半片</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hearthstone/index.html">
#                 <div class="board-name">Hearthstone</div>
#                 <div class="board-nuser"><span class="hl">51</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[爐石] 爐石十週年了! </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SuperBike/index.html">
#                 <div class="board-name">SuperBike</div>
#                 <div class="board-nuser"><span class="hl f3">50</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;PTT重機板 ~ 發買賣文請詳閱置底</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/MLB/index.html">
#                 <div class="board-name">MLB</div>
#                 <div class="board-nuser"><span class="hl f3">49</span></div>
#                 <div class="board-class">#MLB</div>
#                 <div class="board-title">&#9678;2024 Opening Day</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FORMULA1/index.html">
#                 <div class="board-name">FORMULA1</div>
#                 <div class="board-nuser"><span class="hl f3">48</span></div>
#                 <div class="board-class">賽車</div>
#                 <div class="board-title">&#9678;F1板 燈滅起跑!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/ToS/index.html">
#                 <div class="board-name">ToS</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">轉珠</div>
#                 <div class="board-title">&#9678;[神魔] 四乃森蒼紫</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Guardians/index.html">
#                 <div class="board-name">Guardians</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">CPBL</div>
#                 <div class="board-title">&#9678;[悍將] 滿壘狂攻！夠悍</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Food/index.html">
#                 <div class="board-name">Food</div>
#                 <div class="board-nuser"><span class="hl f3">47</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;美食板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Option/index.html">
#                 <div class="board-name">Option</div>
#                 <div class="board-nuser"><span class="hl f3">46</span></div>
#                 <div class="board-class">學術</div>
#                 <div class="board-title">&#9678;[期權] 違規檢舉請至置底文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/TaiwanDrama/index.html">
#                 <div class="board-name">TaiwanDrama</div>
#                 <div class="board-nuser"><span class="hl f3">46</span></div>
#                 <div class="board-class">臺劇</div>
#                 <div class="board-title">&#9678;[臺劇] 4/6 不夠善良的我們</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Teacher/index.html">
#                 <div class="board-name">Teacher</div>
#                 <div class="board-nuser"><span class="hl f3">44</span></div>
#                 <div class="board-class">教師</div>
#                 <div class="board-title">&#9678;[踢雀] 通往開學的倒數計時~~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/KoreanPop/index.html">
#                 <div class="board-name">KoreanPop</div>
#                 <div class="board-nuser"><span class="hl f3">43</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;抵制買榜 抵制作弊，韓樂需要正義</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cat/index.html">
#                 <div class="board-name">cat</div>
#                 <div class="board-nuser"><span class="hl f3">42</span></div>
#                 <div class="board-class">寵物</div>
#                 <div class="board-title">&#9678;[喵板]禁止交易贈送徵求醫療用品</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/SakaTalk/index.html">
#                 <div class="board-name">SakaTalk</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">日本</div>
#                 <div class="board-title">&#9678;坂道閒聊板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/WOW/index.html">
#                 <div class="board-name">WOW</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[WoW] 10.2.6 上線</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/facelift/index.html">
#                 <div class="board-name">facelift</div>
#                 <div class="board-nuser"><span class="hl f3">41</span></div>
#                 <div class="board-class">美容</div>
#                 <div class="board-title">&#9678;[醫學美容版]　嚴禁揪團買賣廣告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Brand/index.html">
#                 <div class="board-name">Brand</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;   ＊* 布蘭德 細節的價值 ＊*</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/DIABLO/index.html">
#                 <div class="board-name">DIABLO</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[暗黑] 暗黑2024年到來!</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/part-time/index.html">
#                 <div class="board-name">part-time</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;[打工] 112/01/01起 工資 176/hr</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/cookclub/index.html">
#                 <div class="board-name">cookclub</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">烹飪</div>
#                 <div class="board-title">&#9678;歡迎分享手做美食</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Hip-Hop/index.html">
#                 <div class="board-name">Hip-Hop</div>
#                 <div class="board-nuser"><span class="hl f3">39</span></div>
#                 <div class="board-class">音樂</div>
#                 <div class="board-title">&#9678;[嘻哈] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Key_Mou_Pad/index.html">
#                 <div class="board-name">Key_Mou_Pad</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">生活</div>
#                 <div class="board-title">&#9678;[鍵鼠] 2024新年快樂</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Taoyuan/index.html">
#                 <div class="board-name">Taoyuan</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">桃園</div>
#                 <div class="board-title">&#9678;[桃園] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Coffee/index.html">
#                 <div class="board-name">Coffee</div>
#                 <div class="board-nuser"><span class="hl f3">38</span></div>
#                 <div class="board-class">咖啡</div>
#                 <div class="board-title">&#9678;咖啡 秋意漸濃</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Badminton/index.html">
#                 <div class="board-name">Badminton</div>
#                 <div class="board-nuser"><span class="hl f3">37</span></div>
#                 <div class="board-class">羽球</div>
#                 <div class="board-title">&#9678;[羽球版]</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FAPL/index.html">
#                 <div class="board-name">FAPL</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">聯賽</div>
#                 <div class="board-title">&#9678;歡樂．三喵．足球</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Digitalhome/index.html">
#                 <div class="board-name">Digitalhome</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">數位</div>
#                 <div class="board-title">&#9678;[電視] 2024 留意舊機出清撿便宜</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/StupidClown/index.html">
#                 <div class="board-name">StupidClown</div>
#                 <div class="board-nuser"><span class="hl f3">36</span></div>
#                 <div class="board-class">經歷</div>
#                 <div class="board-title">&#9678; 哼哼哼哼</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BabyProducts/index.html">
#                 <div class="board-name">BabyProducts</div>
#                 <div class="board-nuser"><span class="hl f3">34</span></div>
#                 <div class="board-class">買賣</div>
#                 <div class="board-title">&#9678;婦嬰用品販售版</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/nb-shopping/index.html">
#                 <div class="board-name">nb-shopping</div>
#                 <div class="board-nuser"><span class="hl f3">34</span></div>
#                 <div class="board-class">硬體</div>
#                 <div class="board-title">&#9678;[筆電蝦] </div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/H-GAME/index.html">
#                 <div class="board-name">H-GAME</div>
#                 <div class="board-nuser"><span class="hl f3">34</span></div>
#                 <div class="board-class">綜合</div>
#                 <div class="board-title">&#9678;H-GAME板</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/bicycle/index.html">
#                 <div class="board-name">bicycle</div>
#                 <div class="board-nuser"><span class="hl f3">33</span></div>
#                 <div class="board-class">車車</div>
#                 <div class="board-title">&#9678;[單車] 大家來看環台賽吧！</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BlueArchive/index.html">
#                 <div class="board-name">BlueArchive</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">蔚藍</div>
#                 <div class="board-title">&#9678;[蔚藍] 0420生放送，樂透開盤中</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/job/index.html">
#                 <div class="board-name">job</div>
#                 <div class="board-nuser"><span class="hl f3">31</span></div>
#                 <div class="board-class">求職</div>
#                 <div class="board-title">&#9678;要求先提供照片 一律刪文水桶一週</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/give/index.html">
#                 <div class="board-name">give</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">贈送</div>
#                 <div class="board-title">&#9678;[贈送] 標題不合置底文規定  刪</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Audiophile/index.html">
#                 <div class="board-name">Audiophile</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">資訊</div>
#                 <div class="board-title">&#9678;[喇音] 請詳閱置底板規公告</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Examination/index.html">
#                 <div class="board-name">Examination</div>
#                 <div class="board-nuser"><span class="hl f3">30</span></div>
#                 <div class="board-class">考試</div>
#                 <div class="board-title">&#9678;[國考] 徵求上榜心得文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FATE_GO/index.html">
#                 <div class="board-name">FATE_GO</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">手遊</div>
#                 <div class="board-title">&#9678;[FGO] 台 周二維修後 八犬傳</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/PathofExile/index.html">
#                 <div class="board-name">PathofExile</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">線上</div>
#                 <div class="board-title">&#9678;[PoE] 勤洗手戴口罩 保持社交距離</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/gay/index.html">
#                 <div class="board-name">gay</div>
#                 <div class="board-nuser"><span class="hl f3">27</span></div>
#                 <div class="board-class">男女</div>
#                 <div class="board-title">&#9678;[甲板]勇気爆発Bang Bravern</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/CheerGirlsTW/index.html">
#                 <div class="board-name">CheerGirlsTW</div>
#                 <div class="board-nuser"><span class="hl f3">26</span></div>
#                 <div class="board-class">應援</div>
#                 <div class="board-title">&#9678;[真香] 參加活動請務必尊重女孩</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/EatToDie/index.html">
#                 <div class="board-name">EatToDie</div>
#                 <div class="board-nuser"><span class="hl f3">26</span></div>
#                 <div class="board-class">美食</div>
#                 <div class="board-title">&#9678;[飽板] 能吃就是福</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/BigBanciao/index.html">
#                 <div class="board-name">BigBanciao</div>
#                 <div class="board-nuser"><span class="hl f3">26</span></div>
#                 <div class="board-class">新北</div>
#                 <div class="board-title">&#9678;[板橋] 這裡是板橋 板橋版~</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/Gov_owned/index.html">
#                 <div class="board-name">Gov_owned</div>
#                 <div class="board-nuser"><span class="hl f3">26</span></div>
#                 <div class="board-class">國營</div>
#                 <div class="board-title">&#9678;[國營] 徵求上榜心得文</div>
#             </a>
#         </div>
#
#         <div class="b-ent">
#             <a class="board" href="/bbs/FITNESS/index.html">
#                 <div class="board-name">FITNESS</div>
#                 <div class="board-nuser"><span class="hl f3">26</span></div>
#                 <div class="board-class">美體</div>
#                 <div class="board-title">&#9678;[體適能] 徵人/轉讓文會被水桶7天</div>
#             </a>
#         </div>
#
# 	</div>
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text
        date = item.find('.board-name', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("日期:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 8574
# 日期: Gossiping
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 4505
# 日期: Stock
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3454
# 日期: C_Chat
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2514
# 日期: Baseball
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 2154
# 日期: NBA
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1505
# 日期: Lifeismoney
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1311
# 日期: marriage
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 1068
# 日期: KoreaStar
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 709
# 日期: HatePolitics
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 631
# 日期: LoL
# -----
# 標題: ◎[西斯] 不要輕易幫別人買蒜味麵包
# 推文數: 601
# 日期: sex
# -----
# 標題: ◎[汽車] 恭喜Pellaeon成為新版主
# 推文數: 572
# 日期: car
# -----
# 標題: ◎[房版] 房屋買賣版
# 推文數: 532
# 日期: home-sale
# -----
# 標題: ◎[台籃] 例行賽
# 推文數: 482
# 日期: basketballTW
# -----
# 標題: ◎[表特] 貼AI圖 一律水桶+退文
# 推文數: 456
# 日期: Beauty
# -----
# 標題: ◎[軍事]理性討論軍事 請詳閱板規
# 推文數: 443
# 日期: Military
# -----
# 標題: ◎[科技] 這裡是科技板
# 推文數: 392
# 日期: Tech_Job
# -----
# 標題: ◎[電影] 禁政治版規延續 注意置底
# 推文數: 360
# 日期: movie
# -----
# 標題: ◎感謝各位參與富士山票選
# 推文數: 357
# 日期: Japan_Travel
# -----
# 標題: ◎[電蝦] intel 13 14代災情回報
# 推文數: 337
# 日期: PC_Shopping
# -----
# 標題: ◎[韓劇]
# 推文數: 328
# 日期: KoreaDrama
# -----
# 標題: ◎[運彩] 運彩板
# 推文數: 324
# 日期: SportLottery
# -----
# 標題: ◎[四叉] 工程師身上有乖乖很合理的
# 推文數: 294
# 日期: BaseballXXXX
# -----
# 標題: ◎[通訊]
# 推文數: 288
# 日期: MobileComm
# -----
# 標題: ◎AV女優板 清新、優質,神人照格式
# 推文數: 269
# 日期: japanavgirls
# -----
# 標題: ◎[邊緣] どう足掻いても明日はない
# 推文數: 232
# 日期: Marginalman
# -----
# 標題: ◎[寶寶] 記得打流感疫苗
# 推文數: 219
# 日期: BabyMother
# -----
# 標題: ◎[卡板]
# 推文數: 215
# 日期: creditcard
# -----
# 標題: ◎[PS5] 4/26 STELLAR BLADE 劍星
# 推文數: 208
# 日期: PlayStation
# -----
# 標題: ◎[歐兔] 愛是一道光 如此美妙
# 推文數: 203
# 日期: AllTogether
# -----
# 標題: ◎本板禁止買賣合購代購代刷
# 推文數: 201
# 日期: Steam
# -----
# 標題: ◎[女孩]請小心餘震注意安全<(@o@)/
# 推文數: 194
# 日期: WomenTalk
# -----
# 標題: ◎The Last Together 最後一齊
# 推文數: 194
# 日期: Elephants
# -----
# 標題: ◎[米哈遊] 原神動畫短片-燼中歌
# 推文數: 189
# 日期: miHoYo
# -----
# 標題: ◎[男女] 水桶很滿 推文請三思
# 推文數: 173
# 日期: Boy-Girl
# -----
# 標題: ◎行車紀錄器-4/15AM9:00路竹區
# 推文數: 161
# 日期: Kaohsiung
# -----
# 標題: ◎[數位貨幣] 地動山搖
# 推文數: 160
# 日期: DigiCurrency
# -----
# 標題: ◎[台南] 請詳閱交易文規範:)
# 推文數: 151
# 日期: Tainan
# -----
# 標題: ◎統一獅板
# 推文數: 151
# 日期: Lions
# -----
# 標題: ◎[iOS] Apple®devices family
# 推文數: 146
# 日期: iOS
# -----
# 標題: ◎[硬交] 欲售之物品須入手時間>1M
# 推文數: 144
# 日期: HardwareSale
# -----
# 標題: ◎[NS] 紙片瑪利歐 RPG 5/23
# 推文數: 137
# 日期: NSwitch
# -----
# 標題: ◎[台中] 節約用水 節約用電
# 推文數: 126
# 日期: TaichungBun
# -----
# 標題: ◎[CVS] 超商店員a.k.a.superman
# 推文數: 124
# 日期: CVS
# -----
# 標題: ◎[玄幻] 玄幻小說板
# 推文數: 122
# 日期: CFantasy
# -----
# 標題: ◎[EA] 歐美影集版
# 推文數: 122
# 日期: EAseries
# -----
# 標題: ◎[日劇] 土22 森本慎太郎
# 推文數: 121
# 日期: Japandrama
# -----
# 標題: ◎[裏洽] 勤洗手
# 推文數: 115
# 日期: AC_In
# -----
# 標題: ◎[網球] Sinner #1 & Sabalenka #2
# 推文數: 114
# 日期: Tennis
# -----
# 標題: ◎[航空] 航空板 請先詳閱板規
# 推文數: 111
# 日期: Aviation
# -----
# 標題: ◎[就可] 貓貓可愛
# 推文數: 110
# 日期: joke
# -----
# 標題: ◎[海賊王] 1111 「太陽之盾」
# 推文數: 109
# 日期: ONE_PIECE
# -----
# 標題: ◎[Lakers] Los Angeles Lakers
# 推文數: 108
# 日期: Lakers
# -----
# 標題: ◎[錶板] Show me your Watch!
# 推文數: 105
# 日期: watch
# -----
# 標題: ◎[Mobile] 板規不看，水桶就來
# 推文數: 99
# 日期: mobilesales
# -----
# 標題: ◎[機車]殺人部長 王國才
# 推文數: 98
# 日期: biker
# -----
# 標題: ◎[汽車買賣] 看【置底公告】再發文
# 推文數: 97
# 日期: CarShop
# -----
# 標題: ◎[美保]
# 推文數: 96
# 日期: BeautySalon
# -----
# 標題: ◎[中劇] 禁止攻擊演員個人及長相
# 推文數: 88
# 日期: China-Drama
# -----
# 標題: ◎[P＆D] 鋼彈系列 合作復刻
# 推文數: 85
# 日期: PuzzleDragon
# -----
# 標題: ◎[麥蝦] 發文前請先詳閱板規
# 推文數: 85
# 日期: MacShop
# -----
# 標題: ◎[ＥＳ] 注意板規 遠離水桶
# 推文數: 83
# 日期: e-shopping
# -----
# 標題: ◎[攝影] 2024
# 推文數: 82
# 日期: DSLR
# -----
# 標題: ◎水桶機器人值勤中 O口O
# 推文數: 81
# 日期: Headphone
# -----
# 標題: ◎[韓綜] Show Me The 新板主!
# 推文數: 79
# 日期: KR_Entertain
# -----
# 標題: ◎[原創] 年度必看 徵文詳見置底
# 推文數: 78
# 日期: YuanChuang
# -----
# 標題: ◎[GS] 遊戲交易板
# 推文數: 77
# 日期: Gamesale
# -----
# 標題: ◎[新竹] 新板主要來了~~\⊙▽⊙/
# 推文數: 76
# 日期: Hsinchu
# -----
# 標題: ◎[媽佛] 恐怖x外星人x預知夢?
# 推文數: 76
# 日期: marvel
# -----
# 標題: ◎標題錯就刪，版主不是客服
# 推文數: 73
# 日期: DC_SALE
# -----
# 標題: ◎[銀行服務板] 發文要有50字滿3行
# 推文數: 73
# 日期: Bank_Service
# -----
# 標題: ◎[健身] 發文前請務必詳閱板規
# 推文數: 69
# 日期: MuscleBeach
# -----
# 標題: ◎[美妝]
# 推文數: 68
# 日期: MakeUp
# -----
# 標題: ◎藝文票券轉售板 禁止徵票小心詐騙
# 推文數: 67
# 日期: Drama-Ticket
# -----
# 標題: ◎[家電] 發文請照規定發文
# 推文數: 66
# 日期: E-appliance
# -----
# 標題: ◎樂天桃猿！徵選版主中
# 推文數: 66
# 日期: Monkeys
# -----
# 標題: ◎[職場] 工作職場板
# 推文數: 63
# 日期: Salary
# -----
# 標題: ◎實習教師! 看板規!代理置底推!^0^
# 推文數: 63
# 日期: studyteacher
# -----
# 標題: ◎[汪踢] 速揪吃早餐
# 推文數: 60
# 日期: Wanted
# -----
# 標題: ◎[PMGO] 4/20:喇叭芽社群日14~17點
# 推文數: 60
# 日期: PokemonGO
# -----
# 標題: ◎[爐石] 爐石十週年了!
# 推文數: 57
# 日期: Hearthstone
# -----
# 標題: ◎[公職] 今年5/1軍公教不放假
# 推文數: 55
# 日期: PublicServan
# -----
# 標題: ◎我勇諸位好好休息，展望下賽季。
# 推文數: 55
# 日期: G-S-WARRIORS
# -----
# 標題: ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# 推文數: 53
# 日期: e-coupon
# -----
# 標題: ◎[期權] 違規檢舉請至置底文
# 推文數: 51
# 日期: Option
# -----
# 標題: ◎[悍將] 滿壘狂攻！夠悍
# 推文數: 50
# 日期: Guardians
# -----
# 標題: ◎F1板 燈滅起跑!
# 推文數: 49
# 日期: FORMULA1
# -----
# 標題: ◎[速食] 慟！麥香魚起士只放半片
# 推文數: 47
# 日期: fastfood
# -----
# 標題: ◎美食板
# 推文數: 47
# 日期: Food
# -----
# 標題: ◎[臺劇] 4/6 不夠善良的我們
# 推文數: 46
# 日期: TaiwanDrama
# -----
# 標題: ◎2024 Opening Day
# 推文數: 46
# 日期: MLB
# -----
# 標題: ◎[踢雀] 通往開學的倒數計時~~
# 推文數: 45
# 日期: Teacher
# -----
# 標題: ◎PTT重機板 ~ 發買賣文請詳閱置底
# 推文數: 44
# 日期: SuperBike
# -----
# 標題: ◎[神魔] 四乃森蒼紫
# 推文數: 43
# 日期: ToS
# -----
# 標題: ◎抵制買榜 抵制作弊，韓樂需要正義
# 推文數: 42
# 日期: KoreanPop
# -----
# 標題: ◎[桃園]
# 推文數: 42
# 日期: Taoyuan
# -----
# 標題: ◎ ＊* 布蘭德 細節的價值 ＊*
# 推文數: 41
# 日期: Brand
# -----
# 標題: ◎[WoW] 10.2.6 上線
# 推文數: 40
# 日期: WOW
# -----
# 標題: ◎[醫學美容版]　嚴禁揪團買賣廣告
# 推文數: 40
# 日期: facelift
# -----
# 標題: ◎歡迎分享手做美食
# 推文數: 40
# 日期: cookclub
# -----
# 標題: ◎坂道閒聊板
# 推文數: 39
# 日期: SakaTalk
# -----
# 標題: ◎[喵板]禁止交易贈送徵求醫療用品
# 推文數: 39
# 日期: cat
# -----
# 標題: ◎H-GAME板
# 推文數: 37
# 日期: H-GAME
# -----
# 標題: ◎[電視] 2024 留意舊機出清撿便宜
# 推文數: 37
# 日期: Digitalhome
# -----
# 標題: ◎[暗黑] 暗黑2024年到來!
# 推文數: 37
# 日期: DIABLO
# -----
# 標題: ◎[打工] 112/01/01起 工資 176/hr
# 推文數: 37
# 日期: part-time
# -----
# 標題: ◎[羽球版]
# 推文數: 37
# 日期: Badminton
# -----
# 標題: ◎ 哼哼哼哼
# 推文數: 37
# 日期: StupidClown
# -----
# 標題: ◎歡樂．三喵．足球
# 推文數: 36
# 日期: FAPL
# -----
# 標題: ◎[喇音] 請詳閱置底板規公告
# 推文數: 35
# 日期: Audiophile
# -----
# 標題: ◎[鍵鼠] 2024新年快樂
# 推文數: 34
# 日期: Key_Mou_Pad
# -----
# 標題: ◎咖啡 秋意漸濃
# 推文數: 34
# 日期: Coffee
# -----
# 標題: ◎要求先提供照片 一律刪文水桶一週
# 推文數: 34
# 日期: job
# -----
# 標題: ◎[FGO] 台 周二維修後 八犬傳
# 推文數: 33
# 日期: FATE_GO
# -----
# 標題: ◎婦嬰用品販售版
# 推文數: 33
# 日期: BabyProducts
# -----
# 標題: ◎[贈送] 標題不合置底文規定 刪
# 推文數: 33
# 日期: give
# -----
# 標題: ◎[國考] 徵求上榜心得文
# 推文數: 33
# 日期: Examination
# -----
# 標題: ◎[嘻哈]
# 推文數: 33
# 日期: Hip-Hop
# -----
# 標題: ◎[蔚藍] 0420生放送，樂透開盤中
# 推文數: 32
# 日期: BlueArchive
# -----
# 標題: ◎[單車] 大家來看環台賽吧！
# 推文數: 31
# 日期: bicycle
# -----
# 標題: ◎[甲板]勇気爆発Bang Bravern
# 推文數: 31
# 日期: gay
# -----
# 標題: ◎[真香] 參加活動請務必尊重女孩
# 推文數: 30
# 日期: CheerGirlsTW
# -----
# 標題: ◎[筆電蝦]
# 推文數: 30
# 日期: nb-shopping
# -----
# 標題: ◎[鐵道] 徵選板主
# 推文數: 30
# 日期: Railway
# -----
# 標題: ◎[飽板] 能吃就是福
# 推文數: 29
# 日期: EatToDie
# -----
# 標題: ◎[PoE] 勤洗手戴口罩 保持社交距離
# 推文數: 29
# 日期: PathofExile
# -----
# 標題: ◎[國營] 徵求上榜心得文
# 推文數: 28
# 日期: Gov_owned
# -----
# 標題: ◎[DMMG] 歡迎光臨DMM GAMES
# 推文數: 28
# 日期: DMM_GAMES
# -----

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text
        author = item.find('.board-date', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("作者:", author)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 8351
# 日期: Gossiping
# 8351
# 綜合
# ◎[八卦] 違反板規一直往水桶痛點踩
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 4413
# 日期: Stock
# 4413
# 學術
# ◎[股票] 地震來襲 請注意安全
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3404
# 日期: C_Chat
# 3404
# 閒談
# ◎[希洽] 五十嵐梨花生日快樂!!!
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2422
# 日期: Baseball
# 2422
# 棒球
# ◎[棒球] 三地開魯閣囉!
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 2160
# 日期: NBA
# 2160
# NBA.
# ◎[NBA] W4附加賽 熱火76 老鷹公牛
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1461
# 日期: Lifeismoney
# 1461
# 省錢
# ◎推薦碼板規已修改，推文前請注意
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1293
# 日期: marriage
# 1293
# 婚姻
# ◎[婚姻] 歡迎光臨婚姻板
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 1063
# 日期: KoreaStar
# 1063
# 韓國
# ◎[韓星] 0413 HAPPY JIWOO DAY~
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 678
# 日期: HatePolitics
# 678
# Hate
# ◎[政黑] 開冷氣開到股票賺錢
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 619
# 日期: LoL
# 619
# 遊戲
# ◎[LoL] GEN達成首次LCK四連霸
# -----
# 標題: ◎[西斯] 不要輕易幫別人買蒜味麵包
# 推文數: 549
# 日期: sex
# 549
# 男女
# ◎[西斯] 不要輕易幫別人買蒜味麵包
# -----
# 標題: ◎[汽車] 恭喜Pellaeon成為新版主
# 推文數: 545
# 日期: car
# 545
# 車車
# ◎[汽車] 恭喜Pellaeon成為新版主
# -----
# 標題: ◎[房版] 房屋買賣版
# 推文數: 518
# 日期: home-sale
# 518
# 房屋
# ◎[房版] 房屋買賣版
# -----
# 標題: ◎[台籃] 例行賽
# 推文數: 488
# 日期: basketballTW
# 488
# 籃球
# ◎[台籃] 例行賽
# -----
# 標題: ◎[軍事]理性討論軍事 請詳閱板規
# 推文數: 449
# 日期: Military
# 449
# 軍事
# ◎[軍事]理性討論軍事 請詳閱板規
# -----
# 標題: ◎[表特] 貼AI圖 一律水桶+退文
# 推文數: 438
# 日期: Beauty
# 438
# 聊天
# ◎[表特] 貼AI圖 一律水桶+退文
# -----
# 標題: ◎[科技] 這裡是科技板
# 推文數: 366
# 日期: Tech_Job
# 366
# 工作
# ◎[科技] 這裡是科技板
# -----
# 標題: ◎感謝各位參與富士山票選
# 推文數: 343
# 日期: Japan_Travel
# 343
# 旅遊
# ◎感謝各位參與富士山票選
# -----
# 標題: ◎[電蝦] intel 13 14代災情回報
# 推文數: 319
# 日期: PC_Shopping
# 319
# 硬體
# ◎[電蝦] intel 13 14代災情回報
# -----
# 標題: ◎[運彩] 運彩板
# 推文數: 319
# 日期: SportLottery
# 319
# 博弈
# ◎[運彩] 運彩板
# -----
# 標題: ◎[電影] 禁政治版規延續 注意置底
# 推文數: 316
# 日期: movie
# 316
# 綜合
# ◎[電影] 禁政治版規延續 注意置底
# -----
# 標題: ◎[韓劇]
# 推文數: 311
# 日期: KoreaDrama
# 311
# 韓劇
# ◎[韓劇]
# -----
# 標題: ◎[通訊]
# 推文數: 288
# 日期: MobileComm
# 288
# 資訊
# ◎[通訊]
# -----
# 標題: ◎[四叉] 工程師身上有乖乖很合理的
# 推文數: 283
# 日期: BaseballXXXX
# 283
# ４Ｘ
# ◎[四叉] 工程師身上有乖乖很合理的
# -----
# 標題: ◎AV女優板 清新、優質,神人照格式
# 推文數: 268
# 日期: japanavgirls
# 268
# 綜合
# ◎AV女優板 清新、優質,神人照格式
# -----
# 標題: ◎[邊緣] どう足掻いても明日はない
# 推文數: 220
# 日期: Marginalman
# 220
# 心情
# ◎[邊緣] どう足掻いても明日はない
# -----
# 標題: ◎[卡板]
# 推文數: 217
# 日期: creditcard
# 217
# 理財
# ◎[卡板]
# -----
# 標題: ◎[PS5] 4/26 STELLAR BLADE 劍星
# 推文數: 215
# 日期: PlayStation
# 215
# 主機
# ◎[PS5] 4/26 STELLAR BLADE 劍星
# -----
# 標題: ◎[歐兔] 愛是一道光 如此美妙
# 推文數: 208
# 日期: AllTogether
# 208
# 聯誼
# ◎[歐兔] 愛是一道光 如此美妙
# -----
# 標題: ◎The Last Together 最後一齊
# 推文數: 208
# 日期: Elephants
# 208
# CPBL
# ◎The Last Together 最後一齊
# -----
# 標題: ◎[米哈遊] 原神動畫短片-燼中歌
# 推文數: 201
# 日期: miHoYo
# 201
# 米哈
# ◎[米哈遊] 原神動畫短片-燼中歌
# -----
# 標題: ◎本板禁止買賣合購代購代刷
# 推文數: 197
# 日期: Steam
# 197
# 平台
# ◎本板禁止買賣合購代購代刷
# -----
# 標題: ◎[女孩]請小心餘震注意安全<(@o@)/
# 推文數: 194
# 日期: WomenTalk
# 194
# 聊天
# ◎[女孩]請小心餘震注意安全<(@o@)/
# -----
# 標題: ◎[寶寶] 記得打流感疫苗
# 推文數: 193
# 日期: BabyMother
# 193
# 家庭
# ◎[寶寶] 記得打流感疫苗
# -----
# 標題: ◎[男女] 水桶很滿 推文請三思
# 推文數: 167
# 日期: Boy-Girl
# 167
# 心情
# ◎[男女] 水桶很滿 推文請三思
# -----
# 標題: ◎[台南] 請詳閱交易文規範:)
# 推文數: 148
# 日期: Tainan
# 148
# 台南
# ◎[台南] 請詳閱交易文規範:)
# -----
# 標題: ◎[硬交] 欲售之物品須入手時間>1M
# 推文數: 147
# 日期: HardwareSale
# 147
# 買賣
# ◎[硬交] 欲售之物品須入手時間>1M
# -----
# 標題: ◎行車紀錄器-4/15AM9:00路竹區
# 推文數: 147
# 日期: Kaohsiung
# 147
# 高雄
# ◎行車紀錄器-4/15AM9:00路竹區
# -----
# 標題: ◎[NS] 紙片瑪利歐 RPG 5/23
# 推文數: 146
# 日期: NSwitch
# 146
# 主機
# ◎[NS] 紙片瑪利歐 RPG 5/23
# -----
# 標題: ◎[數位貨幣] 地動山搖
# 推文數: 145
# 日期: DigiCurrency
# 145
# 資訊
# ◎[數位貨幣] 地動山搖
# -----
# 標題: ◎統一獅板
# 推文數: 143
# 日期: Lions
# 143
# CPBL
# ◎統一獅板
# -----
# 標題: ◎[iOS] Apple®devices family
# 推文數: 141
# 日期: iOS
# 141
# 系統
# ◎[iOS] Apple®devices family
# -----
# 標題: ◎[台中] 節約用水 節約用電
# 推文數: 129
# 日期: TaichungBun
# 129
# 台中
# ◎[台中] 節約用水 節約用電
# -----
# 標題: ◎[EA] 歐美影集版
# 推文數: 125
# 日期: EAseries
# 125
# 歐美
# ◎[EA] 歐美影集版
# -----
# 標題: ◎[CVS] 超商店員a.k.a.superman
# 推文數: 124
# 日期: CVS
# 124
# 資訊
# ◎[CVS] 超商店員a.k.a.superman
# -----
# 標題: ◎[玄幻] 玄幻小說板
# 推文數: 119
# 日期: CFantasy
# 119
# 玄幻
# ◎[玄幻] 玄幻小說板
# -----
# 標題: ◎[日劇] 土22 森本慎太郎
# 推文數: 119
# 日期: Japandrama
# 119
# 日劇
# ◎[日劇] 土22 森本慎太郎
# -----
# 標題: ◎[航空] 航空板 請先詳閱板規
# 推文數: 110
# 日期: Aviation
# 110
# 交通
# ◎[航空] 航空板 請先詳閱板規
# -----
# 標題: ◎[裏洽] 勤洗手
# 推文數: 109
# 日期: AC_In
# 109
# 閒談
# ◎[裏洽] 勤洗手
# -----
# 標題: ◎[錶板] Show me your Watch!
# 推文數: 106
# 日期: watch
# 106
# 購一
# ◎[錶板] Show me your Watch!
# -----
# 標題: ◎[Lakers] Los Angeles Lakers
# 推文數: 103
# 日期: Lakers
# 103
# W-PA
# ◎[Lakers] Los Angeles Lakers
# -----
# 標題: ◎[網球] Sinner #1 & Sabalenka #2
# 推文數: 100
# 日期: Tennis
# 100
# 網球
# ◎[網球] Sinner #1 & Sabalenka #2
# -----
# 標題: ◎[機車]殺人部長 王國才
# 推文數: 97
# 日期: biker
# 97
# 車車
# ◎[機車]殺人部長 王國才
# -----
# 標題: ◎[就可] 貓貓可愛
# 推文數: 97
# 日期: joke
# 97
# 娛樂
# ◎[就可] 貓貓可愛
# -----
# 標題: ◎[汽車買賣] 看【置底公告】再發文
# 推文數: 95
# 日期: CarShop
# 95
# 買賣
# ◎[汽車買賣] 看【置底公告】再發文
# -----
# 標題: ◎[中劇] 禁止攻擊演員個人及長相
# 推文數: 95
# 日期: China-Drama
# 95
# 中劇
# ◎[中劇] 禁止攻擊演員個人及長相
# -----
# 標題: ◎[海賊王] 1111 「太陽之盾」
# 推文數: 95
# 日期: ONE_PIECE
# 95
# 日本
# ◎[海賊王] 1111 「太陽之盾」
# -----
# 標題: ◎[Mobile] 板規不看，水桶就來
# 推文數: 89
# 日期: mobilesales
# 89
# 資訊
# ◎[Mobile] 板規不看，水桶就來
# -----
# 標題: ◎[P＆D] 鋼彈系列 合作復刻
# 推文數: 86
# 日期: PuzzleDragon
# 86
# 轉珠
# ◎[P＆D] 鋼彈系列 合作復刻
# -----
# 標題: ◎[美保]
# 推文數: 86
# 日期: BeautySalon
# 86
# 美容
# ◎[美保]
# -----
# 標題: ◎[麥蝦] 發文前請先詳閱板規
# 推文數: 84
# 日期: MacShop
# 84
# 資訊
# ◎[麥蝦] 發文前請先詳閱板規
# -----
# 標題: ◎[ＥＳ] 注意板規 遠離水桶
# 推文數: 80
# 日期: e-shopping
# 80
# 網購
# ◎[ＥＳ] 注意板規 遠離水桶
# -----
# 標題: ◎[GS] 遊戲交易板
# 推文數: 79
# 日期: Gamesale
# 79
# 綜合
# ◎[GS] 遊戲交易板
# -----
# 標題: ◎[韓綜] Show Me The 新板主!
# 推文數: 79
# 日期: KR_Entertain
# 79
# 綜藝
# ◎[韓綜] Show Me The 新板主!
# -----
# 標題: ◎水桶機器人值勤中 O口O
# 推文數: 76
# 日期: Headphone
# 76
# 資訊
# ◎水桶機器人值勤中 O口O
# -----
# 標題: ◎[攝影] 2024
# 推文數: 75
# 日期: DSLR
# 75
# 攝影
# ◎[攝影] 2024
# -----
# 標題: ◎[新竹] 新板主要來了~~\⊙▽⊙/
# 推文數: 74
# 日期: Hsinchu
# 74
# 新竹
# ◎[新竹] 新板主要來了~~\⊙▽⊙/
# -----
# 標題: ◎標題錯就刪，版主不是客服
# 推文數: 71
# 日期: DC_SALE
# 71
# 攝影
# ◎標題錯就刪，版主不是客服
# -----
# 標題: ◎[原創] 年度必看 徵文詳見置底
# 推文數: 70
# 日期: YuanChuang
# 70
# 原創
# ◎[原創] 年度必看 徵文詳見置底
# -----
# 標題: ◎藝文票券轉售板 禁止徵票小心詐騙
# 推文數: 70
# 日期: Drama-Ticket
# 70
# 舞臺
# ◎藝文票券轉售板 禁止徵票小心詐騙
# -----
# 標題: ◎[媽佛] 恐怖x外星人x預知夢?
# 推文數: 70
# 日期: marvel
# 70
# 生二
# ◎[媽佛] 恐怖x外星人x預知夢?
# -----
# 標題: ◎[職場] 工作職場板
# 推文數: 64
# 日期: Salary
# 64
# 職場
# ◎[職場] 工作職場板
# -----
# 標題: ◎樂天桃猿！徵選版主中
# 推文數: 64
# 日期: Monkeys
# 64
# CPBL
# ◎樂天桃猿！徵選版主中
# -----
# 標題: ◎[銀行服務板] 發文要有50字滿3行
# 推文數: 63
# 日期: Bank_Service
# 63
# 銀行
# ◎[銀行服務板] 發文要有50字滿3行
# -----
# 標題: ◎[家電] 發文請照規定發文
# 推文數: 62
# 日期: E-appliance
# 62
# 資訊
# ◎[家電] 發文請照規定發文
# -----
# 標題: ◎[美妝]
# 推文數: 62
# 日期: MakeUp
# 62
# 美容
# ◎[美妝]
# -----
# 標題: ◎[PMGO] 4/20:喇叭芽社群日14~17點
# 推文數: 61
# 日期: PokemonGO
# 61
# 抓寶
# ◎[PMGO] 4/20:喇叭芽社群日14~17點
# -----
# 標題: ◎實習教師! 看板規!代理置底推!^0^
# 推文數: 59
# 日期: studyteacher
# 59
# 教師
# ◎實習教師! 看板規!代理置底推!^0^
# -----
# 標題: ◎[汪踢] 速揪吃早餐
# 推文數: 58
# 日期: Wanted
# 58
# 徵求
# ◎[汪踢] 速揪吃早餐
# -----
# 標題: ◎我勇諸位好好休息，展望下賽季。
# 推文數: 57
# 日期: G-S-WARRIORS
# 57
# W-PA
# ◎我勇諸位好好休息，展望下賽季。
# -----
# 標題: ◎[爐石] 爐石十週年了!
# 推文數: 54
# 日期: Hearthstone
# 54
# 線上
# ◎[爐石] 爐石十週年了!
# -----
# 標題: ◎[速食] 慟！麥香魚起士只放半片
# 推文數: 53
# 日期: fastfood
# 53
# 美食
# ◎[速食] 慟！麥香魚起士只放半片
# -----
# 標題: ◎[健身] 發文前請務必詳閱板規
# 推文數: 53
# 日期: MuscleBeach
# 53
# 美體
# ◎[健身] 發文前請務必詳閱板規
# -----
# 標題: ◎[公職] 今年5/1軍公教不放假
# 推文數: 51
# 日期: PublicServan
# 51
# 公職
# ◎[公職] 今年5/1軍公教不放假
# -----
# 標題: ◎F1板 燈滅起跑!
# 推文數: 51
# 日期: FORMULA1
# 51
# 賽車
# ◎F1板 燈滅起跑!
# -----
# 標題: ◎[臺劇] 4/6 不夠善良的我們
# 推文數: 50
# 日期: TaiwanDrama
# 50
# 臺劇
# ◎[臺劇] 4/6 不夠善良的我們
# -----
# 標題: ◎抵制買榜 抵制作弊，韓樂需要正義
# 推文數: 49
# 日期: KoreanPop
# 49
# 音樂
# ◎抵制買榜 抵制作弊，韓樂需要正義
# -----
# 標題: ◎2024 Opening Day
# 推文數: 49
# 日期: MLB
# 49
# #MLB
# ◎2024 Opening Day
# -----
# 標題: ◎PTT重機板 ~ 發買賣文請詳閱置底
# 推文數: 46
# 日期: SuperBike
# 46
# 車車
# ◎PTT重機板 ~ 發買賣文請詳閱置底
# -----
# 標題: ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# 推文數: 46
# 日期: e-coupon
# 46
# 理財
# ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# -----
# 標題: ◎[神魔] 四乃森蒼紫
# 推文數: 44
# 日期: ToS
# 44
# 轉珠
# ◎[神魔] 四乃森蒼紫
# -----
# 標題: ◎[喵板]禁止交易贈送徵求醫療用品
# 推文數: 43
# 日期: cat
# 43
# 寵物
# ◎[喵板]禁止交易贈送徵求醫療用品
# -----
# 標題: ◎[踢雀] 通往開學的倒數計時~~
# 推文數: 42
# 日期: Teacher
# 42
# 教師
# ◎[踢雀] 通往開學的倒數計時~~
# -----
# 標題: ◎[醫學美容版]　嚴禁揪團買賣廣告
# 推文數: 42
# 日期: facelift
# 42
# 美容
# ◎[醫學美容版]　嚴禁揪團買賣廣告
# -----
# 標題: ◎[悍將] 滿壘狂攻！夠悍
# 推文數: 42
# 日期: Guardians
# 42
# CPBL
# ◎[悍將] 滿壘狂攻！夠悍
# -----
# 標題: ◎美食板
# 推文數: 42
# 日期: Food
# 42
# 美食
# ◎美食板
# -----
# 標題: ◎[期權] 違規檢舉請至置底文
# 推文數: 41
# 日期: Option
# 41
# 學術
# ◎[期權] 違規檢舉請至置底文
# -----
# 標題: ◎[羽球版]
# 推文數: 41
# 日期: Badminton
# 41
# 羽球
# ◎[羽球版]
# -----
# 標題: ◎坂道閒聊板
# 推文數: 40
# 日期: SakaTalk
# 40
# 日本
# ◎坂道閒聊板
# -----
# 標題: ◎[嘻哈]
# 推文數: 40
# 日期: Hip-Hop
# 40
# 音樂
# ◎[嘻哈]
# -----
# 標題: ◎[WoW] 10.2.6 上線
# 推文數: 38
# 日期: WOW
# 38
# 線上
# ◎[WoW] 10.2.6 上線
# -----
# 標題: ◎H-GAME板
# 推文數: 37
# 日期: H-GAME
# 37
# 綜合
# ◎H-GAME板
# -----
# 標題: ◎[桃園]
# 推文數: 37
# 日期: Taoyuan
# 37
# 桃園
# ◎[桃園]
# -----
# 標題: ◎歡迎分享手做美食
# 推文數: 37
# 日期: cookclub
# 37
# 烹飪
# ◎歡迎分享手做美食
# -----
# 標題: ◎[喇音] 請詳閱置底板規公告
# 推文數: 36
# 日期: Audiophile
# 36
# 資訊
# ◎[喇音] 請詳閱置底板規公告
# -----
# 標題: ◎咖啡 秋意漸濃
# 推文數: 36
# 日期: Coffee
# 36
# 咖啡
# ◎咖啡 秋意漸濃
# -----
# 標題: ◎[蔚藍] 0420生放送，樂透開盤中
# 推文數: 35
# 日期: BlueArchive
# 35
# 蔚藍
# ◎[蔚藍] 0420生放送，樂透開盤中
# -----
# 標題: ◎ ＊* 布蘭德 細節的價值 ＊*
# 推文數: 35
# 日期: Brand
# 35
# 資訊
# ◎ ＊* 布蘭德 細節的價值 ＊*
# -----
# 標題: ◎[鍵鼠] 2024新年快樂
# 推文數: 34
# 日期: Key_Mou_Pad
# 34
# 生活
# ◎[鍵鼠] 2024新年快樂
# -----
# 標題: ◎[暗黑] 暗黑2024年到來!
# 推文數: 34
# 日期: DIABLO
# 34
# 線上
# ◎[暗黑] 暗黑2024年到來!
# -----
# 標題: ◎ 哼哼哼哼
# 推文數: 33
# 日期: StupidClown
# 33
# 經歷
# ◎ 哼哼哼哼
# -----
# 標題: ◎[飽板] 能吃就是福
# 推文數: 32
# 日期: EatToDie
# 32
# 美食
# ◎[飽板] 能吃就是福
# -----
# 標題: ◎歡樂．三喵．足球
# 推文數: 32
# 日期: FAPL
# 32
# 聯賽
# ◎歡樂．三喵．足球
# -----
# 標題: ◎[打工] 112/01/01起 工資 176/hr
# 推文數: 32
# 日期: part-time
# 32
# 求職
# ◎[打工] 112/01/01起 工資 176/hr
# -----
# 標題: ◎[鐵道] 徵選板主
# 推文數: 31
# 日期: Railway
# 31
# 交通
# ◎[鐵道] 徵選板主
# -----
# 標題: ◎[國營] 徵求上榜心得文
# 推文數: 31
# 日期: Gov_owned
# 31
# 國營
# ◎[國營] 徵求上榜心得文
# -----
# 標題: ◎婦嬰用品販售版
# 推文數: 30
# 日期: BabyProducts
# 30
# 買賣
# ◎婦嬰用品販售版
# -----
# 標題: ◎要求先提供照片 一律刪文水桶一週
# 推文數: 30
# 日期: job
# 30
# 求職
# ◎要求先提供照片 一律刪文水桶一週
# -----
# 標題: ◎[軟工] 成為全宇宙のNo.1吧
# 推文數: 29
# 日期: Soft_Job
# 29
# 工作
# ◎[軟工] 成為全宇宙のNo.1吧
# -----
# 標題: ◎[筆電蝦]
# 推文數: 29
# 日期: nb-shopping
# 29
# 硬體
# ◎[筆電蝦]
# -----
# 標題: ◎你安靜 發文前請詳置底文
# 推文數: 29
# 日期: shoes
# 29
# 購一
# ◎你安靜 發文前請詳置底文
# -----
# 標題: ◎[國考] 徵求上榜心得文
# 推文數: 28
# 日期: Examination
# 28
# 考試
# ◎[國考] 徵求上榜心得文
# -----
# 標題: ◎[電視] 2024 留意舊機出清撿便宜
# 推文數: 28
# 日期: Digitalhome
# 28
# 數位
# ◎[電視] 2024 留意舊機出清撿便宜
# -----
# 標題: ◎[DMMG] 歡迎光臨DMM GAMES
# 推文數: 28
# 日期: DMM_GAMES
# 28
# 遊戲
# ◎[DMMG] 歡迎光臨DMM GAMES
# -----
# 標題: ◎[FGO] 台 周二維修後 八犬傳
# 推文數: 27
# 日期: FATE_GO
# 27
# 手遊
# ◎[FGO] 台 周二維修後 八犬傳
# -----
# 標題: ◎[真香] 參加活動請務必尊重女孩
# 推文數: 27
# 日期: CheerGirlsTW
# 27
# 應援
# ◎[真香] 參加活動請務必尊重女孩
# -----
# 標題: ◎[贈送] 標題不合置底文規定 刪
# 推文數: 27
# 日期: give
# 27
# 贈送
# ◎[贈送] 標題不合置底文規定 刪
# -----
# 標題: ◎[雙和] 置底商業文板規調整討論
# 推文數: 27
# 日期: ShuangHe
# 27
# 新北
# ◎[雙和] 置底商業文板規調整討論
# -----

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text
        date = item.find('.date', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("作者:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 17
#      15 title = item.find('.board-title', first=True).text
#      16 nuser = item.find('.board-nuser .hl', first=True).text
# ---> 17 date = item.find('.date', first=True).text
#      19 # 打印標題、推文數和日期
#      20 print("標題:", title)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text
        author = item.find('.board-date', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("作者:", author)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 17
#      15 title = item.find('.board-title', first=True).text
#      16 nuser = item.find('.board-nuser .hl', first=True).text
# ---> 17 author = item.find('.board-date', first=True).text
#      19 # 打印標題、推文數和日期
#      20 print("標題:", title)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text
        date = item.find('.board-name', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("日期:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 8184
# 日期: Gossiping
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 4118
# 日期: Stock
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3317
# 日期: C_Chat
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2360
# 日期: Baseball
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 2064
# 日期: NBA
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1416
# 日期: Lifeismoney
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1203
# 日期: marriage
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 1012
# 日期: KoreaStar
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 669
# 日期: HatePolitics
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 610
# 日期: LoL
# -----
# 標題: ◎[西斯] 不要輕易幫別人買蒜味麵包
# 推文數: 564
# 日期: sex
# -----
# 標題: ◎[汽車] 恭喜Pellaeon成為新版主
# 推文數: 535
# 日期: car
# -----
# 標題: ◎[房版] 房屋買賣版
# 推文數: 503
# 日期: home-sale
# -----
# 標題: ◎[台籃] 例行賽
# 推文數: 462
# 日期: basketballTW
# -----
# 標題: ◎[軍事]理性討論軍事 請詳閱板規
# 推文數: 456
# 日期: Military
# -----
# 標題: ◎[表特] 貼AI圖 一律水桶+退文
# 推文數: 415
# 日期: Beauty
# -----
# 標題: ◎[科技] 這裡是科技板
# 推文數: 354
# 日期: Tech_Job
# -----
# 標題: ◎[電蝦] intel 13 14代災情回報
# 推文數: 332
# 日期: PC_Shopping
# -----
# 標題: ◎感謝各位參與富士山票選
# 推文數: 326
# 日期: Japan_Travel
# -----
# 標題: ◎[運彩] 運彩板
# 推文數: 311
# 日期: SportLottery
# -----
# 標題: ◎[電影] 禁政治版規延續 注意置底
# 推文數: 307
# 日期: movie
# -----
# 標題: ◎[通訊]
# 推文數: 300
# 日期: MobileComm
# -----
# 標題: ◎[韓劇]
# 推文數: 284
# 日期: KoreaDrama
# -----
# 標題: ◎[四叉] 工程師身上有乖乖很合理的
# 推文數: 268
# 日期: BaseballXXXX
# -----
# 標題: ◎AV女優板 清新、優質,神人照格式
# 推文數: 257
# 日期: japanavgirls
# -----
# 標題: ◎[邊緣] どう足掻いても明日はない
# 推文數: 241
# 日期: Marginalman
# -----
# 標題: ◎[卡板]
# 推文數: 219
# 日期: creditcard
# -----
# 標題: ◎[PS5] 4/26 STELLAR BLADE 劍星
# 推文數: 204
# 日期: PlayStation
# -----
# 標題: ◎[寶寶] 記得打流感疫苗
# 推文數: 203
# 日期: BabyMother
# -----
# 標題: ◎本板禁止買賣合購代購代刷
# 推文數: 203
# 日期: Steam
# -----
# 標題: ◎[女孩]請小心餘震注意安全<(@o@)/
# 推文數: 197
# 日期: WomenTalk
# -----
# 標題: ◎The Last Together 最後一齊
# 推文數: 193
# 日期: Elephants
# -----
# 標題: ◎[歐兔] 愛是一道光 如此美妙
# 推文數: 185
# 日期: AllTogether
# -----
# 標題: ◎[米哈遊] 原神動畫短片-燼中歌
# 推文數: 181
# 日期: miHoYo
# -----
# 標題: ◎[男女] 水桶很滿 推文請三思
# 推文數: 168
# 日期: Boy-Girl
# -----
# 標題: ◎[數位貨幣] 地動山搖
# 推文數: 150
# 日期: DigiCurrency
# -----
# 標題: ◎行車紀錄器-4/15AM9:00路竹區
# 推文數: 144
# 日期: Kaohsiung
# -----
# 標題: ◎[硬交] 欲售之物品須入手時間>1M
# 推文數: 141
# 日期: HardwareSale
# -----
# 標題: ◎統一獅板
# 推文數: 140
# 日期: Lions
# -----
# 標題: ◎[台南] 請詳閱交易文規範:)
# 推文數: 136
# 日期: Tainan
# -----
# 標題: ◎[台中] 節約用水 節約用電
# 推文數: 129
# 日期: TaichungBun
# -----
# 標題: ◎[iOS] Apple®devices family
# 推文數: 125
# 日期: iOS
# -----
# 標題: ◎[NS] 紙片瑪利歐 RPG 5/23
# 推文數: 123
# 日期: NSwitch
# -----
# 標題: ◎[玄幻] 玄幻小說板
# 推文數: 123
# 日期: CFantasy
# -----
# 標題: ◎[EA] 歐美影集版
# 推文數: 115
# 日期: EAseries
# -----
# 標題: ◎[CVS] 超商店員a.k.a.superman
# 推文數: 114
# 日期: CVS
# -----
# 標題: ◎[日劇] 土22 森本慎太郎
# 推文數: 110
# 日期: Japandrama
# -----
# 標題: ◎[裏洽] 勤洗手
# 推文數: 105
# 日期: AC_In
# -----
# 標題: ◎[就可] 貓貓可愛
# 推文數: 105
# 日期: joke
# -----
# 標題: ◎[錶板] Show me your Watch!
# 推文數: 103
# 日期: watch
# -----
# 標題: ◎[Lakers] Los Angeles Lakers
# 推文數: 100
# 日期: Lakers
# -----
# 標題: ◎[網球] Sinner #1 & Sabalenka #2
# 推文數: 98
# 日期: Tennis
# -----
# 標題: ◎[航空] 航空板 請先詳閱板規
# 推文數: 96
# 日期: Aviation
# -----
# 標題: ◎[海賊王] 1111 「太陽之盾」
# 推文數: 94
# 日期: ONE_PIECE
# -----
# 標題: ◎[P＆D] 鋼彈系列 合作復刻
# 推文數: 93
# 日期: PuzzleDragon
# -----
# 標題: ◎[汽車買賣] 看【置底公告】再發文
# 推文數: 91
# 日期: CarShop
# -----
# 標題: ◎[Mobile] 板規不看，水桶就來
# 推文數: 86
# 日期: mobilesales
# -----
# 標題: ◎[機車]殺人部長 王國才
# 推文數: 86
# 日期: biker
# -----
# 標題: ◎[美保]
# 推文數: 86
# 日期: BeautySalon
# -----
# 標題: ◎[中劇] 禁止攻擊演員個人及長相
# 推文數: 84
# 日期: China-Drama
# -----
# 標題: ◎[ＥＳ] 注意板規 遠離水桶
# 推文數: 84
# 日期: e-shopping
# -----
# 標題: ◎[韓綜] Show Me The 新板主!
# 推文數: 82
# 日期: KR_Entertain
# -----
# 標題: ◎[麥蝦] 發文前請先詳閱板規
# 推文數: 81
# 日期: MacShop
# -----
# 標題: ◎水桶機器人值勤中 O口O
# 推文數: 80
# 日期: Headphone
# -----
# 標題: ◎[GS] 遊戲交易板
# 推文數: 78
# 日期: Gamesale
# -----
# 標題: ◎[媽佛] 恐怖x外星人x預知夢?
# 推文數: 78
# 日期: marvel
# -----
# 標題: ◎[原創] 年度必看 徵文詳見置底
# 推文數: 71
# 日期: YuanChuang
# -----
# 標題: ◎[攝影] 2024
# 推文數: 70
# 日期: DSLR
# -----
# 標題: ◎藝文票券轉售板 禁止徵票小心詐騙
# 推文數: 70
# 日期: Drama-Ticket
# -----
# 標題: ◎[新竹] 新板主要來了~~\⊙▽⊙/
# 推文數: 69
# 日期: Hsinchu
# -----
# 標題: ◎標題錯就刪，版主不是客服
# 推文數: 66
# 日期: DC_SALE
# -----
# 標題: ◎我勇諸位好好休息，展望下賽季。
# 推文數: 65
# 日期: G-S-WARRIORS
# -----
# 標題: ◎[PMGO] 4/20:喇叭芽社群日14~17點
# 推文數: 64
# 日期: PokemonGO
# -----
# 標題: ◎實習教師! 看板規!代理置底推!^0^
# 推文數: 63
# 日期: studyteacher
# -----
# 標題: ◎[職場] 工作職場板
# 推文數: 62
# 日期: Salary
# -----
# 標題: ◎樂天桃猿！徵選版主中
# 推文數: 58
# 日期: Monkeys
# -----
# 標題: ◎[銀行服務板] 發文要有50字滿3行
# 推文數: 55
# 日期: Bank_Service
# -----
# 標題: ◎[爐石] 爐石十週年了!
# 推文數: 53
# 日期: Hearthstone
# -----
# 標題: ◎[家電] 發文請照規定發文
# 推文數: 53
# 日期: E-appliance
# -----
# 標題: ◎[速食] 慟！麥香魚起士只放半片
# 推文數: 53
# 日期: fastfood
# -----
# 標題: ◎[美妝]
# 推文數: 52
# 日期: MakeUp
# -----
# 標題: ◎[健身] 發文前請務必詳閱板規
# 推文數: 51
# 日期: MuscleBeach
# -----
# 標題: ◎[汪踢] 速揪吃早餐
# 推文數: 49
# 日期: Wanted
# -----
# 標題: ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# 推文數: 49
# 日期: e-coupon
# -----
# 標題: ◎2024 Opening Day
# 推文數: 49
# 日期: MLB
# -----
# 標題: ◎[神魔] 四乃森蒼紫
# 推文數: 47
# 日期: ToS
# -----
# 標題: ◎[公職] 今年5/1軍公教不放假
# 推文數: 45
# 日期: PublicServan
# -----
# 標題: ◎[臺劇] 4/6 不夠善良的我們
# 推文數: 45
# 日期: TaiwanDrama
# -----
# 標題: ◎[醫學美容版]　嚴禁揪團買賣廣告
# 推文數: 44
# 日期: facelift
# -----
# 標題: ◎F1板 燈滅起跑!
# 推文數: 44
# 日期: FORMULA1
# -----
# 標題: ◎美食板
# 推文數: 44
# 日期: Food
# -----
# 標題: ◎[喵板]禁止交易贈送徵求醫療用品
# 推文數: 42
# 日期: cat
# -----
# 標題: ◎[羽球版]
# 推文數: 42
# 日期: Badminton
# -----
# 標題: ◎[悍將] 滿壘狂攻！夠悍
# 推文數: 42
# 日期: Guardians
# -----
# 標題: ◎坂道閒聊板
# 推文數: 39
# 日期: SakaTalk
# -----
# 標題: ◎[踢雀] 通往開學的倒數計時~~
# 推文數: 39
# 日期: Teacher
# -----
# 標題: ◎抵制買榜 抵制作弊，韓樂需要正義
# 推文數: 38
# 日期: KoreanPop
# -----
# 標題: ◎[期權] 違規檢舉請至置底文
# 推文數: 38
# 日期: Option
# -----
# 標題: ◎[WoW] 10.2.6 上線
# 推文數: 37
# 日期: WOW
# -----
# 標題: ◎咖啡 秋意漸濃
# 推文數: 37
# 日期: Coffee
# -----
# 標題: ◎[桃園]
# 推文數: 36
# 日期: Taoyuan
# -----
# 標題: ◎PTT重機板 ~ 發買賣文請詳閱置底
# 推文數: 36
# 日期: SuperBike
# -----
# 標題: ◎[暗黑] 暗黑2024年到來!
# 推文數: 36
# 日期: DIABLO
# -----
# 標題: ◎[喇音] 請詳閱置底板規公告
# 推文數: 35
# 日期: Audiophile
# -----
# 標題: ◎H-GAME板
# 推文數: 35
# 日期: H-GAME
# -----
# 標題: ◎[鍵鼠] 2024新年快樂
# 推文數: 35
# 日期: Key_Mou_Pad
# -----
# 標題: ◎歡迎分享手做美食
# 推文數: 35
# 日期: cookclub
# -----
# 標題: ◎[嘻哈]
# 推文數: 35
# 日期: Hip-Hop
# -----
# 標題: ◎ 哼哼哼哼
# 推文數: 35
# 日期: StupidClown
# -----
# 標題: ◎歡樂．三喵．足球
# 推文數: 34
# 日期: FAPL
# -----
# 標題: ◎[軟工] 成為全宇宙のNo.1吧
# 推文數: 33
# 日期: Soft_Job
# -----
# 標題: ◎[打工] 112/01/01起 工資 176/hr
# 推文數: 33
# 日期: part-time
# -----
# 標題: ◎[蔚藍] 0420生放送，樂透開盤中
# 推文數: 32
# 日期: BlueArchive
# -----
# 標題: ◎ ＊* 布蘭德 細節的價值 ＊*
# 推文數: 31
# 日期: Brand
# -----
# 標題: ◎[電視] 2024 留意舊機出清撿便宜
# 推文數: 31
# 日期: Digitalhome
# -----
# 標題: ◎婦嬰用品販售版
# 推文數: 30
# 日期: BabyProducts
# -----
# 標題: ◎[筆電蝦]
# 推文數: 29
# 日期: nb-shopping
# -----
# 標題: ◎13:30林昀儒-張禹珍 世界盃4/18
# 推文數: 29
# 日期: tabletennis
# -----
# 標題: ◎[DMMG] 歡迎光臨DMM GAMES
# 推文數: 28
# 日期: DMM_GAMES
# -----
# 標題: ◎韓國旅遊板(韓幣交易桶10年)
# 推文數: 27
# 日期: Korea_Travel
# -----
# 標題: ◎[飽板] 能吃就是福
# 推文數: 27
# 日期: EatToDie
# -----
# 標題: ◎要求先提供照片 一律刪文水桶一週
# 推文數: 27
# 日期: job
# -----
# 標題: ◎[FGO] 台 周二維修後 八犬傳
# 推文數: 26
# 日期: FATE_GO
# -----
# 標題: ◎[國考] 徵求上榜心得文
# 推文數: 26
# 日期: Examination
# -----
# 標題: ◎[鐵道] 徵選板主
# 推文數: 25
# 日期: Railway
# -----
# 標題: ◎[單車] 大家來看環台賽吧！
# 推文數: 25
# 日期: bicycle
# -----
# 標題: ◎[拉板] welcome to 拉版
# 推文數: 25
# 日期: lesbian
# -----
# 標題: ◎[台綜]
# 推文數: 25
# 日期: TW_Entertain
# -----

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    for item in items:
        # 提取標題和推文數
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 提取日期
        # 日期在標題的相鄰元素，可以通過索引取得
        date_element = item.find('.board-title', first=True).next_element
        date = date_element.strip()  # 去除多餘的空白

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("日期:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 21
#      17 nuser = item.find('.board-nuser .hl', first=True).text
#      19 # 提取日期
#      20 # 日期在標題的相鄰元素，可以通過索引取得
# ---> 21 date_element = item.find('.board-title', first=True).next_element
#      22 date = date_element.strip()  # 去除多餘的空白
#      24 # 打印標題、推文數和日期
#
# AttributeError: 'Element' object has no attribute 'next_element'

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 7532
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 3719
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3134
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2173
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 1901
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1240
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1068
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 871
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 634
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 599
# -----
# 標題: ◎[西斯] 不要輕易幫別人買蒜味麵包
# 推文數: 516
# -----
# 標題: ◎[汽車] 恭喜Pellaeon成為新版主
# 推文數: 509
# -----
# 標題: ◎[房版] 房屋買賣版
# 推文數: 446
# -----
# 標題: ◎[台籃] 例行賽
# 推文數: 399
# -----
# 標題: ◎[軍事]理性討論軍事 請詳閱板規
# 推文數: 381
# -----
# 標題: ◎[表特] 貼AI圖 一律水桶+退文
# 推文數: 375
# -----
# 標題: ◎[運彩] 運彩板
# 推文數: 339
# -----
# 標題: ◎[電影] 禁政治版規延續 注意置底
# 推文數: 323
# -----
# 標題: ◎[電蝦] intel 13 14代災情回報
# 推文數: 312
# -----
# 標題: ◎[科技] 這裡是科技板
# 推文數: 306
# -----
# 標題: ◎感謝各位參與富士山票選
# 推文數: 295
# -----
# 標題: ◎[韓劇]
# 推文數: 280
# -----
# 標題: ◎[通訊]
# 推文數: 271
# -----
# 標題: ◎AV女優板 清新、優質,神人照格式
# 推文數: 257
# -----
# 標題: ◎[四叉] 工程師身上有乖乖很合理的
# 推文數: 255
# -----
# 標題: ◎[邊緣] どう足掻いても明日はない
# 推文數: 211
# -----
# 標題: ◎[女孩]請小心餘震注意安全<(@o@)/
# 推文數: 208
# -----
# 標題: ◎[卡板]
# 推文數: 198
# -----
# 標題: ◎[PS5] 4/26 STELLAR BLADE 劍星
# 推文數: 187
# -----
# 標題: ◎[寶寶] 記得打流感疫苗
# 推文數: 185
# -----
# 標題: ◎本板禁止買賣合購代購代刷
# 推文數: 182
# -----
# 標題: ◎[米哈遊] 原神動畫短片-燼中歌
# 推文數: 178
# -----
# 標題: ◎[歐兔] 愛是一道光 如此美妙
# 推文數: 174
# -----
# 標題: ◎[男女] 水桶很滿 推文請三思
# 推文數: 170
# -----
# 標題: ◎The Last Together 最後一齊
# 推文數: 146
# -----
# 標題: ◎[台南] 請詳閱交易文規範:)
# 推文數: 142
# -----
# 標題: ◎[數位貨幣] 地動山搖
# 推文數: 137
# -----
# 標題: ◎[硬交] 欲售之物品須入手時間>1M
# 推文數: 135
# -----
# 標題: ◎[iOS] Apple®devices family
# 推文數: 127
# -----
# 標題: ◎行車紀錄器-4/15AM9:00路竹區
# 推文數: 127
# -----
# 標題: ◎[CVS] 超商店員a.k.a.superman
# 推文數: 125
# -----
# 標題: ◎[台中] 節約用水 節約用電
# 推文數: 116
# -----
# 標題: ◎[玄幻] 玄幻小說板
# 推文數: 115
# -----
# 標題: ◎統一獅板
# 推文數: 115
# -----
# 標題: ◎[NS] 紙片瑪利歐 RPG 5/23
# 推文數: 113
# -----
# 標題: ◎[EA] 歐美影集版
# 推文數: 111
# -----
# 標題: ◎[裏洽] 勤洗手
# 推文數: 98
# -----
# 標題: ◎[日劇] 土22 森本慎太郎
# 推文數: 98
# -----
# 標題: ◎[就可] 貓貓可愛
# 推文數: 97
# -----
# 標題: ◎[錶板] Show me your Watch!
# 推文數: 96
# -----
# 標題: ◎[機車]殺人部長 王國才
# 推文數: 93
# -----
# 標題: ◎[P＆D] 鋼彈系列 合作復刻
# 推文數: 84
# -----
# 標題: ◎[航空] 航空板 請先詳閱板規
# 推文數: 83
# -----
# 標題: ◎[海賊王] 1111 「太陽之盾」
# 推文數: 83
# -----
# 標題: ◎[Mobile] 板規不看，水桶就來
# 推文數: 82
# -----
# 標題: ◎[中劇] 禁止攻擊演員個人及長相
# 推文數: 82
# -----
# 標題: ◎[汽車買賣] 看【置底公告】再發文
# 推文數: 80
# -----
# 標題: ◎水桶機器人值勤中 O口O
# 推文數: 79
# -----
# 標題: ◎[Lakers] Los Angeles Lakers
# 推文數: 79
# -----
# 標題: ◎[網球] Sinner #1 & Sabalenka #2
# 推文數: 78
# -----
# 標題: ◎[韓綜] Show Me The 新板主!
# 推文數: 75
# -----
# 標題: ◎[麥蝦] 發文前請先詳閱板規
# 推文數: 75
# -----
# 標題: ◎[媽佛] 恐怖x外星人x預知夢?
# 推文數: 73
# -----
# 標題: ◎[美保]
# 推文數: 73
# -----
# 標題: ◎[ＥＳ] 注意板規 遠離水桶
# 推文數: 68
# -----
# 標題: ◎我勇諸位好好休息，展望下賽季。
# 推文數: 66
# -----
# 標題: ◎標題錯就刪，版主不是客服
# 推文數: 65
# -----
# 標題: ◎[攝影] 2024
# 推文數: 65
# -----
# 標題: ◎[新竹] 新板主要來了~~\⊙▽⊙/
# 推文數: 65
# -----
# 標題: ◎[家電] 發文請照規定發文
# 推文數: 61
# -----
# 標題: ◎[職場] 工作職場板
# 推文數: 61
# -----
# 標題: ◎[原創] 年度必看 徵文詳見置底
# 推文數: 59
# -----
# 標題: ◎藝文票券轉售板 禁止徵票小心詐騙
# 推文數: 57
# -----
# 標題: ◎[爐石] 爐石十週年了!
# 推文數: 56
# -----
# 標題: ◎[GS] 遊戲交易板
# 推文數: 56
# -----
# 標題: ◎[PMGO] 4/20:喇叭芽社群日14~17點
# 推文數: 53
# -----
# 標題: ◎樂天桃猿！徵選版主中
# 推文數: 52
# -----
# 標題: ◎實習教師! 看板規!代理置底推!^0^
# 推文數: 51
# -----
# 標題: ◎[健身] 發文前請務必詳閱板規
# 推文數: 51
# -----
# 標題: ◎[美妝]
# 推文數: 50
# -----
# 標題: ◎[汪踢] 速揪吃早餐
# 推文數: 48
# -----
# 標題: ◎[神魔] 四乃森蒼紫
# 推文數: 46
# -----
# 標題: ◎[銀行服務板] 發文要有50字滿3行
# 推文數: 46
# -----
# 標題: ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# 推文數: 44
# -----
# 標題: ◎[公職] 今年5/1軍公教不放假
# 推文數: 42
# -----
# 標題: ◎H-GAME板
# 推文數: 41
# -----
# 標題: ◎[速食] 慟！麥香魚起士只放半片
# 推文數: 41
# -----
# 標題: ◎[臺劇] 4/6 不夠善良的我們
# 推文數: 41
# -----
# 標題: ◎2024 Opening Day
# 推文數: 41
# -----
# 標題: ◎[WoW] 10.2.6 上線
# 推文數: 40
# -----
# 標題: ◎[電視] 2024 留意舊機出清撿便宜
# 推文數: 40
# -----
# 標題: ◎[喵板]禁止交易贈送徵求醫療用品
# 推文數: 39
# -----
# 標題: ◎F1板 燈滅起跑!
# 推文數: 39
# -----
# 標題: ◎[醫學美容版]　嚴禁揪團買賣廣告
# 推文數: 38
# -----
# 標題: ◎抵制買榜 抵制作弊，韓樂需要正義
# 推文數: 37
# -----
# 標題: ◎[桃園]
# 推文數: 37
# -----
# 標題: ◎PTT重機板 ~ 發買賣文請詳閱置底
# 推文數: 37
# -----
# 標題: ◎[羽球版]
# 推文數: 37
# -----
# 標題: ◎[悍將] 滿壘狂攻！夠悍
# 推文數: 37
# -----
# 標題: ◎坂道閒聊板
# 推文數: 36
# -----
# 標題: ◎[期權] 違規檢舉請至置底文
# 推文數: 36
# -----
# 標題: ◎[暗黑] 暗黑2024年到來!
# 推文數: 36
# -----
# 標題: ◎[嘻哈]
# 推文數: 36
# -----
# 標題: ◎ 哼哼哼哼
# 推文數: 36
# -----
# 標題: ◎咖啡 秋意漸濃
# 推文數: 36
# -----
# 標題: ◎婦嬰用品販售版
# 推文數: 34
# -----
# 標題: ◎[軟工] 成為全宇宙のNo.1吧
# 推文數: 34
# -----
# 標題: ◎[打工] 112/01/01起 工資 176/hr
# 推文數: 34
# -----
# 標題: ◎美食板
# 推文數: 34
# -----
# 標題: ◎[筆電蝦]
# 推文數: 32
# -----
# 標題: ◎[贈送] 標題不合置底文規定 刪
# 推文數: 32
# -----
# 標題: ◎[鍵鼠] 2024新年快樂
# 推文數: 32
# -----
# 標題: ◎[蔚藍] 0420生放送，樂透開盤中
# 推文數: 31
# -----
# 標題: ◎[DMMG] 歡迎光臨DMM GAMES
# 推文數: 31
# -----
# 標題: ◎[FGO] 台 周二維修後 八犬傳
# 推文數: 30
# -----
# 標題: ◎韓國旅遊板(韓幣交易桶10年)
# 推文數: 30
# -----
# 標題: ◎[踢雀] 通往開學的倒數計時~~
# 推文數: 29
# -----
# 標題: ◎[喇音] 請詳閱置底板規公告
# 推文數: 27
# -----
# 標題: ◎歡樂．三喵．足球
# 推文數: 27
# -----
# 標題: ◎歡迎分享手做美食
# 推文數: 27
# -----
# 標題: ◎要求先提供照片 一律刪文水桶一週
# 推文數: 27
# -----
# 標題: ◎海外投資版
# 推文數: 26
# -----
# 標題: ◎[飽板] 能吃就是福
# 推文數: 26
# -----
# 標題: ◎[拉板] welcome to 拉版
# 推文數: 26
# -----
# 標題: ◎[甲板]勇気爆発Bang Bravern
# 推文數: 26
# -----
# 標題: ◎[鐵道] 徵選板主
# 推文數: 25
# -----
# 標題: ◎跑步版-抱歉我拖累了路跑版水準
# 推文數: 25
# -----
# 標題: ◎ ＊* 布蘭德 細節的價值 ＊*
# 推文數: 25
# -----

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    for item in items:
        # 提取標題和推文數
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 提取日期
        # 日期在標題的相鄰元素，可以通過 next_sibling 取得
        date_element = item.find('.board-title', first=True).next_sibling
        date = date_element.strip()  # 去除多餘的空白

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("日期:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 21
#      17 nuser = item.find('.board-nuser .hl', first=True).text
#      19 # 提取日期
#      20 # 日期在標題的相鄰元素，可以通過 next_sibling 取得
# ---> 21 date_element = item.find('.board-title', first=True).next_sibling
#      22 date = date_element.strip()  # 去除多餘的空白
#      24 # 打印標題、推文數和日期
#
# AttributeError: 'Element' object has no attribute 'next_sibling'

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    for item in items:
        # 提取標題和推文數
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 提取日期
        # 日期在標題的相鄰元素，可以通過 xpath 取得
        date_element = item.xpath('.//div[@class="board-title"]/following-sibling::div', first=True)
        if date_element is not None:
            date = date_element.text
        else:
            date = "日期未知"

        # 打印標題、推文數和日期
        print("標題:", title)
        print("推文數:", nuser)
        print("日期:", date)
        print("-----")

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 7438
# 日期: 日期未知
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 3580
# 日期: 日期未知
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3053
# 日期: 日期未知
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2077
# 日期: 日期未知
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 1839
# 日期: 日期未知
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1184
# 日期: 日期未知
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1025
# 日期: 日期未知
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 851
# 日期: 日期未知
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 647
# 日期: 日期未知
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 578
# 日期: 日期未知
# -----
# 標題: ◎[西斯] 不要輕易幫別人買蒜味麵包
# 推文數: 514
# 日期: 日期未知
# -----
# 標題: ◎[汽車] 恭喜Pellaeon成為新版主
# 推文數: 494
# 日期: 日期未知
# -----
# 標題: ◎[房版] 房屋買賣版
# 推文數: 453
# 日期: 日期未知
# -----
# 標題: ◎[台籃] 例行賽
# 推文數: 381
# 日期: 日期未知
# -----
# 標題: ◎[軍事]理性討論軍事 請詳閱板規
# 推文數: 381
# 日期: 日期未知
# -----
# 標題: ◎[表特] 貼AI圖 一律水桶+退文
# 推文數: 379
# 日期: 日期未知
# -----
# 標題: ◎[運彩] 運彩板
# 推文數: 312
# 日期: 日期未知
# -----
# 標題: ◎[電蝦] intel 13 14代災情回報
# 推文數: 307
# 日期: 日期未知
# -----
# 標題: ◎[電影] 禁政治版規延續 注意置底
# 推文數: 307
# 日期: 日期未知
# -----
# 標題: ◎[科技] 這裡是科技板
# 推文數: 293
# 日期: 日期未知
# -----
# 標題: ◎[韓劇]
# 推文數: 292
# 日期: 日期未知
# -----
# 標題: ◎感謝各位參與富士山票選
# 推文數: 289
# 日期: 日期未知
# -----
# 標題: ◎[通訊]
# 推文數: 257
# 日期: 日期未知
# -----
# 標題: ◎[四叉] 工程師身上有乖乖很合理的
# 推文數: 243
# 日期: 日期未知
# -----
# 標題: ◎AV女優板 清新、優質,神人照格式
# 推文數: 238
# 日期: 日期未知
# -----
# 標題: ◎[邊緣] どう足掻いても明日はない
# 推文數: 213
# 日期: 日期未知
# -----
# 標題: ◎[女孩]請小心餘震注意安全<(@o@)/
# 推文數: 194
# 日期: 日期未知
# -----
# 標題: ◎[PS5] 4/26 STELLAR BLADE 劍星
# 推文數: 192
# 日期: 日期未知
# -----
# 標題: ◎本板禁止買賣合購代購代刷
# 推文數: 192
# 日期: 日期未知
# -----
# 標題: ◎[卡板]
# 推文數: 186
# 日期: 日期未知
# -----
# 標題: ◎[歐兔] 愛是一道光 如此美妙
# 推文數: 180
# 日期: 日期未知
# -----
# 標題: ◎[寶寶] 記得打流感疫苗
# 推文數: 176
# 日期: 日期未知
# -----
# 標題: ◎[米哈遊] 原神動畫短片-燼中歌
# 推文數: 168
# 日期: 日期未知
# -----
# 標題: ◎The Last Together 最後一齊
# 推文數: 155
# 日期: 日期未知
# -----
# 標題: ◎[男女] 水桶很滿 推文請三思
# 推文數: 155
# 日期: 日期未知
# -----
# 標題: ◎[iOS] Apple®devices family
# 推文數: 146
# 日期: 日期未知
# -----
# 標題: ◎[硬交] 欲售之物品須入手時間>1M
# 推文數: 133
# 日期: 日期未知
# -----
# 標題: ◎[台南] 請詳閱交易文規範:)
# 推文數: 132
# 日期: 日期未知
# -----
# 標題: ◎行車紀錄器-4/15AM9:00路竹區
# 推文數: 124
# 日期: 日期未知
# -----
# 標題: ◎[數位貨幣] 地動山搖
# 推文數: 123
# 日期: 日期未知
# -----
# 標題: ◎[NS] 紙片瑪利歐 RPG 5/23
# 推文數: 121
# 日期: 日期未知
# -----
# 標題: ◎[CVS] 超商店員a.k.a.superman
# 推文數: 113
# 日期: 日期未知
# -----
# 標題: ◎[EA] 歐美影集版
# 推文數: 111
# 日期: 日期未知
# -----
# 標題: ◎[玄幻] 玄幻小說板
# 推文數: 109
# 日期: 日期未知
# -----
# 標題: ◎統一獅板
# 推文數: 109
# 日期: 日期未知
# -----
# 標題: ◎[錶板] Show me your Watch!
# 推文數: 103
# 日期: 日期未知
# -----
# 標題: ◎[台中] 節約用水 節約用電
# 推文數: 102
# 日期: 日期未知
# -----
# 標題: ◎[裏洽] 勤洗手
# 推文數: 101
# 日期: 日期未知
# -----
# 標題: ◎[日劇] 土22 森本慎太郎
# 推文數: 99
# 日期: 日期未知
# -----
# 標題: ◎[機車]殺人部長 王國才
# 推文數: 95
# 日期: 日期未知
# -----
# 標題: ◎[就可] 貓貓可愛
# 推文數: 93
# 日期: 日期未知
# -----
# 標題: ◎[海賊王] 1111 「太陽之盾」
# 推文數: 90
# 日期: 日期未知
# -----
# 標題: ◎[P＆D] 鋼彈系列 合作復刻
# 推文數: 88
# 日期: 日期未知
# -----
# 標題: ◎[航空] 航空板 請先詳閱板規
# 推文數: 88
# 日期: 日期未知
# -----
# 標題: ◎水桶機器人值勤中 O口O
# 推文數: 82
# 日期: 日期未知
# -----
# 標題: ◎[Mobile] 板規不看，水桶就來
# 推文數: 81
# 日期: 日期未知
# -----
# 標題: ◎[美保]
# 推文數: 80
# 日期: 日期未知
# -----
# 標題: ◎[汽車買賣] 看【置底公告】再發文
# 推文數: 79
# 日期: 日期未知
# -----
# 標題: ◎[媽佛] 恐怖x外星人x預知夢?
# 推文數: 78
# 日期: 日期未知
# -----
# 標題: ◎[中劇] 禁止攻擊演員個人及長相
# 推文數: 75
# 日期: 日期未知
# -----
# 標題: ◎[網球] Sinner #1 & Sabalenka #2
# 推文數: 75
# 日期: 日期未知
# -----
# 標題: ◎[麥蝦] 發文前請先詳閱板規
# 推文數: 73
# 日期: 日期未知
# -----
# 標題: ◎[韓綜] Show Me The 新板主!
# 推文數: 72
# 日期: 日期未知
# -----
# 標題: ◎[ＥＳ] 注意板規 遠離水桶
# 推文數: 72
# 日期: 日期未知
# -----
# 標題: ◎我勇諸位好好休息，展望下賽季。
# 推文數: 68
# 日期: 日期未知
# -----
# 標題: ◎[新竹] 新板主要來了~~\⊙▽⊙/
# 推文數: 68
# 日期: 日期未知
# -----
# 標題: ◎[Lakers] Los Angeles Lakers
# 推文數: 66
# 日期: 日期未知
# -----
# 標題: ◎[攝影] 2024
# 推文數: 65
# 日期: 日期未知
# -----
# 標題: ◎[職場] 工作職場板
# 推文數: 62
# 日期: 日期未知
# -----
# 標題: ◎標題錯就刪，版主不是客服
# 推文數: 59
# 日期: 日期未知
# -----
# 標題: ◎[原創] 年度必看 徵文詳見置底
# 推文數: 56
# 日期: 日期未知
# -----
# 標題: ◎[GS] 遊戲交易板
# 推文數: 55
# 日期: 日期未知
# -----
# 標題: ◎藝文票券轉售板 禁止徵票小心詐騙
# 推文數: 55
# 日期: 日期未知
# -----
# 標題: ◎[家電] 發文請照規定發文
# 推文數: 53
# 日期: 日期未知
# -----
# 標題: ◎[爐石] 爐石十週年了!
# 推文數: 51
# 日期: 日期未知
# -----
# 標題: ◎實習教師! 看板規!代理置底推!^0^
# 推文數: 51
# 日期: 日期未知
# -----
# 標題: ◎樂天桃猿！徵選版主中
# 推文數: 49
# 日期: 日期未知
# -----
# 標題: ◎[健身] 發文前請務必詳閱板規
# 推文數: 48
# 日期: 日期未知
# -----
# 標題: ◎[PMGO] 4/20:喇叭芽社群日14~17點
# 推文數: 48
# 日期: 日期未知
# -----
# 標題: ◎[公職] 今年5/1軍公教不放假
# 推文數: 46
# 日期: 日期未知
# -----
# 標題: ◎[汪踢] 速揪吃早餐
# 推文數: 45
# 日期: 日期未知
# -----
# 標題: ◎[神魔] 四乃森蒼紫
# 推文數: 43
# 日期: 日期未知
# -----
# 標題: ◎[臺劇] 4/6 不夠善良的我們
# 推文數: 43
# 日期: 日期未知
# -----
# 標題: ◎[美妝]
# 推文數: 43
# 日期: 日期未知
# -----
# 標題: ◎[銀行服務板] 發文要有50字滿3行
# 推文數: 42
# 日期: 日期未知
# -----
# 標題: ◎[悍將] 滿壘狂攻！夠悍
# 推文數: 42
# 日期: 日期未知
# -----
# 標題: ◎2024 Opening Day
# 推文數: 41
# 日期: 日期未知
# -----
# 標題: ◎H-GAME板
# 推文數: 40
# 日期: 日期未知
# -----
# 標題: ◎[WoW] 10.2.6 上線
# 推文數: 40
# 日期: 日期未知
# -----
# 標題: ◎e-coupon板規#1XewXRTO/#1Zxrj5t0
# 推文數: 38
# 日期: 日期未知
# -----
# 標題: ◎[期權] 違規檢舉請至置底文
# 推文數: 37
# 日期: 日期未知
# -----
# 標題: ◎[喵板]禁止交易贈送徵求醫療用品
# 推文數: 37
# 日期: 日期未知
# -----
# 標題: ◎F1板 燈滅起跑!
# 推文數: 37
# 日期: 日期未知
# -----
# 標題: ◎[嘻哈]
# 推文數: 37
# 日期: 日期未知
# -----
# 標題: ◎坂道閒聊板
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎[軟工] 成為全宇宙のNo.1吧
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎[醫學美容版]　嚴禁揪團買賣廣告
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎PTT重機板 ~ 發買賣文請詳閱置底
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎[羽球版]
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎ 哼哼哼哼
# 推文數: 36
# 日期: 日期未知
# -----
# 標題: ◎[速食] 慟！麥香魚起士只放半片
# 推文數: 35
# 日期: 日期未知
# -----
# 標題: ◎[桃園]
# 推文數: 35
# 日期: 日期未知
# -----
# 標題: ◎[暗黑] 暗黑2024年到來!
# 推文數: 35
# 日期: 日期未知
# -----
# 標題: ◎[打工] 112/01/01起 工資 176/hr
# 推文數: 35
# 日期: 日期未知
# -----
# 標題: ◎抵制買榜 抵制作弊，韓樂需要正義
# 推文數: 34
# 日期: 日期未知
# -----
# 標題: ◎[鍵鼠] 2024新年快樂
# 推文數: 34
# 日期: 日期未知
# -----
# 標題: ◎[電視] 2024 留意舊機出清撿便宜
# 推文數: 34
# 日期: 日期未知
# -----
# 標題: ◎[捷運] 環狀線板橋-中和仍停駛
# 推文數: 32
# 日期: 日期未知
# -----
# 標題: ◎美食板
# 推文數: 32
# 日期: 日期未知
# -----
# 標題: ◎[DMMG] 歡迎光臨DMM GAMES
# 推文數: 31
# 日期: 日期未知
# -----
# 標題: ◎[蔚藍] 0420生放送，樂透開盤中
# 推文數: 30
# 日期: 日期未知
# -----
# 標題: ◎婦嬰用品販售版
# 推文數: 30
# 日期: 日期未知
# -----
# 標題: ◎[鐵道] 徵選板主
# 推文數: 30
# 日期: 日期未知
# -----
# 標題: ◎歡樂．三喵．足球
# 推文數: 30
# 日期: 日期未知
# -----
# 標題: ◎[FGO] 台 周二維修後 八犬傳
# 推文數: 29
# 日期: 日期未知
# -----
# 標題: ◎韓國旅遊板(韓幣交易桶10年)
# 推文數: 29
# 日期: 日期未知
# -----
# 標題: ◎ ＊* 布蘭德 細節的價值 ＊*
# 推文數: 28
# 日期: 日期未知
# -----
# 標題: ◎歡迎分享手做美食
# 推文數: 28
# 日期: 日期未知
# -----
# 標題: ◎咖啡 秋意漸濃
# 推文數: 28
# 日期: 日期未知
# -----
# 標題: ◎[筆電蝦]
# 推文數: 27
# 日期: 日期未知
# -----
# 標題: ◎[喇音] 請詳閱置底板規公告
# 推文數: 27
# 日期: 日期未知
# -----
# 標題: ◎[踢雀] 通往開學的倒數計時~~
# 推文數: 27
# 日期: 日期未知
# -----
# 標題: ◎[飽板] 能吃就是福
# 推文數: 26
# 日期: 日期未知
# -----
# 標題: ◎跑步版-抱歉我拖累了路跑版水準
# 推文數: 26
# 日期: 日期未知
# -----
# 標題: ◎你安靜 發文前請詳置底文
# 推文數: 26
# 日期: 日期未知
# -----
# 標題: ◎[甲板]勇気爆発Bang Bravern
# 推文數: 26
# 日期: 日期未知
# -----
# 標題: ◎要求先提供照片 一律刪文水桶一週
# 推文數: 25
# 日期: 日期未知
# -----
# 標題: ◎[贈送] 標題不合置底文規定 刪
# 推文數: 24
# 日期: 日期未知
# -----

# %%
from requests_html import HTMLSession

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數
    items = response.html.find('.b-ent')

    # 計數器
    count = 0
    
    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 打印標題、推文數
        print("標題:", title)
        print("推文數:", nuser)
        print("-----")

        # 每打印一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎[八卦] 違反板規一直往水桶痛點踩
# 推文數: 7381
# -----
# 標題: ◎[股票] 地震來襲 請注意安全
# 推文數: 3523
# -----
# 標題: ◎[希洽] 五十嵐梨花生日快樂!!!
# 推文數: 3027
# -----
# 標題: ◎[棒球] 三地開魯閣囉!
# 推文數: 2058
# -----
# 標題: ◎[NBA] W4附加賽 熱火76 老鷹公牛
# 推文數: 1861
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1161
# -----
# 標題: ◎[婚姻] 歡迎光臨婚姻板
# 推文數: 1018
# -----
# 標題: ◎[韓星] 0413 HAPPY JIWOO DAY~
# 推文數: 829
# -----
# 標題: ◎[政黑] 開冷氣開到股票賺錢
# 推文數: 651
# -----
# 標題: ◎[LoL] GEN達成首次LCK四連霸
# 推文數: 558
# -----

# %%
from requests_html import HTMLSession
import re

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    # 計數器
    count = 0

    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 使用正則表達式清洗標題和推文數
        cleaned_title = re.sub(r'\[.*?\]', '', title)  # 移除中括號及內容
        cleaned_nuser = re.sub(r'\s+', '', nuser)  # 移除所有空白

        # 打印清理後的標題和推文數
        print("標題:", cleaned_title.strip())
        print("推文數:", cleaned_nuser)
        print("-----")

        # 每打印一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

else:
    print("無法取得網頁內容")
# Out:
# 標題: ◎ 違反板規一直往水桶痛點踩
# 推文數: 7362
# -----
# 標題: ◎ 地震來襲 請注意安全
# 推文數: 3477
# -----
# 標題: ◎ 五十嵐梨花生日快樂!!!
# 推文數: 2996
# -----
# 標題: ◎ 三地開魯閣囉!
# 推文數: 1973
# -----
# 標題: ◎ W4附加賽 熱火76 老鷹公牛
# 推文數: 1867
# -----
# 標題: ◎推薦碼板規已修改，推文前請注意
# 推文數: 1157
# -----
# 標題: ◎ 歡迎光臨婚姻板
# 推文數: 1007
# -----
# 標題: ◎ 0413 HAPPY JIWOO DAY~
# 推文數: 823
# -----
# 標題: ◎ 開冷氣開到股票賺錢
# 推文數: 632
# -----
# 標題: ◎ GEN達成首次LCK四連霸
# 推文數: 562
# -----

# %%
from requests_html import HTMLSession
import re
import pandas as pd

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    # 儲存清理後的資料的列表
    data = []

    # 計數器
    count = 0

    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 使用正則表達式清洗標題和推文數
        cleaned_title = re.sub(r'\[.*?\]', '', title).strip()  # 移除中括號及內容
        cleaned_nuser = re.sub(r'\s+', '', nuser)  # 移除所有空白

        # 將清理後的資料加入列表
        data.append({
            '標題': cleaned_title,
            '推文數': cleaned_nuser
        })

        # 每處理一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

    # 將資料列表轉換成 DataFrame
    df = pd.DataFrame(data)

    # 打印 DataFrame
    print(df)

else:
    print("無法取得網頁內容")
# Out:
#                         標題   推文數
# 0           ◎ 違反板規一直往水桶痛點踩  7281
# 1             ◎ 地震來襲 請注意安全  3451
# 2           ◎ 五十嵐梨花生日快樂!!!  3011
# 3                ◎ 三地開魯閣囉!  1956
# 4        ◎ W4附加賽 熱火76 老鷹公牛  1846
# 5         ◎推薦碼板規已修改，推文前請注意  1162
# 6                ◎ 歡迎光臨婚姻板   978
# 7  ◎ 0413 HAPPY JIWOO DAY~   807
# 8              ◎ 開冷氣開到股票賺錢   638
# 9          ◎ GEN達成首次LCK四連霸   565

# %%
from requests_html import HTMLSession
import re
import pandas as pd

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    # 儲存清理後的資料的列表
    data = []

    # 計數器
    count = 0

    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 使用正則表達式清洗標題和推文數
        cleaned_title = re.sub(r'\[.*?\]', '', title).strip()  # 移除中括號及內容
        cleaned_nuser = re.sub(r'\s+', '', nuser)  # 移除所有空白

        # 將清理後的資料加入列表
        data.append({
            '標題': cleaned_title,
            '推文數': cleaned_nuser
        })

        # 每處理一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

    # 將資料列表轉換成 DataFrame
    df = pd.DataFrame(data)

    # 將 DataFrame 儲存為 CSV 檔案
    df.to_csv('output.csv', index=False)

    print("已儲存為 output.csv 檔案")

else:
    print("無法取得網頁內容")
# Out:
# 已儲存為 output.csv 檔案

# %%
from requests_html import HTMLSession
import re
import pandas as pd

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    # 儲存清理後的資料的列表
    data = []

    # 計數器
    count = 0

    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 使用正則表達式清洗標題和推文數
        cleaned_title = re.sub(r'\[.*?\]', '', title).strip()  # 移除中括號及內容
        cleaned_nuser = re.sub(r'\s+', '', nuser)  # 移除所有空白

        # 將清理後的資料加入列表
        data.append({
            '標題': cleaned_title,
            '推文數': cleaned_nuser
        })

        # 每處理一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

    # 將資料列表儲存為 JSON 檔案
    with open('output.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print("已儲存為 output.json 檔案")

else:
    print("無法取得網頁內容")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 45
#      43     # 將資料列表儲存為 JSON 檔案
#      44     with open('output.json', 'w', encoding='utf-8') as f:
# ---> 45         json.dump(data, f, ensure_ascii=False, indent=4)
#      47     print("已儲存為 output.json 檔案")
#      49 else:
#
# NameError: name 'json' is not defined

# %%
from requests_html import HTMLSession
import re
import pandas as pd
import json  # 引入 json 模組

url = 'https://www.ptt.cc/bbs/hotboards.html'

# 建立 HTML 會話
session = HTMLSession()
response = session.get(url)

# 檢查是否成功取得網頁
if response.status_code == 200:
    # 使用 CSS 選擇器來提取標題、推文數和日期
    items = response.html.find('.b-ent')

    # 儲存清理後的資料的列表
    data = []

    # 計數器
    count = 0

    for item in items:
        title = item.find('.board-title', first=True).text
        nuser = item.find('.board-nuser .hl', first=True).text

        # 使用正則表達式清潔標題和推文數
        cleaned_title = re.sub(r'\[.*?\]', '', title).strip()  # 移除中括號及內容
        cleaned_nuser = re.sub(r'\s+', '', nuser)  # 移除所有空白

        # 將清潔後的資料加入列表
        data.append({
            '標題': cleaned_title,
            '推文數': cleaned_nuser
        })

        # 每處理一次就將計數器加一
        count += 1

        # 如果計數器達到10，就跳出迴圈
        if count == 10:
            break

    # 將資料列表儲存為 JSON 檔案
    with open('output.json', 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

    print("已儲存為 output.json 檔案")

else:
    print("無法取得網頁內容")
# Out:
# 已儲存為 output.json 檔案
